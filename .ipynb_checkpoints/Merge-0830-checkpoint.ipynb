# %%
#dependencies and option setup
import pandas as pd
from sqlalchemy import create_engine

# %%
#import csv
happiness = pd.read_csv('2015 Happiness Data.csv')
wdi = pd.read_csv('wdi_2015.csv')

# %%
#determine approximate number of indicators
x=list(wdi['IndicatorName'].unique())
indicators= [x[0]]
for i in range(1, len(x)-1):
    if x[i+1].split()[0:2] != x[i].split()[0:2]:
        indicators.append(x[i+1])
print(f'approximation of number of indicators: {len(indicators)}')
indicators
# Out:
# approximation of number of indicators: 65
# ['Bird species, threatened',
#  'Cost of business start-up procedures (% of GNI per capita)',
#  'Depth of credit information index (0=low to 8=high)',
#  'Distance to frontier score (0=lowest performance to 100=frontier)',
#  'Ease of doing business index (1=most business-friendly regulations)',
#  'Fish species, threatened',
#  'Improved sanitation facilities (% of population with access)',
#  'Improved water source (% of population with access)',
#  'Labor tax and contributions (% of commercial profits)',
#  'Lifetime risk of maternal death (%)',
#  'Mammal species, threatened',
#  'Maternal mortality ratio (modeled estimate, per 100,000 live births)',
#  'Mortality rate, infant (per 1,000 live births)',
#  'Number of maternal deaths',
#  'Other taxes payable by businesses (% of commercial profits)',
#  'Plant species (higher), threatened',
#  'Private credit bureau coverage (% of adults)',
#  'Procedures to build a warehouse (number)',
# ...

# %%
#pivot table created on Country Name and index reset to create primary key
indicator_table = pd.pivot_table(wdi, values='Value', index='CountryName', columns='IndicatorCode')
indicator_table.reset_index(inplace=True)
indicator_table
# Out:
# IndicatorCode         CountryName  DT.AMT.BLAT.CD  DT.AMT.DLXF.CD  \
# 0                     Afghanistan      93356000.0     122152000.0
# 1                         Albania      63421000.0     628276000.0
# 2                         Algeria     156481000.0     229092000.0
# 3                  American Samoa             NaN             NaN
# 4                         Andorra             NaN             NaN
# ..                            ...             ...             ...
# 241            West Bank and Gaza             NaN             NaN
# 242                         World             NaN             NaN
# 243                   Yemen, Rep.     149907000.0     443917000.0
# 244                        Zambia      67311000.0     158140000.0
# 245                      Zimbabwe     144888000.0     167018000.0
#
# IndicatorCode  DT.AMT.DPNG.CD  DT.AMT.MLAT.CD  DT.AMT.OFFT.CD  DT.AMT.PBND.CD  \
# 0                         0.0      28796000.0     122152000.0             0.0
# ...

# %%
#merge wdi with happiness df
merge = pd.merge(happiness, indicator_table, left_on = 'Country', right_on = 'CountryName', how='inner')
merge.drop(columns='CountryName', inplace=True)
merge
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Switzerland      Western Europe               1            7.587
# 1        Iceland      Western Europe               2            7.561
# 2        Denmark      Western Europe               3            7.527
# 3         Norway      Western Europe               4            7.522
# 4         Canada       North America               5            7.427
# ..           ...                 ...             ...              ...
# 134  Afghanistan       Southern Asia             153            3.575
# 135       Rwanda  Sub-Saharan Africa             154            3.465
# 136        Benin  Sub-Saharan Africa             155            3.340
# 137      Burundi  Sub-Saharan Africa             157            2.905
# 138         Togo  Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# ...

# %%
#display indicators and their indicator codes
indicate=wdi.iloc[:,2:4]
indicate.drop_duplicates(inplace=True)
#reset index
reset_index_df = indicate.reset_index()
indicator_df = reset_index_df.drop(['index'], axis=1)

#display max rows
pd.set_option('display.max_rows', None)

#display df
indicator_df
# Out:
#                                          IndicatorName      IndicatorCode
# 0                             Bird species, threatened     EN.BIR.THRD.NO
# 1    Business extent of disclosure index (0=less di...     IC.BUS.DISC.XQ
# 2    Cost of business start-up procedures (% of GNI...  IC.REG.COST.PC.ZS
# 3    Depth of credit information index (0=low to 8=...     IC.CRD.INFO.XQ
# 4    Distance to frontier score (0=lowest performan...     IC.BUS.DFRN.XQ
# 5    Ease of doing business index (1=most business-...     IC.BUS.EASE.XQ
# 6                             Fish species, threatened     EN.FSH.THRD.NO
# 7    Improved sanitation facilities (% of populatio...        SH.STA.ACSN
# 8    Improved sanitation facilities, rural (% of ru...     SH.STA.ACSN.RU
# 9    Improved sanitation facilities, urban (% of ur...     SH.STA.ACSN.UR
# 10   Improved water source (% of population with ac...     SH.H2O.SAFE.ZS
# 11   Improved water source, rural (% of rural popul...  SH.H2O.SAFE.RU.ZS
# ...

# %%
#reset option
pd.set_option('display.max_rows', 15)

#world happiness dataframe merged with development indicators
column_list1 = ['Country', 'Region', 'Happiness Rank', 'Happiness Score',
       'Standard Error', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity', 'Dystopia Residual']
df1=merge.loc[:, column_list1]
#list of indicators the group collectively determines as interesting/relevant
column_list2 = ['FB.BNK.CAPA.ZS', 'IC.ELC.OUTG', 'IC.FRM.OUTG.ZS', 'SH.STA.ACSN', 'SH.H2O.SAFE.ZS', 'IC.TAX.TOTL.CP.ZS', 'SI.POV.NAHC', 'IC.FRM.CRIM.ZS', 'IC.FRM.FEMM.ZS', 'IC.FRM.CORR.ZS', 'IC.FRM.OUTG.ZS']
df2=merge.loc[:, column_list2]
final = pd.concat([df1, df2], axis=1)
final
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Switzerland      Western Europe               1            7.587
# 1        Iceland      Western Europe               2            7.561
# 2        Denmark      Western Europe               3            7.527
# 3         Norway      Western Europe               4            7.522
# 4         Canada       North America               5            7.427
# ..           ...                 ...             ...              ...
# 134  Afghanistan       Southern Asia             153            3.575
# 135       Rwanda  Sub-Saharan Africa             154            3.465
# 136        Benin  Sub-Saharan Africa             155            3.340
# 137      Burundi  Sub-Saharan Africa             157            2.905
# 138         Togo  Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# ...

# %%
#notice numerous null values in the above dataframe - for loop used to further inspect data
for i in range(12, len(final.columns)):
    name = final.iloc[:,i].name
    null_sum = final.iloc[:,i].isna().sum()
    print(f"{name} has {null_sum} null values")
# Out:
# FB.BNK.CAPA.ZS has 65 null values
# IC.ELC.OUTG has 138 null values
# IC.FRM.OUTG.ZS has 138 null values
# SH.STA.ACSN has 4 null values
# SH.H2O.SAFE.ZS has 5 null values
# IC.TAX.TOTL.CP.ZS has 1 null values
# SI.POV.NAHC has 138 null values
# IC.FRM.CRIM.ZS has 138 null values
# IC.FRM.FEMM.ZS has 138 null values
# IC.FRM.CORR.ZS has 138 null values
# IC.FRM.OUTG.ZS has 138 null values

# %%
#appends list where null values are less than 10
code_list=[]
for i in range(13,len(merge.columns)):
    name=merge.iloc[:,i].name
    null_sum=merge.iloc[:,i].isna().sum()
    if null_sum <10:
        code_list.append(name)
        print(f"{name} has {null_sum} null values")
# Out:
# EN.BIR.THRD.NO has 1 null values
# EN.FSH.THRD.NO has 1 null values
# EN.HPT.THRD.NO has 1 null values
# EN.MAM.THRD.NO has 1 null values
# IC.BUS.DFRN.XQ has 1 null values
# IC.BUS.DISC.XQ has 1 null values
# IC.BUS.EASE.XQ has 1 null values
# IC.CRD.INFO.XQ has 1 null values
# IC.CRD.PRVT.ZS has 1 null values
# IC.CRD.PUBL.ZS has 1 null values
# IC.ELC.TIME has 1 null values
# IC.ISV.DURS has 9 null values
# IC.LGL.CRED.XQ has 1 null values
# IC.LGL.DURS has 1 null values
# IC.PRP.DURS has 2 null values
# IC.PRP.PROC has 2 null values
# IC.REG.COST.PC.ZS has 1 null values
# IC.REG.DURS has 1 null values
# IC.REG.PROC has 1 null values
# IC.TAX.DURS has 1 null values
# IC.TAX.PAYM has 1 null values
# IC.TAX.TOTL.CP.ZS has 1 null values
# IC.WRH.DURS has 3 null values
# IC.WRH.PROC has 3 null values
# SG.GEN.PARL.ZS has 4 null values
# SH.DTH.IMRT has 1 null values
# SH.DTH.MORT has 1 null values
# SH.DTH.NMRT has 1 null values
# SH.DYN.MORT has 1 null values
# ...

# %%
#merges happiness df with columns that contain less than 10 null values
df1=merge.loc[:,'Country':'Dystopia Residual']
df2=merge.loc[:,code_list]
final_subset = pd.concat([df1, df2], axis=1)
final_subset
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Switzerland      Western Europe               1            7.587
# 1        Iceland      Western Europe               2            7.561
# 2        Denmark      Western Europe               3            7.527
# 3         Norway      Western Europe               4            7.522
# 4         Canada       North America               5            7.427
# ..           ...                 ...             ...              ...
# 134  Afghanistan       Southern Asia             153            3.575
# 135       Rwanda  Sub-Saharan Africa             154            3.465
# 136        Benin  Sub-Saharan Africa             155            3.340
# 137      Burundi  Sub-Saharan Africa             157            2.905
# 138         Togo  Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# ...

# %%
#display max rows
pd.set_option('display.max_rows', None)
#determine indicator code and respective indicator name for those with less than 10 null values
reset_index_df = indicator_df[indicator_df['IndicatorCode'].isin(code_list)].reset_index()
code_list_df = reset_index_df.drop(['index'], axis=1)
code_list_df
# Out:
#                                         IndicatorName      IndicatorCode
# 0                            Bird species, threatened     EN.BIR.THRD.NO
# 1   Business extent of disclosure index (0=less di...     IC.BUS.DISC.XQ
# 2   Cost of business start-up procedures (% of GNI...  IC.REG.COST.PC.ZS
# 3   Depth of credit information index (0=low to 8=...     IC.CRD.INFO.XQ
# 4   Distance to frontier score (0=lowest performan...     IC.BUS.DFRN.XQ
# 5   Ease of doing business index (1=most business-...     IC.BUS.EASE.XQ
# 6                            Fish species, threatened     EN.FSH.THRD.NO
# 7   Improved sanitation facilities (% of populatio...        SH.STA.ACSN
# 8   Improved sanitation facilities, rural (% of ru...     SH.STA.ACSN.RU
# 9   Improved sanitation facilities, urban (% of ur...     SH.STA.ACSN.UR
# 10  Improved water source (% of population with ac...     SH.H2O.SAFE.ZS
# 11  Improved water source, rural (% of rural popul...  SH.H2O.SAFE.RU.ZS
# ...

# %%
#reset option
pd.set_option('display.max_rows', 15)
#display all columns
pd.set_option('display.max_columns', None)
#renamed for clarity
renamed = final_subset.rename(columns={"EN.BIR.THRD.NO": "Bird Species, Threatened",
                                      "IC.BUS.DISC.XQ": "Business extent of disclosure index (0=less disclosure to 10=more disclosure)",
                                       "IC.REG.COST.PC.ZS": "Cost of business start-up procedures (% of GNI per capita)",
                                       "IC.CRD.INFO.XQ": "Depth of credit information index (0=low to 8=high)",
                                       "IC.BUS.DFRN.XQ": "Distance to frontier score (0=lowest performance to 100=frontier)",
                                       "IC.BUS.EASE.XQ": "Ease of doing business index (1=most business-friendly regulations)",
                                       "EN.FSH.THRD.NO": "Fish species, threatened",
                                       "SH.STA.ACSN": "Improved sanitation facilities (% of population with access)",
                                       "SH.STA.ACSN.RU": "Improved sanitation facilities, rural (% of rural population with access)",
                                       "SH.STA.ACSN.UR": "Improved sanitation facilities, urban (% of urban population with access)",
                                       "SH.H2O.SAFE.ZS": "Improved water source (% of population with access)",
                                       "SH.H2O.SAFE.RU.ZS": "Improved water source, rural (% of rural population with access)",
                                       "SH.H2O.SAFE.UR.ZS": "Improved water source, urban (% of urban population with access)",
                                       "SH.MMR.RISK.ZS": "Lifetime risk of maternal death (%)",
                                       "SH.MMR.RISK": "Lifetime risk of maternal death (1 in: rate varies by country)",
                                       "EN.MAM.THRD.NO": "Mammal species, threatened",
                                       "SH.STA.MMRT": "Maternal mortality ratio (modeled estimate, per 100,000 live births)",
                                       "SP.DYN.IMRT.IN": "Mortality rate, infant (per 1,000 live births)",
                                       "SP.DYN.IMRT.FE.IN": "Mortality rate, infant, female (per 1,000 live births)",
                                       "SP.DYN.IMRT.MA.IN": "Mortality rate, infant, male (per 1,000 live births)",
                                       "SH.DYN.NMRT": "Mortality rate, neonatal (per 1,000 live births)",
                                       "SH.DYN.MORT": "Mortality rate, under-5 (per 1,000)",
                                       "SH.DYN.MORT.FE": "Mortality rate, under-5, female (per 1,000 live births)",
                                       "SH.DYN.MORT.MA": "Mortality rate, under-5, male (per 1,000 live births)",
                                       "SH.MMR.DTHS": "Number of maternal deaths",
                                       "EN.HPT.THRD.NO": "Plant species (higher), threatened",
                                       "IC.CRD.PRVT.ZS": "Private credit bureau coverage (% of adults)",
                                       "IC.WRH.PROC": "Time required to build a warehouse (days)",
                                       "IC.PRP.PROC": "Procedures to register property (number)",
                                       "SG.GEN.PARL.ZS": "Proportion of seats held by women in national parliaments (%)",
                                       "IC.CRD.PUBL.ZS": "Public credit registry coverage (% of adults)",
                                       "IC.REG.PROC": "Start-up procedures to register a business (number)",
                                       "IC.LGL.CRED.XQ": "Strength of legal rights index (0=weak to 12=strong)",
                                       "IC.TAX.PAYM": "Tax payments (number)",
                                       "IC.WRH.DURS": "Time required to build a warehouse (days)",
                                       "IC.LGL.DURS": "Time required to enforce a contract (days)",
                                       "IC.ELC.TIME": "Time required to get electricity (days)",
                                       "IC.PRP.DURS": "Time required to register property (days)",
                                       "IC.REG.DURS": "Time required to start a business (days)",
                                       "IC.TAX.DURS": "Time to prepare and pay taxes (hours)",
                                       "IC.ISV.DURS": "Time to resolve insolvency (years)",
                                       "IC.TAX.TOTL.CP.ZS": "Total tax rate (% of commercial profits)",
                                       "SH.DTH.IMRT": "Number of infant deaths",
                                       "SH.DTH.NMRT": "Number of neonatal deaths",
                                       "SH.DTH.MORT": "Number of under-five deaths",
                                      })

# %%
#exported to csv
renamed.to_csv("Resources/world_data.csv")
renamed
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Switzerland      Western Europe               1            7.587
# 1        Iceland      Western Europe               2            7.561
# 2        Denmark      Western Europe               3            7.527
# 3         Norway      Western Europe               4            7.522
# 4         Canada       North America               5            7.427
# ..           ...                 ...             ...              ...
# 134  Afghanistan       Southern Asia             153            3.575
# 135       Rwanda  Sub-Saharan Africa             154            3.465
# 136        Benin  Sub-Saharan Africa             155            3.340
# 137      Burundi  Sub-Saharan Africa             157            2.905
# 138         Togo  Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# ...
