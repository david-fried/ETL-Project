# %%
import pandas as pd
pd.options.display.max_columns = None
happiness = pd.read_csv('2015 Happiness Data.csv')
wdi = pd.read_csv('wdi_2015.csv')

# %%
print(len(happiness))
happiness.head(3)
# Out:
# 158
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204

# %%
print(len(wdi))
wdi.head(3)
# Out:
# 14762
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB                           Bird species, threatened
# 1  Arab World         ARB  Business extent of disclosure index (0=less di...
# 2  Arab World         ARB  Cost of business start-up procedures (% of GNI...
#
#        IndicatorCode  Year       Value
# 0     EN.BIR.THRD.NO  2015  297.000000
# 1     IC.BUS.DISC.XQ  2015    5.666667
# 2  IC.REG.COST.PC.ZS  2015   31.142857

# %%
print(wdi.IndicatorName.nunique())
print(wdi.IndicatorCode.nunique())
# Out:
# 103
# 103

# %%
x=list(wdi['IndicatorName'].unique())
indicators= [x[0]]
for i in range(1, len(x)-1):
    if x[i+1].split()[0:2] != x[i].split()[0:2]:
        indicators.append(x[i+1])
print(f'approximation of number of indicators: {len(indicators)}')
indicators
# Out:
# approximation of number of indicators: 65
# ['Bird species, threatened',
#  'Cost of business start-up procedures (% of GNI per capita)',
#  'Depth of credit information index (0=low to 8=high)',
#  'Distance to frontier score (0=lowest performance to 100=frontier)',
#  'Ease of doing business index (1=most business-friendly regulations)',
#  'Fish species, threatened',
#  'Improved sanitation facilities (% of population with access)',
#  'Improved water source (% of population with access)',
#  'Labor tax and contributions (% of commercial profits)',
#  'Lifetime risk of maternal death (%)',
#  'Mammal species, threatened',
#  'Maternal mortality ratio (modeled estimate, per 100,000 live births)',
#  'Mortality rate, infant (per 1,000 live births)',
#  'Number of maternal deaths',
#  'Other taxes payable by businesses (% of commercial profits)',
#  'Plant species (higher), threatened',
#  'Private credit bureau coverage (% of adults)',
#  'Procedures to build a warehouse (number)',
#  'Profit tax (% of commercial profits)',
#  'Proportion of seats held by women in national parliaments (%)',
#  'Public credit registry coverage (% of adults)',
#  'Start-up procedures to register a business (number)',
#  'Strength of legal rights index (0=weak to 12=strong)',
#  'Tax payments (number)',
#  'Time required to build a warehouse (days)',
#  'Time to prepare and pay taxes (hours)',
#  'Total tax rate (% of commercial profits)',
#  'Methodology assessment of statistical capacity (scale 0 - 100)',
#  'Overall level of statistical capacity (scale 0 - 100)',
#  'Periodicity and timeliness assessment of statistical capacity (scale 0 - 100)',
#  'Source data assessment of statistical capacity (scale 0 - 100)',
#  'Bank capital to assets ratio (%)',
#  'Bank nonperforming loans to total gross loans (%)',
#  'Disbursements on external debt, long-term (DIS, current US$)',
#  'Interest payments on external debt, long-term (INT, current US$)',
#  'Number of infant deaths',
#  'PPG, bilateral (AMT, current US$)',
#  'PPG, bonds (AMT, current US$)',
#  'PPG, commercial banks (AMT, current US$)',
#  'PPG, multilateral (AMT, current US$)',
#  'PPG, official creditors (AMT, current US$)',
#  'PPG, other private creditors (AMT, current US$)',
#  'PPG, private creditors (AMT, current US$)',
#  'Principal repayments on external debt, long-term (AMT, current US$)',
#  'Average time to clear exports through customs (days)',
#  'Delay in obtaining an electrical connection (days)',
#  'Firms competing against unregistered firms (% of firms)',
#  'Firms expected to give gifts in meetings with tax officials (% of firms)',
#  'Firms formally registered when operations started (% of firms)',
#  'Firms offering formal training (% of firms)',
#  'Firms using banks to finance investment (% of firms)',
#  'Firms with female participation in ownership (% of firms)',
#  'Informal payments to public officials (% of firms)',
#  'Internationally-recognized quality certification (% of firms)',
#  'Losses due to theft, robbery, vandalism, and arson (% sales)',
#  'Number of visits or required meetings with tax officials',
#  'Power outages in firms in a typical month (number)',
#  'Time required to obtain an operating license (days)',
#  'Time spent dealing with the requirements of government regulations (% of senior management time)',
#  'Value lost due to electrical outages (% of sales)',
#  'Poverty gap at national poverty lines (%)',
#  'Poverty headcount ratio at national poverty lines (% of population)',
#  'Rural poverty gap at national poverty lines (%)',
#  'Urban poverty gap at national poverty lines (%)',
#  'Female headed households (% of households with a female head)']

# %%
for items,row in wdi.iterrows():
    print(items, row.IndicatorCode, row.IndicatorName, )
# Out:
# 0 Bird species, threatened EN.BIR.THRD.NO
# 1 Business extent of disclosure index (0=less disclosure to 10=more disclosure) IC.BUS.DISC.XQ
# 2 Cost of business start-up procedures (% of GNI per capita) IC.REG.COST.PC.ZS
# 3 Depth of credit information index (0=low to 8=high) IC.CRD.INFO.XQ
# 4 Distance to frontier score (0=lowest performance to 100=frontier) IC.BUS.DFRN.XQ
# 5 Ease of doing business index (1=most business-friendly regulations) IC.BUS.EASE.XQ
# 6 Fish species, threatened EN.FSH.THRD.NO
# 7 Improved sanitation facilities (% of population with access) SH.STA.ACSN
# 8 Improved sanitation facilities, rural (% of rural population with access) SH.STA.ACSN.RU
# 9 Improved sanitation facilities, urban (% of urban population with access) SH.STA.ACSN.UR
# 10 Improved water source (% of population with access) SH.H2O.SAFE.ZS
# 11 Improved water source, rural (% of rural population with access) SH.H2O.SAFE.RU.ZS
# 12 Improved water source, urban (% of urban population with access) SH.H2O.SAFE.UR.ZS
# 13 Labor tax and contributions (% of commercial profits) IC.TAX.LABR.CP.ZS
# 14 Lifetime risk of maternal death (%) SH.MMR.RISK.ZS
# 15 Lifetime risk of maternal death (1 in: rate varies by country) SH.MMR.RISK
# 16 Mammal species, threatened EN.MAM.THRD.NO
# 17 Maternal mortality ratio (modeled estimate, per 100,000 live births) SH.STA.MMRT
# 18 Mortality rate, infant (per 1,000 live births) SP.DYN.IMRT.IN
# 19 Mortality rate, infant, female (per 1,000 live births) SP.DYN.IMRT.FE.IN
# 20 Mortality rate, infant, male (per 1,000 live births) SP.DYN.IMRT.MA.IN
# 21 Mortality rate, neonatal (per 1,000 live births) SH.DYN.NMRT
# 22 Mortality rate, under-5 (per 1,000) SH.DYN.MORT
# 23 Mortality rate, under-5, female (per 1,000 live births) SH.DYN.MORT.FE
# 24 Mortality rate, under-5, male (per 1,000 live births) SH.DYN.MORT.MA
# 25 Number of maternal deaths SH.MMR.DTHS
# 26 Other taxes payable by businesses (% of commercial profits) IC.TAX.OTHR.CP.ZS
# 27 Plant species (higher), threatened EN.HPT.THRD.NO
# 28 Private credit bureau coverage (% of adults) IC.CRD.PRVT.ZS
# 29 Procedures to build a warehouse (number) IC.WRH.PROC
# 30 Procedures to register property (number) IC.PRP.PROC
# 31 Profit tax (% of commercial profits) IC.TAX.PRFT.CP.ZS
# 32 Proportion of seats held by women in national parliaments (%) SG.GEN.PARL.ZS
# 33 Public credit registry coverage (% of adults) IC.CRD.PUBL.ZS
# 34 Start-up procedures to register a business (number) IC.REG.PROC
# 35 Strength of legal rights index (0=weak to 12=strong) IC.LGL.CRED.XQ
# 36 Tax payments (number) IC.TAX.PAYM
# 37 Time required to build a warehouse (days) IC.WRH.DURS
# 38 Time required to enforce a contract (days) IC.LGL.DURS
# 39 Time required to get electricity (days) IC.ELC.TIME
# 40 Time required to register property (days) IC.PRP.DURS
# 41 Time required to start a business (days) IC.REG.DURS
# 42 Time to prepare and pay taxes (hours) IC.TAX.DURS
# 43 Time to resolve insolvency (years) IC.ISV.DURS
# 44 Total tax rate (% of commercial profits) IC.TAX.TOTL.CP.ZS
# 45 Bird species, threatened EN.BIR.THRD.NO
# 46 Business extent of disclosure index (0=less disclosure to 10=more disclosure) IC.BUS.DISC.XQ
# 47 Cost of business start-up procedures (% of GNI per capita) IC.REG.COST.PC.ZS
# 48 Depth of credit information index (0=low to 8=high) IC.CRD.INFO.XQ
# 49 Distance to frontier score (0=lowest performance to 100=frontier) IC.BUS.DFRN.XQ
# 50 Ease of doing business index (1=most business-friendly regulations) IC.BUS.EASE.XQ
# 51 Fish species, threatened EN.FSH.THRD.NO
# 52 Improved sanitation facilities (% of population with access) SH.STA.ACSN
# 53 Improved sanitation facilities, rural (% of rural population with access) SH.STA.ACSN.RU
# 54 Improved sanitation facilities, urban (% of urban population with access) SH.STA.ACSN.UR
# 55 Improved water source (% of population with access) SH.H2O.SAFE.ZS
# 56 Improved water source, rural (% of rural population with access) SH.H2O.SAFE.RU.ZS
# 57 Improved water source, urban (% of urban population with access) SH.H2O.SAFE.UR.ZS
# 58 Labor tax and contributions (% of commercial profits) IC.TAX.LABR.CP.ZS
# 59 Lifetime risk of maternal death (%) SH.MMR.RISK.ZS
# 60 Lifetime risk of maternal death (1 in: rate varies by country) SH.MMR.RISK
# 61 Mammal species, threatened EN.MAM.THRD.NO
# 62 Maternal mortality ratio (modeled estimate, per 100,000 live births) SH.STA.MMRT
# 63 Methodology assessment of statistical capacity (scale 0 - 100) IQ.SCI.MTHD
# 64 Mortality rate, infant (per 1,000 live births) SP.DYN.IMRT.IN
# 65 Mortality rate, infant, female (per 1,000 live births) SP.DYN.IMRT.FE.IN
# 66 Mortality rate, infant, male (per 1,000 live births) SP.DYN.IMRT.MA.IN
# 67 Mortality rate, neonatal (per 1,000 live births) SH.DYN.NMRT
# 68 Mortality rate, under-5 (per 1,000) SH.DYN.MORT
# 69 Mortality rate, under-5, female (per 1,000 live births) SH.DYN.MORT.FE
# 70 Mortality rate, under-5, male (per 1,000 live births) SH.DYN.MORT.MA
# 71 Number of maternal deaths SH.MMR.DTHS
# 72 Other taxes payable by businesses (% of commercial profits) IC.TAX.OTHR.CP.ZS
# 73 Overall level of statistical capacity (scale 0 - 100) IQ.SCI.OVRL
# 74 Periodicity and timeliness assessment of statistical capacity (scale 0 - 100) IQ.SCI.PRDC
# 75 Plant species (higher), threatened EN.HPT.THRD.NO
# 76 Private credit bureau coverage (% of adults) IC.CRD.PRVT.ZS
# 77 Procedures to build a warehouse (number) IC.WRH.PROC
# 78 Procedures to register property (number) IC.PRP.PROC
# 79 Profit tax (% of commercial profits) IC.TAX.PRFT.CP.ZS
# 80 Proportion of seats held by women in national parliaments (%) SG.GEN.PARL.ZS
# 81 Public credit registry coverage (% of adults) IC.CRD.PUBL.ZS
# 82 Source data assessment of statistical capacity (scale 0 - 100) IQ.SCI.SRCE
# 83 Start-up procedures to register a business (number) IC.REG.PROC
# 84 Strength of legal rights index (0=weak to 12=strong) IC.LGL.CRED.XQ
# 85 Tax payments (number) IC.TAX.PAYM
# 86 Time required to build a warehouse (days) IC.WRH.DURS
# 87 Time required to enforce a contract (days) IC.LGL.DURS
# 88 Time required to get electricity (days) IC.ELC.TIME
# 89 Time required to register property (days) IC.PRP.DURS
# 90 Time required to start a business (days) IC.REG.DURS
# 91 Time to prepare and pay taxes (hours) IC.TAX.DURS
# 92 Time to resolve insolvency (years) IC.ISV.DURS
# 93 Total tax rate (% of commercial profits) IC.TAX.TOTL.CP.ZS
# 94 Bank capital to assets ratio (%) FB.BNK.CAPA.ZS
# 95 Bank nonperforming loans to total gross loans (%) FB.AST.NPER.ZS
# 96 Bird species, threatened EN.BIR.THRD.NO
# 97 Business extent of disclosure index (0=less disclosure to 10=more disclosure) IC.BUS.DISC.XQ
# 98 Cost of business start-up procedures (% of GNI per capita) IC.REG.COST.PC.ZS
# 99 Depth of credit information index (0=low to 8=high) IC.CRD.INFO.XQ
# 100 Distance to frontier score (0=lowest performance to 100=frontier) IC.BUS.DFRN.XQ
# 101 Ease of doing business index (1=most business-friendly regulations) IC.BUS.EASE.XQ
# 102 Fish species, threatened EN.FSH.THRD.NO
# 103 Improved sanitation facilities (% of population with access) SH.STA.ACSN
# 104 Improved sanitation facilities, rural (% of rural population with access) SH.STA.ACSN.RU
# 105 Improved sanitation facilities, urban (% of urban population with access) SH.STA.ACSN.UR
# 106 Improved water source (% of population with access) SH.H2O.SAFE.ZS
# 107 Improved water source, rural (% of rural population with access) SH.H2O.SAFE.RU.ZS
# 108 Improved water source, urban (% of urban population with access) SH.H2O.SAFE.UR.ZS
# 109 Labor tax and contributions (% of commercial profits) IC.TAX.LABR.CP.ZS
# 110 Lifetime risk of maternal death (%) SH.MMR.RISK.ZS
# 111 Lifetime risk of maternal death (1 in: rate varies by country) SH.MMR.RISK
# 112 Mammal species, threatened EN.MAM.THRD.NO
# 113 Maternal mortality ratio (modeled estimate, per 100,000 live births) SH.STA.MMRT
# 114 Mortality rate, infant (per 1,000 live births) SP.DYN.IMRT.IN
# 115 Mortality rate, infant, female (per 1,000 live births) SP.DYN.IMRT.FE.IN
# 116 Mortality rate, infant, male (per 1,000 live births) SP.DYN.IMRT.MA.IN
# 117 Mortality rate, neonatal (per 1,000 live births) SH.DYN.NMRT
# 118 Mortality rate, under-5 (per 1,000) SH.DYN.MORT
# 119 Mortality rate, under-5, female (per 1,000 live births) SH.DYN.MORT.FE
# 120 Mortality rate, under-5, male (per 1,000 live births) SH.DYN.MORT.MA
# 121 Number of maternal deaths SH.MMR.DTHS
# 122 Other taxes payable by businesses (% of commercial profits) IC.TAX.OTHR.CP.ZS
# 123 Plant species (higher), threatened EN.HPT.THRD.NO
# 124 Private credit bureau coverage (% of adults) IC.CRD.PRVT.ZS
# 125 Procedures to build a warehouse (number) IC.WRH.PROC
# 126 Procedures to register property (number) IC.PRP.PROC
# 127 Profit tax (% of commercial profits) IC.TAX.PRFT.CP.ZS
# 128 Proportion of seats held by women in national parliaments (%) SG.GEN.PARL.ZS
# 129 Public credit registry coverage (% of adults) IC.CRD.PUBL.ZS
# 130 Start-up procedures to register a business (number) IC.REG.PROC
# 131 Strength of legal rights index (0=weak to 12=strong) IC.LGL.CRED.XQ
# 132 Tax payments (number) IC.TAX.PAYM
# 133 Time required to build a warehouse (days) IC.WRH.DURS
# 134 Time required to enforce a contract (days) IC.LGL.DURS
# 135 Time required to get electricity (days) IC.ELC.TIME
# 136 Time required to register property (days) IC.PRP.DURS
# 137 Time required to start a business (days) IC.REG.DURS
# 138 Time to prepare and pay taxes (hours) IC.TAX.DURS
# 139 Time to resolve insolvency (years) IC.ISV.DURS
# 140 Total tax rate (% of commercial profits) IC.TAX.TOTL.CP.ZS
# 141 Bird species, threatened EN.BIR.THRD.NO
# 142 Business extent of disclosure index (0=less disclosure to 10=more disclosure) IC.BUS.DISC.XQ
# 143 Cost of business start-up procedures (% of GNI per capita) IC.REG.COST.PC.ZS
# 144 Depth of credit information index (0=low to 8=high) IC.CRD.INFO.XQ
# 145 Distance to frontier score (0=lowest performance to 100=frontier) IC.BUS.DFRN.XQ
# 146 Ease of doing business index (1=most business-friendly regulations) IC.BUS.EASE.XQ
# 147 Fish species, threatened EN.FSH.THRD.NO
# 148 Improved sanitation facilities (% of population with access) SH.STA.ACSN
# 149 Improved sanitation facilities, rural (% of rural population with access) SH.STA.ACSN.RU
# 150 Improved sanitation facilities, urban (% of urban population with access) SH.STA.ACSN.UR
# 151 Improved water source (% of population with access) SH.H2O.SAFE.ZS
# 152 Improved water source, rural (% of rural population with access) SH.H2O.SAFE.RU.ZS
# 153 Improved water source, urban (% of urban population with access) SH.H2O.SAFE.UR.ZS
# 154 Labor tax and contributions (% of commercial profits) IC.TAX.LABR.CP.ZS
# 155 Lifetime risk of maternal death (%) SH.MMR.RISK.ZS
# 156 Lifetime risk of maternal death (1 in: rate varies by country) SH.MMR.RISK
# 157 Mammal species, threatened EN.MAM.THRD.NO
# 158 Maternal mortality ratio (modeled estimate, per 100,000 live births) SH.STA.MMRT
# 159 Mortality rate, infant (per 1,000 live births) SP.DYN.IMRT.IN
# 160 Mortality rate, infant, female (per 1,000 live births) SP.DYN.IMRT.FE.IN
# 161 Mortality rate, infant, male (per 1,000 live births) SP.DYN.IMRT.MA.IN
# 162 Mortality rate, neonatal (per 1,000 live births) SH.DYN.NMRT
# 163 Mortality rate, under-5 (per 1,000) SH.DYN.MORT
# 164 Mortality rate, under-5, female (per 1,000 live births) SH.DYN.MORT.FE
# 165 Mortality rate, under-5, male (per 1,000 live births) SH.DYN.MORT.MA
# 166 Number of maternal deaths SH.MMR.DTHS
# 167 Other taxes payable by businesses (% of commercial profits) IC.TAX.OTHR.CP.ZS
# 168 Plant species (higher), threatened EN.HPT.THRD.NO
# 169 Private credit bureau coverage (% of adults) IC.CRD.PRVT.ZS
# 170 Procedures to build a warehouse (number) IC.WRH.PROC
# 171 Procedures to register property (number) IC.PRP.PROC
# 172 Profit tax (% of commercial profits) IC.TAX.PRFT.CP.ZS
# 173 Proportion of seats held by women in national parliaments (%) SG.GEN.PARL.ZS
# 174 Public credit registry coverage (% of adults) IC.CRD.PUBL.ZS
# 175 Start-up procedures to register a business (number) IC.REG.PROC
# 176 Strength of legal rights index (0=weak to 12=strong) IC.LGL.CRED.XQ
# 177 Tax payments (number) IC.TAX.PAYM
# 178 Time required to build a warehouse (days) IC.WRH.DURS
# 179 Time required to enforce a contract (days) IC.LGL.DURS
# 180 Time required to get electricity (days) IC.ELC.TIME
# 181 Time required to register property (days) IC.PRP.DURS
# 182 Time required to start a business (days) IC.REG.DURS
# 183 Time to prepare and pay taxes (hours) IC.TAX.DURS
# 184 Time to resolve insolvency (years) IC.ISV.DURS
# 185 Total tax rate (% of commercial profits) IC.TAX.TOTL.CP.ZS
# 186 Bird species, threatened EN.BIR.THRD.NO
# 187 Business extent of disclosure index (0=less disclosure to 10=more disclosure) IC.BUS.DISC.XQ
# 188 Cost of business start-up procedures (% of GNI per capita) IC.REG.COST.PC.ZS
# 189 Depth of credit information index (0=low to 8=high) IC.CRD.INFO.XQ
# 190 Disbursements on external debt, long-term (DIS, current US$) DT.DIS.DLXF.CD
# 191 Distance to frontier score (0=lowest performance to 100=frontier) IC.BUS.DFRN.XQ
# 192 Ease of doing business index (1=most business-friendly regulations) IC.BUS.EASE.XQ
# 193 Fish species, threatened EN.FSH.THRD.NO
# 194 Improved sanitation facilities (% of population with access) SH.STA.ACSN
# 195 Improved sanitation facilities, rural (% of rural population with access) SH.STA.ACSN.RU
# 196 Improved sanitation facilities, urban (% of urban population with access) SH.STA.ACSN.UR
# 197 Improved water source (% of population with access) SH.H2O.SAFE.ZS
# 198 Improved water source, rural (% of rural population with access) SH.H2O.SAFE.RU.ZS
# 199 Improved water source, urban (% of urban population with access) SH.H2O.SAFE.UR.ZS
# 200 Interest payments on external debt, long-term (INT, current US$) DT.INT.DLXF.CD
# 201 Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$) DT.INT.DPNG.CD
# 202 Labor tax and contributions (% of commercial profits) IC.TAX.LABR.CP.ZS
# 203 Lifetime risk of maternal death (%) SH.MMR.RISK.ZS
# 204 Lifetime risk of maternal death (1 in: rate varies by country) SH.MMR.RISK
# 205 Mammal species, threatened EN.MAM.THRD.NO
# 206 Maternal mortality ratio (modeled estimate, per 100,000 live births) SH.STA.MMRT
# 207 Methodology assessment of statistical capacity (scale 0 - 100) IQ.SCI.MTHD
# 208 Mortality rate, infant (per 1,000 live births) SP.DYN.IMRT.IN
# 209 Mortality rate, infant, female (per 1,000 live births) SP.DYN.IMRT.FE.IN
# 210 Mortality rate, infant, male (per 1,000 live births) SP.DYN.IMRT.MA.IN
# 211 Mortality rate, neonatal (per 1,000 live births) SH.DYN.NMRT
# 212 Mortality rate, under-5 (per 1,000) SH.DYN.MORT
# 213 Mortality rate, under-5, female (per 1,000 live births) SH.DYN.MORT.FE
# 214 Mortality rate, under-5, male (per 1,000 live births) SH.DYN.MORT.MA
# 215 Number of infant deaths SH.DTH.IMRT
# 216 Number of maternal deaths SH.MMR.DTHS
# 217 Number of neonatal deaths SH.DTH.NMRT
# 218 Number of under-five deaths SH.DTH.MORT
# 219 Other taxes payable by businesses (% of commercial profits) IC.TAX.OTHR.CP.ZS
# 220 Overall level of statistical capacity (scale 0 - 100) IQ.SCI.OVRL
# 221 Periodicity and timeliness assessment of statistical capacity (scale 0 - 100) IQ.SCI.PRDC
# 222 Plant species (higher), threatened EN.HPT.THRD.NO
# 223 PPG, bilateral (AMT, current US$) DT.AMT.BLAT.CD
# 224 PPG, bilateral (DIS, current US$) DT.DIS.BLAT.CD
# 225 PPG, bilateral (INT, current US$) DT.INT.BLAT.CD
# 226 PPG, bonds (AMT, current US$) DT.AMT.PBND.CD
# 227 PPG, bonds (INT, current US$) DT.INT.PBND.CD
# 228 PPG, commercial banks (AMT, current US$) DT.AMT.PCBK.CD
# 229 PPG, commercial banks (DIS, current US$) DT.DIS.PCBK.CD
# 230 PPG, commercial banks (INT, current US$) DT.INT.PCBK.CD
# 231 PPG, multilateral (AMT, current US$) DT.AMT.MLAT.CD
# 232 PPG, multilateral (DIS, current US$) DT.DIS.MLAT.CD
# 233 PPG, multilateral (INT, current US$) DT.INT.MLAT.CD
# 234 PPG, official creditors (AMT, current US$) DT.AMT.OFFT.CD
# 235 PPG, official creditors (DIS, current US$) DT.DIS.OFFT.CD
# 236 PPG, official creditors (INT, current US$) DT.INT.OFFT.CD
# 237 PPG, other private creditors (AMT, current US$) DT.AMT.PROP.CD
# 238 PPG, other private creditors (DIS, current US$) DT.DIS.PROP.CD
# 239 PPG, other private creditors (INT, current US$) DT.INT.PROP.CD
# 240 PPG, private creditors (AMT, current US$) DT.AMT.PRVT.CD
# 241 PPG, private creditors (DIS, current US$) DT.DIS.PRVT.CD
# 242 PPG, private creditors (INT, current US$) DT.INT.PRVT.CD
# 243 Principal repayments on external debt, long-term (AMT, current US$) DT.AMT.DLXF.CD
# 244 Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$) DT.AMT.DPNG.CD
# 245 Private credit bureau coverage (% of adults) IC.CRD.PRVT.ZS
# 246 Procedures to build a warehouse (number) IC.WRH.PROC
# 247 Procedures to register property (number) IC.PRP.PROC
# 248 Profit tax (% of commercial profits) IC.TAX.PRFT.CP.ZS
# 249 Proportion of seats held by women in national parliaments (%) SG.GEN.PARL.ZS
# 250 Public credit registry coverage (% of adults) IC.CRD.PUBL.ZS
# 251 Source data assessment of statistical capacity (scale 0 - 100) IQ.SCI.SRCE
# 252 Start-up procedures to register a business (number) IC.REG.PROC
# 253 Strength of legal rights index (0=weak to 12=strong) IC.LGL.CRED.XQ
# 254 Tax payments (number) IC.TAX.PAYM
# 255 Time required to build a warehouse (days) IC.WRH.DURS
# 256 Time required to enforce a contract (days) IC.LGL.DURS
# 257 Time required to get electricity (days) IC.ELC.TIME
# 258 Time required to register property (days) IC.PRP.DURS
# 259 Time required to start a business (days) IC.REG.DURS
# 260 Time to prepare and pay taxes (hours) IC.TAX.DURS
# 261 Time to resolve insolvency (years) IC.ISV.DURS
# 262 Total tax rate (% of commercial profits) IC.TAX.TOTL.CP.ZS
# 263 Bank capital to assets ratio (%) FB.BNK.CAPA.ZS
# 264 Bank nonperforming loans to total gross loans (%) FB.AST.NPER.ZS
# 265 Bird species, threatened EN.BIR.THRD.NO
# 266 Business extent of disclosure index (0=less disclosure to 10=more disclosure) IC.BUS.DISC.XQ
# 267 Cost of business start-up procedures (% of GNI per capita) IC.REG.COST.PC.ZS
# 268 Depth of credit information index (0=low to 8=high) IC.CRD.INFO.XQ
# 269 Distance to frontier score (0=lowest performance to 100=frontier) IC.BUS.DFRN.XQ
# 270 Ease of doing business index (1=most business-friendly regulations) IC.BUS.EASE.XQ
# 271 Fish species, threatened EN.FSH.THRD.NO
# 272 Improved sanitation facilities (% of population with access) SH.STA.ACSN
# 273 Improved sanitation facilities, rural (% of rural population with access) SH.STA.ACSN.RU
# 274 Improved sanitation facilities, urban (% of urban population with access) SH.STA.ACSN.UR
# 275 Improved water source (% of population with access) SH.H2O.SAFE.ZS
# 276 Improved water source, rural (% of rural population with access) SH.H2O.SAFE.RU.ZS
# 277 Improved water source, urban (% of urban population with access) SH.H2O.SAFE.UR.ZS
# 278 Labor tax and contributions (% of commercial profits) IC.TAX.LABR.CP.ZS
# 279 Lifetime risk of maternal death (%) SH.MMR.RISK.ZS
# 280 Lifetime risk of maternal death (1 in: rate varies by country) SH.MMR.RISK
# 281 Mammal species, threatened EN.MAM.THRD.NO
# 282 Maternal mortality ratio (modeled estimate, per 100,000 live births) SH.STA.MMRT
# 283 Mortality rate, infant (per 1,000 live births) SP.DYN.IMRT.IN
# 284 Mortality rate, infant, female (per 1,000 live births) SP.DYN.IMRT.FE.IN
# 285 Mortality rate, infant, male (per 1,000 live births) SP.DYN.IMRT.MA.IN
# 286 Mortality rate, neonatal (per 1,000 live births) SH.DYN.NMRT
# 287 Mortality rate, under-5 (per 1,000) SH.DYN.MORT
# 288 Mortality rate, under-5, female (per 1,000 live births) SH.DYN.MORT.FE
# 289 Mortality rate, under-5, male (per 1,000 live births) SH.DYN.MORT.MA
# 290 Number of maternal deaths SH.MMR.DTHS
# 291 Other taxes payable by businesses (% of commercial profits) IC.TAX.OTHR.CP.ZS
# 292 Plant species (higher), threatened EN.HPT.THRD.NO
# 293 Private credit bureau coverage (% of adults) IC.CRD.PRVT.ZS
# 294 Procedures to build a warehouse (number) IC.WRH.PROC
# 295 Procedures to register property (number) IC.PRP.PROC
# 296 Profit tax (% of commercial profits) IC.TAX.PRFT.CP.ZS
# 297 Proportion of seats held by women in national parliaments (%) SG.GEN.PARL.ZS
# 298 Public credit registry coverage (% of adults) IC.CRD.PUBL.ZS
# 299 Start-up procedures to register a business (number) IC.REG.PROC
# 300 Strength of legal rights index (0=weak to 12=strong) IC.LGL.CRED.XQ
# 301 Tax payments (number) IC.TAX.PAYM
# 302 Time required to build a warehouse (days) IC.WRH.DURS
# 303 Time required to enforce a contract (days) IC.LGL.DURS
# 304 Time required to get electricity (days) IC.ELC.TIME
# 305 Time required to register property (days) IC.PRP.DURS
# 306 Time required to start a business (days) IC.REG.DURS
# 307 Time to prepare and pay taxes (hours) IC.TAX.DURS
# 308 Time to resolve insolvency (years) IC.ISV.DURS
# 309 Total tax rate (% of commercial profits) IC.TAX.TOTL.CP.ZS
# 310 Bank capital to assets ratio (%) FB.BNK.CAPA.ZS
# 311 Bank nonperforming loans to total gross loans (%) FB.AST.NPER.ZS
# 312 Bird species, threatened EN.BIR.THRD.NO
# 313 Business extent of disclosure index (0=less disclosure to 10=more disclosure) IC.BUS.DISC.XQ
# 314 Cost of business start-up procedures (% of GNI per capita) IC.REG.COST.PC.ZS
# 315 Depth of credit information index (0=low to 8=high) IC.CRD.INFO.XQ
# 316 Distance to frontier score (0=lowest performance to 100=frontier) IC.BUS.DFRN.XQ
# 317 Ease of doing business index (1=most business-friendly regulations) IC.BUS.EASE.XQ
# 318 Fish species, threatened EN.FSH.THRD.NO
# 319 Improved sanitation facilities (% of population with access) SH.STA.ACSN
# 320 Improved sanitation facilities, rural (% of rural population with access) SH.STA.ACSN.RU
# 321 Improved sanitation facilities, urban (% of urban population with access) SH.STA.ACSN.UR
# 322 Improved water source (% of population with access) SH.H2O.SAFE.ZS
# 323 Improved water source, rural (% of rural population with access) SH.H2O.SAFE.RU.ZS
# 324 Improved water source, urban (% of urban population with access) SH.H2O.SAFE.UR.ZS
# 325 Labor tax and contributions (% of commercial profits) IC.TAX.LABR.CP.ZS
# 326 Lifetime risk of maternal death (%) SH.MMR.RISK.ZS
# 327 Lifetime risk of maternal death (1 in: rate varies by country) SH.MMR.RISK
# 328 Mammal species, threatened EN.MAM.THRD.NO
# 329 Maternal mortality ratio (modeled estimate, per 100,000 live births) SH.STA.MMRT
# 330 Mortality rate, infant (per 1,000 live births) SP.DYN.IMRT.IN
# 331 Mortality rate, infant, female (per 1,000 live births) SP.DYN.IMRT.FE.IN
# 332 Mortality rate, infant, male (per 1,000 live births) SP.DYN.IMRT.MA.IN
# 333 Mortality rate, neonatal (per 1,000 live births) SH.DYN.NMRT
# 334 Mortality rate, under-5 (per 1,000) SH.DYN.MORT
# 335 Mortality rate, under-5, female (per 1,000 live births) SH.DYN.MORT.FE
# 336 Mortality rate, under-5, male (per 1,000 live births) SH.DYN.MORT.MA
# 337 Number of maternal deaths SH.MMR.DTHS
# 338 Other taxes payable by businesses (% of commercial profits) IC.TAX.OTHR.CP.ZS
# 339 Plant species (higher), threatened EN.HPT.THRD.NO
# 340 Private credit bureau coverage (% of adults) IC.CRD.PRVT.ZS
# 341 Procedures to build a warehouse (number) IC.WRH.PROC
# 342 Procedures to register property (number) IC.PRP.PROC
# 343 Profit tax (% of commercial profits) IC.TAX.PRFT.CP.ZS
# 344 Proportion of seats held by women in national parliaments (%) SG.GEN.PARL.ZS
# 345 Public credit registry coverage (% of adults) IC.CRD.PUBL.ZS
# 346 Start-up procedures to register a business (number) IC.REG.PROC
# 347 Strength of legal rights index (0=weak to 12=strong) IC.LGL.CRED.XQ
# 348 Tax payments (number) IC.TAX.PAYM
# 349 Time required to build a warehouse (days) IC.WRH.DURS
# 350 Time required to enforce a contract (days) IC.LGL.DURS
# 351 Time required to get electricity (days) IC.ELC.TIME
# 352 Time required to register property (days) IC.PRP.DURS
# 353 Time required to start a business (days) IC.REG.DURS
# 354 Time to prepare and pay taxes (hours) IC.TAX.DURS
# 355 Time to resolve insolvency (years) IC.ISV.DURS
# 356 Total tax rate (% of commercial profits) IC.TAX.TOTL.CP.ZS
# 357 Bank capital to assets ratio (%) FB.BNK.CAPA.ZS
# 358 Bank nonperforming loans to total gross loans (%) FB.AST.NPER.ZS
# 359 Bird species, threatened EN.BIR.THRD.NO
# 360 Business extent of disclosure index (0=less disclosure to 10=more disclosure) IC.BUS.DISC.XQ
# 361 Cost of business start-up procedures (% of GNI per capita) IC.REG.COST.PC.ZS
# 362 Depth of credit information index (0=low to 8=high) IC.CRD.INFO.XQ
# 363 Disbursements on external debt, long-term (DIS, current US$) DT.DIS.DLXF.CD
# 364 Distance to frontier score (0=lowest performance to 100=frontier) IC.BUS.DFRN.XQ
# 365 Ease of doing business index (1=most business-friendly regulations) IC.BUS.EASE.XQ
# 366 Fish species, threatened EN.FSH.THRD.NO
# 367 Improved sanitation facilities (% of population with access) SH.STA.ACSN
# 368 Improved sanitation facilities, rural (% of rural population with access) SH.STA.ACSN.RU
# 369 Improved sanitation facilities, urban (% of urban population with access) SH.STA.ACSN.UR
# 370 Improved water source (% of population with access) SH.H2O.SAFE.ZS
# 371 Improved water source, rural (% of rural population with access) SH.H2O.SAFE.RU.ZS
# 372 Improved water source, urban (% of urban population with access) SH.H2O.SAFE.UR.ZS
# 373 Interest payments on external debt, long-term (INT, current US$) DT.INT.DLXF.CD
# 374 Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$) DT.INT.DPNG.CD
# 375 Labor tax and contributions (% of commercial profits) IC.TAX.LABR.CP.ZS
# 376 Lifetime risk of maternal death (%) SH.MMR.RISK.ZS
# 377 Lifetime risk of maternal death (1 in: rate varies by country) SH.MMR.RISK
# 378 Mammal species, threatened EN.MAM.THRD.NO
# 379 Maternal mortality ratio (modeled estimate, per 100,000 live births) SH.STA.MMRT
# 380 Methodology assessment of statistical capacity (scale 0 - 100) IQ.SCI.MTHD
# 381 Mortality rate, infant (per 1,000 live births) SP.DYN.IMRT.IN
# 382 Mortality rate, infant, female (per 1,000 live births) SP.DYN.IMRT.FE.IN
# 383 Mortality rate, infant, male (per 1,000 live births) SP.DYN.IMRT.MA.IN
# 384 Mortality rate, neonatal (per 1,000 live births) SH.DYN.NMRT
# 385 Mortality rate, under-5 (per 1,000) SH.DYN.MORT
# 386 Mortality rate, under-5, female (per 1,000 live births) SH.DYN.MORT.FE
# 387 Mortality rate, under-5, male (per 1,000 live births) SH.DYN.MORT.MA
# 388 Number of infant deaths SH.DTH.IMRT
# 389 Number of maternal deaths SH.MMR.DTHS
# 390 Number of neonatal deaths SH.DTH.NMRT
# 391 Number of under-five deaths SH.DTH.MORT
# 392 Other taxes payable by businesses (% of commercial profits) IC.TAX.OTHR.CP.ZS
# 393 Overall level of statistical capacity (scale 0 - 100) IQ.SCI.OVRL
# 394 Periodicity and timeliness assessment of statistical capacity (scale 0 - 100) IQ.SCI.PRDC
# 395 Plant species (higher), threatened EN.HPT.THRD.NO
# 396 PPG, bilateral (AMT, current US$) DT.AMT.BLAT.CD
# 397 PPG, bilateral (DIS, current US$) DT.DIS.BLAT.CD
# 398 PPG, bilateral (INT, current US$) DT.INT.BLAT.CD
# 399 PPG, bonds (AMT, current US$) DT.AMT.PBND.CD
# 400 PPG, bonds (INT, current US$) DT.INT.PBND.CD
# 401 PPG, commercial banks (AMT, current US$) DT.AMT.PCBK.CD
# 402 PPG, commercial banks (DIS, current US$) DT.DIS.PCBK.CD
# 403 PPG, commercial banks (INT, current US$) DT.INT.PCBK.CD
# 404 PPG, multilateral (AMT, current US$) DT.AMT.MLAT.CD
# 405 PPG, multilateral (DIS, current US$) DT.DIS.MLAT.CD
# 406 PPG, multilateral (INT, current US$) DT.INT.MLAT.CD
# 407 PPG, official creditors (AMT, current US$) DT.AMT.OFFT.CD
# 408 PPG, official creditors (DIS, current US$) DT.DIS.OFFT.CD
# 409 PPG, official creditors (INT, current US$) DT.INT.OFFT.CD
# 410 PPG, other private creditors (AMT, current US$) DT.AMT.PROP.CD
# 411 PPG, other private creditors (DIS, current US$) DT.DIS.PROP.CD
# 412 PPG, other private creditors (INT, current US$) DT.INT.PROP.CD
# 413 PPG, private creditors (AMT, current US$) DT.AMT.PRVT.CD
# 414 PPG, private creditors (DIS, current US$) DT.DIS.PRVT.CD
# 415 PPG, private creditors (INT, current US$) DT.INT.PRVT.CD
# 416 Principal repayments on external debt, long-term (AMT, current US$) DT.AMT.DLXF.CD
# 417 Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$) DT.AMT.DPNG.CD
# 418 Private credit bureau coverage (% of adults) IC.CRD.PRVT.ZS
# 419 Procedures to build a warehouse (number) IC.WRH.PROC
# 420 Procedures to register property (number) IC.PRP.PROC
# 421 Profit tax (% of commercial profits) IC.TAX.PRFT.CP.ZS
# 422 Proportion of seats held by women in national parliaments (%) SG.GEN.PARL.ZS
# 423 Public credit registry coverage (% of adults) IC.CRD.PUBL.ZS
# 424 Source data assessment of statistical capacity (scale 0 - 100) IQ.SCI.SRCE
# 425 Start-up procedures to register a business (number) IC.REG.PROC
# 426 Strength of legal rights index (0=weak to 12=strong) IC.LGL.CRED.XQ
# 427 Tax payments (number) IC.TAX.PAYM
# 428 Time required to build a warehouse (days) IC.WRH.DURS
# 429 Time required to enforce a contract (days) IC.LGL.DURS
# 430 Time required to get electricity (days) IC.ELC.TIME
# 431 Time required to register property (days) IC.PRP.DURS
# 432 Time required to start a business (days) IC.REG.DURS
# 433 Time to prepare and pay taxes (hours) IC.TAX.DURS
# 434 Time to resolve insolvency (years) IC.ISV.DURS
# 435 Total tax rate (% of commercial profits) IC.TAX.TOTL.CP.ZS
# 436 Bank capital to assets ratio (%) FB.BNK.CAPA.ZS
# 437 Bank nonperforming loans to total gross loans (%) FB.AST.NPER.ZS
# 438 Bird species, threatened EN.BIR.THRD.NO
# 439 Business extent of disclosure index (0=less disclosure to 10=more disclosure) IC.BUS.DISC.XQ
# 440 Cost of business start-up procedures (% of GNI per capita) IC.REG.COST.PC.ZS
# 441 Depth of credit information index (0=low to 8=high) IC.CRD.INFO.XQ
# 442 Distance to frontier score (0=lowest performance to 100=frontier) IC.BUS.DFRN.XQ
# 443 Ease of doing business index (1=most business-friendly regulations) IC.BUS.EASE.XQ
# 444 Fish species, threatened EN.FSH.THRD.NO
# 445 Improved sanitation facilities (% of population with access) SH.STA.ACSN
# 446 Improved sanitation facilities, rural (% of rural population with access) SH.STA.ACSN.RU
# 447 Improved sanitation facilities, urban (% of urban population with access) SH.STA.ACSN.UR
# 448 Improved water source (% of population with access) SH.H2O.SAFE.ZS
# 449 Improved water source, rural (% of rural population with access) SH.H2O.SAFE.RU.ZS
# 450 Improved water source, urban (% of urban population with access) SH.H2O.SAFE.UR.ZS
# 451 Labor tax and contributions (% of commercial profits) IC.TAX.LABR.CP.ZS
# 452 Lifetime risk of maternal death (%) SH.MMR.RISK.ZS
# 453 Lifetime risk of maternal death (1 in: rate varies by country) SH.MMR.RISK
# 454 Mammal species, threatened EN.MAM.THRD.NO
# 455 Maternal mortality ratio (modeled estimate, per 100,000 live births) SH.STA.MMRT
# 456 Mortality rate, infant (per 1,000 live births) SP.DYN.IMRT.IN
# 457 Mortality rate, infant, female (per 1,000 live births) SP.DYN.IMRT.FE.IN
# 458 Mortality rate, infant, male (per 1,000 live births) SP.DYN.IMRT.MA.IN
# 459 Mortality rate, neonatal (per 1,000 live births) SH.DYN.NMRT
# 460 Mortality rate, under-5 (per 1,000) SH.DYN.MORT
# 461 Mortality rate, under-5, female (per 1,000 live births) SH.DYN.MORT.FE
# 462 Mortality rate, under-5, male (per 1,000 live births) SH.DYN.MORT.MA
# 463 Number of maternal deaths SH.MMR.DTHS
# 464 Other taxes payable by businesses (% of commercial profits) IC.TAX.OTHR.CP.ZS
# 465 Plant species (higher), threatened EN.HPT.THRD.NO
# 466 Private credit bureau coverage (% of adults) IC.CRD.PRVT.ZS
# 467 Procedures to build a warehouse (number) IC.WRH.PROC
# 468 Procedures to register property (number) IC.PRP.PROC
# 469 Profit tax (% of commercial profits) IC.TAX.PRFT.CP.ZS
# 470 Proportion of seats held by women in national parliaments (%) SG.GEN.PARL.ZS
# 471 Public credit registry coverage (% of adults) IC.CRD.PUBL.ZS
# 472 Start-up procedures to register a business (number) IC.REG.PROC
# 473 Strength of legal rights index (0=weak to 12=strong) IC.LGL.CRED.XQ
# 474 Tax payments (number) IC.TAX.PAYM
# 475 Time required to build a warehouse (days) IC.WRH.DURS
# 476 Time required to enforce a contract (days) IC.LGL.DURS
# 477 Time required to get electricity (days) IC.ELC.TIME
# 478 Time required to register property (days) IC.PRP.DURS
# 479 Time required to start a business (days) IC.REG.DURS
# 480 Time to prepare and pay taxes (hours) IC.TAX.DURS
# 481 Time to resolve insolvency (years) IC.ISV.DURS
# 482 Total tax rate (% of commercial profits) IC.TAX.TOTL.CP.ZS
# 483 Bird species, threatened EN.BIR.THRD.NO
# 484 Business extent of disclosure index (0=less disclosure to 10=more disclosure) IC.BUS.DISC.XQ
# 485 Cost of business start-up procedures (% of GNI per capita) IC.REG.COST.PC.ZS
# 486 Depth of credit information index (0=low to 8=high) IC.CRD.INFO.XQ
# 487 Distance to frontier score (0=lowest performance to 100=frontier) IC.BUS.DFRN.XQ
# 488 Ease of doing business index (1=most business-friendly regulations) IC.BUS.EASE.XQ
# 489 Fish species, threatened EN.FSH.THRD.NO
# 490 Improved sanitation facilities (% of population with access) SH.STA.ACSN
# 491 Improved sanitation facilities, rural (% of rural population with access) SH.STA.ACSN.RU
# 492 Improved sanitation facilities, urban (% of urban population with access) SH.STA.ACSN.UR
# 493 Improved water source (% of population with access) SH.H2O.SAFE.ZS
# 494 Improved water source, rural (% of rural population with access) SH.H2O.SAFE.RU.ZS
# 495 Improved water source, urban (% of urban population with access) SH.H2O.SAFE.UR.ZS
# 496 Labor tax and contributions (% of commercial profits) IC.TAX.LABR.CP.ZS
# 497 Lifetime risk of maternal death (%) SH.MMR.RISK.ZS
# 498 Lifetime risk of maternal death (1 in: rate varies by country) SH.MMR.RISK
# 499 Mammal species, threatened EN.MAM.THRD.NO
# 500 Maternal mortality ratio (modeled estimate, per 100,000 live births) SH.STA.MMRT
# 501 Methodology assessment of statistical capacity (scale 0 - 100) IQ.SCI.MTHD
# 502 Mortality rate, infant (per 1,000 live births) SP.DYN.IMRT.IN
# 503 Mortality rate, infant, female (per 1,000 live births) SP.DYN.IMRT.FE.IN
# 504 Mortality rate, infant, male (per 1,000 live births) SP.DYN.IMRT.MA.IN
# 505 Mortality rate, neonatal (per 1,000 live births) SH.DYN.NMRT
# 506 Mortality rate, under-5 (per 1,000) SH.DYN.MORT
# 507 Mortality rate, under-5, female (per 1,000 live births) SH.DYN.MORT.FE
# 508 Mortality rate, under-5, male (per 1,000 live births) SH.DYN.MORT.MA
# 509 Number of maternal deaths SH.MMR.DTHS
# 510 Other taxes payable by businesses (% of commercial profits) IC.TAX.OTHR.CP.ZS
# 511 Overall level of statistical capacity (scale 0 - 100) IQ.SCI.OVRL
# 512 Periodicity and timeliness assessment of statistical capacity (scale 0 - 100) IQ.SCI.PRDC
# 513 Plant species (higher), threatened EN.HPT.THRD.NO
# 514 Private credit bureau coverage (% of adults) IC.CRD.PRVT.ZS
# 515 Procedures to build a warehouse (number) IC.WRH.PROC
# 516 Procedures to register property (number) IC.PRP.PROC
# 517 Profit tax (% of commercial profits) IC.TAX.PRFT.CP.ZS
# 518 Proportion of seats held by women in national parliaments (%) SG.GEN.PARL.ZS
# 519 Public credit registry coverage (% of adults) IC.CRD.PUBL.ZS
# 520 Source data assessment of statistical capacity (scale 0 - 100) IQ.SCI.SRCE
# 521 Start-up procedures to register a business (number) IC.REG.PROC
# 522 Strength of legal rights index (0=weak to 12=strong) IC.LGL.CRED.XQ
# 523 Tax payments (number) IC.TAX.PAYM
# 524 Time required to build a warehouse (days) IC.WRH.DURS
# 525 Time required to enforce a contract (days) IC.LGL.DURS
# 526 Time required to get electricity (days) IC.ELC.TIME
# 527 Time required to register property (days) IC.PRP.DURS
# 528 Time required to start a business (days) IC.REG.DURS
# 529 Time to prepare and pay taxes (hours) IC.TAX.DURS
# 530 Time to resolve insolvency (years) IC.ISV.DURS
# 531 Total tax rate (% of commercial profits) IC.TAX.TOTL.CP.ZS
# 532 Bird species, threatened EN.BIR.THRD.NO
# 533 Business extent of disclosure index (0=less disclosure to 10=more disclosure) IC.BUS.DISC.XQ
# 534 Cost of business start-up procedures (% of GNI per capita) IC.REG.COST.PC.ZS
# 535 Depth of credit information index (0=low to 8=high) IC.CRD.INFO.XQ
# 536 Distance to frontier score (0=lowest performance to 100=frontier) IC.BUS.DFRN.XQ
# 537 Ease of doing business index (1=most business-friendly regulations) IC.BUS.EASE.XQ
# 538 Fish species, threatened EN.FSH.THRD.NO
# 539 Improved sanitation facilities (% of population with access) SH.STA.ACSN
# 540 Improved sanitation facilities, rural (% of rural population with access) SH.STA.ACSN.RU
# 541 Improved sanitation facilities, urban (% of urban population with access) SH.STA.ACSN.UR
# 542 Improved water source (% of population with access) SH.H2O.SAFE.ZS
# 543 Improved water source, rural (% of rural population with access) SH.H2O.SAFE.RU.ZS
# 544 Improved water source, urban (% of urban population with access) SH.H2O.SAFE.UR.ZS
# 545 Labor tax and contributions (% of commercial profits) IC.TAX.LABR.CP.ZS
# 546 Lifetime risk of maternal death (%) SH.MMR.RISK.ZS
# 547 Lifetime risk of maternal death (1 in: rate varies by country) SH.MMR.RISK
# 548 Mammal species, threatened EN.MAM.THRD.NO
# 549 Maternal mortality ratio (modeled estimate, per 100,000 live births) SH.STA.MMRT
# 550 Methodology assessment of statistical capacity (scale 0 - 100) IQ.SCI.MTHD
# 551 Mortality rate, infant (per 1,000 live births) SP.DYN.IMRT.IN
# 552 Mortality rate, infant, female (per 1,000 live births) SP.DYN.IMRT.FE.IN
# 553 Mortality rate, infant, male (per 1,000 live births) SP.DYN.IMRT.MA.IN
# 554 Mortality rate, neonatal (per 1,000 live births) SH.DYN.NMRT
# 555 Mortality rate, under-5 (per 1,000) SH.DYN.MORT
# 556 Mortality rate, under-5, female (per 1,000 live births) SH.DYN.MORT.FE
# 557 Mortality rate, under-5, male (per 1,000 live births) SH.DYN.MORT.MA
# 558 Number of maternal deaths SH.MMR.DTHS
# 559 Other taxes payable by businesses (% of commercial profits) IC.TAX.OTHR.CP.ZS
# 560 Overall level of statistical capacity (scale 0 - 100) IQ.SCI.OVRL
# 561 Periodicity and timeliness assessment of statistical capacity (scale 0 - 100) IQ.SCI.PRDC
# 562 Plant species (higher), threatened EN.HPT.THRD.NO
# 563 Private credit bureau coverage (% of adults) IC.CRD.PRVT.ZS
# 564 Procedures to build a warehouse (number) IC.WRH.PROC
# 565 Procedures to register property (number) IC.PRP.PROC
# 566 Profit tax (% of commercial profits) IC.TAX.PRFT.CP.ZS
# 567 Proportion of seats held by women in national parliaments (%) SG.GEN.PARL.ZS
# 568 Public credit registry coverage (% of adults) IC.CRD.PUBL.ZS
# 569 Source data assessment of statistical capacity (scale 0 - 100) IQ.SCI.SRCE
# 570 Start-up procedures to register a business (number) IC.REG.PROC
# 571 Strength of legal rights index (0=weak to 12=strong) IC.LGL.CRED.XQ
# 572 Tax payments (number) IC.TAX.PAYM
# 573 Time required to build a warehouse (days) IC.WRH.DURS
# 574 Time required to enforce a contract (days) IC.LGL.DURS
# 575 Time required to get electricity (days) IC.ELC.TIME
# 576 Time required to register property (days) IC.PRP.DURS
# 577 Time required to start a business (days) IC.REG.DURS
# 578 Time to prepare and pay taxes (hours) IC.TAX.DURS
# 579 Time to resolve insolvency (years) IC.ISV.DURS
# 580 Total tax rate (% of commercial profits) IC.TAX.TOTL.CP.ZS
# 581 Bank capital to assets ratio (%) FB.BNK.CAPA.ZS
# 582 Bank nonperforming loans to total gross loans (%) FB.AST.NPER.ZS
# 583 Bird species, threatened EN.BIR.THRD.NO
# 584 Business extent of disclosure index (0=less disclosure to 10=more disclosure) IC.BUS.DISC.XQ
# 585 Cost of business start-up procedures (% of GNI per capita) IC.REG.COST.PC.ZS
# 586 Depth of credit information index (0=low to 8=high) IC.CRD.INFO.XQ
# 587 Distance to frontier score (0=lowest performance to 100=frontier) IC.BUS.DFRN.XQ
# 588 Ease of doing business index (1=most business-friendly regulations) IC.BUS.EASE.XQ
# 589 Fish species, threatened EN.FSH.THRD.NO
# 590 Improved sanitation facilities (% of population with access) SH.STA.ACSN
# 591 Improved sanitation facilities, rural (% of rural population with access) SH.STA.ACSN.RU
# 592 Improved sanitation facilities, urban (% of urban population with access) SH.STA.ACSN.UR
# 593 Improved water source (% of population with access) SH.H2O.SAFE.ZS
# 594 Improved water source, rural (% of rural population with access) SH.H2O.SAFE.RU.ZS
# 595 Improved water source, urban (% of urban population with access) SH.H2O.SAFE.UR.ZS
# 596 Labor tax and contributions (% of commercial profits) IC.TAX.LABR.CP.ZS
# 597 Lifetime risk of maternal death (%) SH.MMR.RISK.ZS
# 598 Lifetime risk of maternal death (1 in: rate varies by country) SH.MMR.RISK
# 599 Mammal species, threatened EN.MAM.THRD.NO
# 600 Maternal mortality ratio (modeled estimate, per 100,000 live births) SH.STA.MMRT
# 601 Mortality rate, infant (per 1,000 live births) SP.DYN.IMRT.IN
# 602 Mortality rate, infant, female (per 1,000 live births) SP.DYN.IMRT.FE.IN
# 603 Mortality rate, infant, male (per 1,000 live births) SP.DYN.IMRT.MA.IN
# 604 Mortality rate, neonatal (per 1,000 live births) SH.DYN.NMRT
# 605 Mortality rate, under-5 (per 1,000) SH.DYN.MORT
# 606 Mortality rate, under-5, female (per 1,000 live births) SH.DYN.MORT.FE
# 607 Mortality rate, under-5, male (per 1,000 live births) SH.DYN.MORT.MA
# 608 Number of infant deaths SH.DTH.IMRT
# 609 Number of maternal deaths SH.MMR.DTHS
# 610 Number of neonatal deaths SH.DTH.NMRT
# 611 Number of under-five deaths SH.DTH.MORT
# 612 Other taxes payable by businesses (% of commercial profits) IC.TAX.OTHR.CP.ZS
# 613 Plant species (higher), threatened EN.HPT.THRD.NO
# 614 Private credit bureau coverage (% of adults) IC.CRD.PRVT.ZS
# 615 Procedures to build a warehouse (number) IC.WRH.PROC
# 616 Procedures to register property (number) IC.PRP.PROC
# 617 Profit tax (% of commercial profits) IC.TAX.PRFT.CP.ZS
# 618 Proportion of seats held by women in national parliaments (%) SG.GEN.PARL.ZS
# 619 Public credit registry coverage (% of adults) IC.CRD.PUBL.ZS
# 620 Start-up procedures to register a business (number) IC.REG.PROC
# 621 Strength of legal rights index (0=weak to 12=strong) IC.LGL.CRED.XQ
# 622 Tax payments (number) IC.TAX.PAYM
# 623 Time required to build a warehouse (days) IC.WRH.DURS
# 624 Time required to enforce a contract (days) IC.LGL.DURS
# 625 Time required to get electricity (days) IC.ELC.TIME
# 626 Time required to register property (days) IC.PRP.DURS
# 627 Time required to start a business (days) IC.REG.DURS
# 628 Time to prepare and pay taxes (hours) IC.TAX.DURS
# 629 Time to resolve insolvency (years) IC.ISV.DURS
# 630 Total tax rate (% of commercial profits) IC.TAX.TOTL.CP.ZS
# 631 Bird species, threatened EN.BIR.THRD.NO
# 632 Business extent of disclosure index (0=less disclosure to 10=more disclosure) IC.BUS.DISC.XQ
# 633 Cost of business start-up procedures (% of GNI per capita) IC.REG.COST.PC.ZS
# 634 Depth of credit information index (0=low to 8=high) IC.CRD.INFO.XQ
# 635 Distance to frontier score (0=lowest performance to 100=frontier) IC.BUS.DFRN.XQ
# 636 Ease of doing business index (1=most business-friendly regulations) IC.BUS.EASE.XQ
# 637 Fish species, threatened EN.FSH.THRD.NO
# 638 Improved sanitation facilities (% of population with access) SH.STA.ACSN
# 639 Improved sanitation facilities, rural (% of rural population with access) SH.STA.ACSN.RU
# 640 Improved sanitation facilities, urban (% of urban population with access) SH.STA.ACSN.UR
# 641 Improved water source (% of population with access) SH.H2O.SAFE.ZS
# 642 Improved water source, rural (% of rural population with access) SH.H2O.SAFE.RU.ZS
# 643 Improved water source, urban (% of urban population with access) SH.H2O.SAFE.UR.ZS
# 644 Labor tax and contributions (% of commercial profits) IC.TAX.LABR.CP.ZS
# 645 Lifetime risk of maternal death (%) SH.MMR.RISK.ZS
# 646 Lifetime risk of maternal death (1 in: rate varies by country) SH.MMR.RISK
# 647 Mammal species, threatened EN.MAM.THRD.NO
# 648 Maternal mortality ratio (modeled estimate, per 100,000 live births) SH.STA.MMRT
# 649 Mortality rate, infant (per 1,000 live births) SP.DYN.IMRT.IN
# 650 Mortality rate, infant, female (per 1,000 live births) SP.DYN.IMRT.FE.IN
# 651 Mortality rate, infant, male (per 1,000 live births) SP.DYN.IMRT.MA.IN
# 652 Mortality rate, neonatal (per 1,000 live births) SH.DYN.NMRT
# 653 Mortality rate, under-5 (per 1,000) SH.DYN.MORT
# 654 Mortality rate, under-5, female (per 1,000 live births) SH.DYN.MORT.FE
# 655 Mortality rate, under-5, male (per 1,000 live births) SH.DYN.MORT.MA
# 656 Number of maternal deaths SH.MMR.DTHS
# 657 Other taxes payable by businesses (% of commercial profits) IC.TAX.OTHR.CP.ZS
# 658 Plant species (higher), threatened EN.HPT.THRD.NO
# 659 Private credit bureau coverage (% of adults) IC.CRD.PRVT.ZS
# 660 Procedures to build a warehouse (number) IC.WRH.PROC
# 661 Procedures to register property (number) IC.PRP.PROC
# 662 Profit tax (% of commercial profits) IC.TAX.PRFT.CP.ZS
# 663 Proportion of seats held by women in national parliaments (%) SG.GEN.PARL.ZS
# 664 Public credit registry coverage (% of adults) IC.CRD.PUBL.ZS
# 665 Start-up procedures to register a business (number) IC.REG.PROC
# 666 Strength of legal rights index (0=weak to 12=strong) IC.LGL.CRED.XQ
# 667 Tax payments (number) IC.TAX.PAYM
# 668 Time required to build a warehouse (days) IC.WRH.DURS
# 669 Time required to enforce a contract (days) IC.LGL.DURS
# 670 Time required to get electricity (days) IC.ELC.TIME
# 671 Time required to register property (days) IC.PRP.DURS
# 672 Time required to start a business (days) IC.REG.DURS
# 673 Time to prepare and pay taxes (hours) IC.TAX.DURS
# 674 Time to resolve insolvency (years) IC.ISV.DURS
# 675 Total tax rate (% of commercial profits) IC.TAX.TOTL.CP.ZS
# 676 Bank capital to assets ratio (%) FB.BNK.CAPA.ZS
# 677 Bank nonperforming loans to total gross loans (%) FB.AST.NPER.ZS
# 678 Bird species, threatened EN.BIR.THRD.NO
# 679 Business extent of disclosure index (0=less disclosure to 10=more disclosure) IC.BUS.DISC.XQ
# 680 Cost of business start-up procedures (% of GNI per capita) IC.REG.COST.PC.ZS
# 681 Depth of credit information index (0=low to 8=high) IC.CRD.INFO.XQ
# 682 Distance to frontier score (0=lowest performance to 100=frontier) IC.BUS.DFRN.XQ
# 683 Ease of doing business index (1=most business-friendly regulations) IC.BUS.EASE.XQ
# 684 Fish species, threatened EN.FSH.THRD.NO
# 685 Improved sanitation facilities (% of population with access) SH.STA.ACSN
# 686 Improved sanitation facilities, rural (% of rural population with access) SH.STA.ACSN.RU
# 687 Improved sanitation facilities, urban (% of urban population with access) SH.STA.ACSN.UR
# 688 Improved water source (% of population with access) SH.H2O.SAFE.ZS
# 689 Improved water source, rural (% of rural population with access) SH.H2O.SAFE.RU.ZS
# 690 Improved water source, urban (% of urban population with access) SH.H2O.SAFE.UR.ZS
# 691 Labor tax and contributions (% of commercial profits) IC.TAX.LABR.CP.ZS
# 692 Lifetime risk of maternal death (%) SH.MMR.RISK.ZS
# 693 Lifetime risk of maternal death (1 in: rate varies by country) SH.MMR.RISK
# 694 Mammal species, threatened EN.MAM.THRD.NO
# 695 Maternal mortality ratio (modeled estimate, per 100,000 live births) SH.STA.MMRT
# 696 Mortality rate, infant (per 1,000 live births) SP.DYN.IMRT.IN
# 697 Mortality rate, infant, female (per 1,000 live births) SP.DYN.IMRT.FE.IN
# 698 Mortality rate, infant, male (per 1,000 live births) SP.DYN.IMRT.MA.IN
# 699 Mortality rate, neonatal (per 1,000 live births) SH.DYN.NMRT
# 700 Mortality rate, under-5 (per 1,000) SH.DYN.MORT
# 701 Mortality rate, under-5, female (per 1,000 live births) SH.DYN.MORT.FE
# 702 Mortality rate, under-5, male (per 1,000 live births) SH.DYN.MORT.MA
# 703 Number of maternal deaths SH.MMR.DTHS
# 704 Other taxes payable by businesses (% of commercial profits) IC.TAX.OTHR.CP.ZS
# 705 Plant species (higher), threatened EN.HPT.THRD.NO
# 706 Private credit bureau coverage (% of adults) IC.CRD.PRVT.ZS
# 707 Procedures to build a warehouse (number) IC.WRH.PROC
# 708 Procedures to register property (number) IC.PRP.PROC
# 709 Profit tax (% of commercial profits) IC.TAX.PRFT.CP.ZS
# 710 Proportion of seats held by women in national parliaments (%) SG.GEN.PARL.ZS
# 711 Public credit registry coverage (% of adults) IC.CRD.PUBL.ZS
# 712 Start-up procedures to register a business (number) IC.REG.PROC
# ...
# 14526 Source data assessment of statistical capacity (scale 0 - 100) IQ.SCI.SRCE
# 14527 Start-up procedures to register a business (number) IC.REG.PROC
# 14528 Strength of legal rights index (0=weak to 12=strong) IC.LGL.CRED.XQ
# 14529 Tax payments (number) IC.TAX.PAYM
# 14530 Time required to build a warehouse (days) IC.WRH.DURS
# 14531 Time required to enforce a contract (days) IC.LGL.DURS
# 14532 Time required to get electricity (days) IC.ELC.TIME
# 14533 Time required to register property (days) IC.PRP.DURS
# 14534 Time required to start a business (days) IC.REG.DURS
# 14535 Time to prepare and pay taxes (hours) IC.TAX.DURS
# 14536 Total tax rate (% of commercial profits) IC.TAX.TOTL.CP.ZS
# 14537 Bird species, threatened EN.BIR.THRD.NO
# 14538 Business extent of disclosure index (0=less disclosure to 10=more disclosure) IC.BUS.DISC.XQ
# 14539 Cost of business start-up procedures (% of GNI per capita) IC.REG.COST.PC.ZS
# 14540 Depth of credit information index (0=low to 8=high) IC.CRD.INFO.XQ
# 14541 Disbursements on external debt, long-term (DIS, current US$) DT.DIS.DLXF.CD
# 14542 Distance to frontier score (0=lowest performance to 100=frontier) IC.BUS.DFRN.XQ
# 14543 Ease of doing business index (1=most business-friendly regulations) IC.BUS.EASE.XQ
# 14544 Fish species, threatened EN.FSH.THRD.NO
# 14545 Interest payments on external debt, long-term (INT, current US$) DT.INT.DLXF.CD
# 14546 Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$) DT.INT.DPNG.CD
# 14547 Labor tax and contributions (% of commercial profits) IC.TAX.LABR.CP.ZS
# 14548 Lifetime risk of maternal death (%) SH.MMR.RISK.ZS
# 14549 Lifetime risk of maternal death (1 in: rate varies by country) SH.MMR.RISK
# 14550 Mammal species, threatened EN.MAM.THRD.NO
# 14551 Maternal mortality ratio (modeled estimate, per 100,000 live births) SH.STA.MMRT
# 14552 Methodology assessment of statistical capacity (scale 0 - 100) IQ.SCI.MTHD
# 14553 Mortality rate, infant (per 1,000 live births) SP.DYN.IMRT.IN
# 14554 Mortality rate, infant, female (per 1,000 live births) SP.DYN.IMRT.FE.IN
# 14555 Mortality rate, infant, male (per 1,000 live births) SP.DYN.IMRT.MA.IN
# 14556 Mortality rate, neonatal (per 1,000 live births) SH.DYN.NMRT
# 14557 Mortality rate, under-5 (per 1,000) SH.DYN.MORT
# 14558 Mortality rate, under-5, female (per 1,000 live births) SH.DYN.MORT.FE
# 14559 Mortality rate, under-5, male (per 1,000 live births) SH.DYN.MORT.MA
# 14560 Number of infant deaths SH.DTH.IMRT
# 14561 Number of maternal deaths SH.MMR.DTHS
# 14562 Number of neonatal deaths SH.DTH.NMRT
# 14563 Number of under-five deaths SH.DTH.MORT
# 14564 Other taxes payable by businesses (% of commercial profits) IC.TAX.OTHR.CP.ZS
# 14565 Overall level of statistical capacity (scale 0 - 100) IQ.SCI.OVRL
# 14566 Periodicity and timeliness assessment of statistical capacity (scale 0 - 100) IQ.SCI.PRDC
# 14567 Plant species (higher), threatened EN.HPT.THRD.NO
# 14568 PPG, bilateral (AMT, current US$) DT.AMT.BLAT.CD
# 14569 PPG, bilateral (DIS, current US$) DT.DIS.BLAT.CD
# 14570 PPG, bilateral (INT, current US$) DT.INT.BLAT.CD
# 14571 PPG, bonds (AMT, current US$) DT.AMT.PBND.CD
# 14572 PPG, bonds (INT, current US$) DT.INT.PBND.CD
# 14573 PPG, commercial banks (AMT, current US$) DT.AMT.PCBK.CD
# 14574 PPG, commercial banks (DIS, current US$) DT.DIS.PCBK.CD
# 14575 PPG, commercial banks (INT, current US$) DT.INT.PCBK.CD
# 14576 PPG, multilateral (AMT, current US$) DT.AMT.MLAT.CD
# 14577 PPG, multilateral (DIS, current US$) DT.DIS.MLAT.CD
# 14578 PPG, multilateral (INT, current US$) DT.INT.MLAT.CD
# 14579 PPG, official creditors (AMT, current US$) DT.AMT.OFFT.CD
# 14580 PPG, official creditors (DIS, current US$) DT.DIS.OFFT.CD
# 14581 PPG, official creditors (INT, current US$) DT.INT.OFFT.CD
# 14582 PPG, other private creditors (AMT, current US$) DT.AMT.PROP.CD
# 14583 PPG, other private creditors (DIS, current US$) DT.DIS.PROP.CD
# 14584 PPG, other private creditors (INT, current US$) DT.INT.PROP.CD
# 14585 PPG, private creditors (AMT, current US$) DT.AMT.PRVT.CD
# 14586 PPG, private creditors (DIS, current US$) DT.DIS.PRVT.CD
# 14587 PPG, private creditors (INT, current US$) DT.INT.PRVT.CD
# 14588 Principal repayments on external debt, long-term (AMT, current US$) DT.AMT.DLXF.CD
# 14589 Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$) DT.AMT.DPNG.CD
# 14590 Private credit bureau coverage (% of adults) IC.CRD.PRVT.ZS
# 14591 Procedures to build a warehouse (number) IC.WRH.PROC
# 14592 Procedures to register property (number) IC.PRP.PROC
# 14593 Profit tax (% of commercial profits) IC.TAX.PRFT.CP.ZS
# 14594 Proportion of seats held by women in national parliaments (%) SG.GEN.PARL.ZS
# 14595 Public credit registry coverage (% of adults) IC.CRD.PUBL.ZS
# 14596 Source data assessment of statistical capacity (scale 0 - 100) IQ.SCI.SRCE
# 14597 Start-up procedures to register a business (number) IC.REG.PROC
# 14598 Strength of legal rights index (0=weak to 12=strong) IC.LGL.CRED.XQ
# 14599 Tax payments (number) IC.TAX.PAYM
# 14600 Time required to build a warehouse (days) IC.WRH.DURS
# 14601 Time required to enforce a contract (days) IC.LGL.DURS
# 14602 Time required to get electricity (days) IC.ELC.TIME
# 14603 Time required to register property (days) IC.PRP.DURS
# 14604 Time required to start a business (days) IC.REG.DURS
# 14605 Time to prepare and pay taxes (hours) IC.TAX.DURS
# 14606 Time to resolve insolvency (years) IC.ISV.DURS
# 14607 Total tax rate (% of commercial profits) IC.TAX.TOTL.CP.ZS
# 14608 Bird species, threatened EN.BIR.THRD.NO
# 14609 Business extent of disclosure index (0=less disclosure to 10=more disclosure) IC.BUS.DISC.XQ
# 14610 Cost of business start-up procedures (% of GNI per capita) IC.REG.COST.PC.ZS
# 14611 Depth of credit information index (0=low to 8=high) IC.CRD.INFO.XQ
# 14612 Disbursements on external debt, long-term (DIS, current US$) DT.DIS.DLXF.CD
# 14613 Distance to frontier score (0=lowest performance to 100=frontier) IC.BUS.DFRN.XQ
# 14614 Ease of doing business index (1=most business-friendly regulations) IC.BUS.EASE.XQ
# 14615 Fish species, threatened EN.FSH.THRD.NO
# 14616 Improved sanitation facilities (% of population with access) SH.STA.ACSN
# 14617 Improved sanitation facilities, rural (% of rural population with access) SH.STA.ACSN.RU
# 14618 Improved sanitation facilities, urban (% of urban population with access) SH.STA.ACSN.UR
# 14619 Improved water source (% of population with access) SH.H2O.SAFE.ZS
# 14620 Improved water source, rural (% of rural population with access) SH.H2O.SAFE.RU.ZS
# 14621 Improved water source, urban (% of urban population with access) SH.H2O.SAFE.UR.ZS
# 14622 Interest payments on external debt, long-term (INT, current US$) DT.INT.DLXF.CD
# 14623 Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$) DT.INT.DPNG.CD
# 14624 Labor tax and contributions (% of commercial profits) IC.TAX.LABR.CP.ZS
# 14625 Lifetime risk of maternal death (%) SH.MMR.RISK.ZS
# 14626 Lifetime risk of maternal death (1 in: rate varies by country) SH.MMR.RISK
# 14627 Mammal species, threatened EN.MAM.THRD.NO
# 14628 Maternal mortality ratio (modeled estimate, per 100,000 live births) SH.STA.MMRT
# 14629 Methodology assessment of statistical capacity (scale 0 - 100) IQ.SCI.MTHD
# 14630 Mortality rate, infant (per 1,000 live births) SP.DYN.IMRT.IN
# 14631 Mortality rate, infant, female (per 1,000 live births) SP.DYN.IMRT.FE.IN
# 14632 Mortality rate, infant, male (per 1,000 live births) SP.DYN.IMRT.MA.IN
# 14633 Mortality rate, neonatal (per 1,000 live births) SH.DYN.NMRT
# 14634 Mortality rate, under-5 (per 1,000) SH.DYN.MORT
# 14635 Mortality rate, under-5, female (per 1,000 live births) SH.DYN.MORT.FE
# 14636 Mortality rate, under-5, male (per 1,000 live births) SH.DYN.MORT.MA
# 14637 Number of infant deaths SH.DTH.IMRT
# 14638 Number of maternal deaths SH.MMR.DTHS
# 14639 Number of neonatal deaths SH.DTH.NMRT
# 14640 Number of under-five deaths SH.DTH.MORT
# 14641 Other taxes payable by businesses (% of commercial profits) IC.TAX.OTHR.CP.ZS
# 14642 Overall level of statistical capacity (scale 0 - 100) IQ.SCI.OVRL
# 14643 Periodicity and timeliness assessment of statistical capacity (scale 0 - 100) IQ.SCI.PRDC
# 14644 Plant species (higher), threatened EN.HPT.THRD.NO
# 14645 PPG, bilateral (AMT, current US$) DT.AMT.BLAT.CD
# 14646 PPG, bilateral (DIS, current US$) DT.DIS.BLAT.CD
# 14647 PPG, bilateral (INT, current US$) DT.INT.BLAT.CD
# 14648 PPG, bonds (AMT, current US$) DT.AMT.PBND.CD
# 14649 PPG, bonds (INT, current US$) DT.INT.PBND.CD
# 14650 PPG, commercial banks (AMT, current US$) DT.AMT.PCBK.CD
# 14651 PPG, commercial banks (DIS, current US$) DT.DIS.PCBK.CD
# 14652 PPG, commercial banks (INT, current US$) DT.INT.PCBK.CD
# 14653 PPG, multilateral (AMT, current US$) DT.AMT.MLAT.CD
# 14654 PPG, multilateral (DIS, current US$) DT.DIS.MLAT.CD
# 14655 PPG, multilateral (INT, current US$) DT.INT.MLAT.CD
# 14656 PPG, official creditors (AMT, current US$) DT.AMT.OFFT.CD
# 14657 PPG, official creditors (DIS, current US$) DT.DIS.OFFT.CD
# 14658 PPG, official creditors (INT, current US$) DT.INT.OFFT.CD
# 14659 PPG, other private creditors (AMT, current US$) DT.AMT.PROP.CD
# 14660 PPG, other private creditors (DIS, current US$) DT.DIS.PROP.CD
# 14661 PPG, other private creditors (INT, current US$) DT.INT.PROP.CD
# 14662 PPG, private creditors (AMT, current US$) DT.AMT.PRVT.CD
# 14663 PPG, private creditors (DIS, current US$) DT.DIS.PRVT.CD
# 14664 PPG, private creditors (INT, current US$) DT.INT.PRVT.CD
# 14665 Principal repayments on external debt, long-term (AMT, current US$) DT.AMT.DLXF.CD
# 14666 Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$) DT.AMT.DPNG.CD
# 14667 Private credit bureau coverage (% of adults) IC.CRD.PRVT.ZS
# 14668 Procedures to build a warehouse (number) IC.WRH.PROC
# 14669 Procedures to register property (number) IC.PRP.PROC
# 14670 Profit tax (% of commercial profits) IC.TAX.PRFT.CP.ZS
# 14671 Proportion of seats held by women in national parliaments (%) SG.GEN.PARL.ZS
# 14672 Public credit registry coverage (% of adults) IC.CRD.PUBL.ZS
# 14673 Source data assessment of statistical capacity (scale 0 - 100) IQ.SCI.SRCE
# 14674 Start-up procedures to register a business (number) IC.REG.PROC
# 14675 Strength of legal rights index (0=weak to 12=strong) IC.LGL.CRED.XQ
# 14676 Tax payments (number) IC.TAX.PAYM
# 14677 Time required to build a warehouse (days) IC.WRH.DURS
# 14678 Time required to enforce a contract (days) IC.LGL.DURS
# 14679 Time required to get electricity (days) IC.ELC.TIME
# 14680 Time required to register property (days) IC.PRP.DURS
# 14681 Time required to start a business (days) IC.REG.DURS
# 14682 Time to prepare and pay taxes (hours) IC.TAX.DURS
# 14683 Time to resolve insolvency (years) IC.ISV.DURS
# 14684 Total tax rate (% of commercial profits) IC.TAX.TOTL.CP.ZS
# 14685 Bird species, threatened EN.BIR.THRD.NO
# 14686 Business extent of disclosure index (0=less disclosure to 10=more disclosure) IC.BUS.DISC.XQ
# 14687 Cost of business start-up procedures (% of GNI per capita) IC.REG.COST.PC.ZS
# 14688 Depth of credit information index (0=low to 8=high) IC.CRD.INFO.XQ
# 14689 Disbursements on external debt, long-term (DIS, current US$) DT.DIS.DLXF.CD
# 14690 Distance to frontier score (0=lowest performance to 100=frontier) IC.BUS.DFRN.XQ
# 14691 Ease of doing business index (1=most business-friendly regulations) IC.BUS.EASE.XQ
# 14692 Fish species, threatened EN.FSH.THRD.NO
# 14693 Improved sanitation facilities (% of population with access) SH.STA.ACSN
# 14694 Improved sanitation facilities, rural (% of rural population with access) SH.STA.ACSN.RU
# 14695 Improved sanitation facilities, urban (% of urban population with access) SH.STA.ACSN.UR
# 14696 Improved water source (% of population with access) SH.H2O.SAFE.ZS
# 14697 Improved water source, rural (% of rural population with access) SH.H2O.SAFE.RU.ZS
# 14698 Improved water source, urban (% of urban population with access) SH.H2O.SAFE.UR.ZS
# 14699 Interest payments on external debt, long-term (INT, current US$) DT.INT.DLXF.CD
# 14700 Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$) DT.INT.DPNG.CD
# 14701 Labor tax and contributions (% of commercial profits) IC.TAX.LABR.CP.ZS
# 14702 Lifetime risk of maternal death (%) SH.MMR.RISK.ZS
# 14703 Lifetime risk of maternal death (1 in: rate varies by country) SH.MMR.RISK
# 14704 Mammal species, threatened EN.MAM.THRD.NO
# 14705 Maternal mortality ratio (modeled estimate, per 100,000 live births) SH.STA.MMRT
# 14706 Methodology assessment of statistical capacity (scale 0 - 100) IQ.SCI.MTHD
# 14707 Mortality rate, infant (per 1,000 live births) SP.DYN.IMRT.IN
# 14708 Mortality rate, infant, female (per 1,000 live births) SP.DYN.IMRT.FE.IN
# 14709 Mortality rate, infant, male (per 1,000 live births) SP.DYN.IMRT.MA.IN
# 14710 Mortality rate, neonatal (per 1,000 live births) SH.DYN.NMRT
# 14711 Mortality rate, under-5 (per 1,000) SH.DYN.MORT
# 14712 Mortality rate, under-5, female (per 1,000 live births) SH.DYN.MORT.FE
# 14713 Mortality rate, under-5, male (per 1,000 live births) SH.DYN.MORT.MA
# 14714 Number of infant deaths SH.DTH.IMRT
# 14715 Number of maternal deaths SH.MMR.DTHS
# 14716 Number of neonatal deaths SH.DTH.NMRT
# 14717 Number of under-five deaths SH.DTH.MORT
# 14718 Other taxes payable by businesses (% of commercial profits) IC.TAX.OTHR.CP.ZS
# 14719 Overall level of statistical capacity (scale 0 - 100) IQ.SCI.OVRL
# 14720 Periodicity and timeliness assessment of statistical capacity (scale 0 - 100) IQ.SCI.PRDC
# 14721 Plant species (higher), threatened EN.HPT.THRD.NO
# 14722 PPG, bilateral (AMT, current US$) DT.AMT.BLAT.CD
# 14723 PPG, bilateral (DIS, current US$) DT.DIS.BLAT.CD
# 14724 PPG, bilateral (INT, current US$) DT.INT.BLAT.CD
# 14725 PPG, bonds (AMT, current US$) DT.AMT.PBND.CD
# 14726 PPG, bonds (INT, current US$) DT.INT.PBND.CD
# 14727 PPG, commercial banks (AMT, current US$) DT.AMT.PCBK.CD
# 14728 PPG, commercial banks (DIS, current US$) DT.DIS.PCBK.CD
# 14729 PPG, commercial banks (INT, current US$) DT.INT.PCBK.CD
# 14730 PPG, multilateral (AMT, current US$) DT.AMT.MLAT.CD
# 14731 PPG, multilateral (DIS, current US$) DT.DIS.MLAT.CD
# 14732 PPG, multilateral (INT, current US$) DT.INT.MLAT.CD
# 14733 PPG, official creditors (AMT, current US$) DT.AMT.OFFT.CD
# 14734 PPG, official creditors (DIS, current US$) DT.DIS.OFFT.CD
# 14735 PPG, official creditors (INT, current US$) DT.INT.OFFT.CD
# 14736 PPG, other private creditors (AMT, current US$) DT.AMT.PROP.CD
# 14737 PPG, other private creditors (DIS, current US$) DT.DIS.PROP.CD
# 14738 PPG, other private creditors (INT, current US$) DT.INT.PROP.CD
# 14739 PPG, private creditors (AMT, current US$) DT.AMT.PRVT.CD
# 14740 PPG, private creditors (DIS, current US$) DT.DIS.PRVT.CD
# 14741 PPG, private creditors (INT, current US$) DT.INT.PRVT.CD
# 14742 Principal repayments on external debt, long-term (AMT, current US$) DT.AMT.DLXF.CD
# 14743 Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$) DT.AMT.DPNG.CD
# 14744 Private credit bureau coverage (% of adults) IC.CRD.PRVT.ZS
# 14745 Procedures to build a warehouse (number) IC.WRH.PROC
# 14746 Procedures to register property (number) IC.PRP.PROC
# 14747 Profit tax (% of commercial profits) IC.TAX.PRFT.CP.ZS
# 14748 Proportion of seats held by women in national parliaments (%) SG.GEN.PARL.ZS
# 14749 Public credit registry coverage (% of adults) IC.CRD.PUBL.ZS
# 14750 Source data assessment of statistical capacity (scale 0 - 100) IQ.SCI.SRCE
# 14751 Start-up procedures to register a business (number) IC.REG.PROC
# 14752 Strength of legal rights index (0=weak to 12=strong) IC.LGL.CRED.XQ
# 14753 Tax payments (number) IC.TAX.PAYM
# 14754 Time required to build a warehouse (days) IC.WRH.DURS
# 14755 Time required to enforce a contract (days) IC.LGL.DURS
# 14756 Time required to get electricity (days) IC.ELC.TIME
# 14757 Time required to register property (days) IC.PRP.DURS
# 14758 Time required to start a business (days) IC.REG.DURS
# 14759 Time to prepare and pay taxes (hours) IC.TAX.DURS
# 14760 Time to resolve insolvency (years) IC.ISV.DURS
# 14761 Total tax rate (% of commercial profits) IC.TAX.TOTL.CP.ZS

# %%
wdi_in = wdi.groupby('CountryName')

# %%
h=list(happiness.Country.unique())

# %%
h.sort()
h
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Bangladesh',
#  'Belarus',
#  'Belgium',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo (Brazzaville)',
#  'Congo (Kinshasa)',
#  'Costa Rica',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Estonia',
#  'Ethiopia',
#  'Finland',
#  'France',
#  'Gabon',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Guatemala',
#  'Guinea',
#  'Haiti',
#  'Honduras',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Ivory Coast',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Laos',
#  'Latvia',
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Lithuania',
#  'Luxembourg',
#  'Macedonia',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Mali',
#  'Malta',
#  'Mauritania',
#  'Mauritius',
#  'Mexico',
#  'Moldova',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Nepal',
#  'Netherlands',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'North Cyprus',
#  'Norway',
#  'Oman',
#  'Pakistan',
#  'Palestinian Territories',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Qatar',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Sierra Leone',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'Somaliland region',
#  'South Africa',
#  'South Korea',
#  'Spain',
#  'Sri Lanka',
#  'Sudan',
#  'Suriname',
#  'Swaziland',
#  'Sweden',
#  'Switzerland',
#  'Syria',
#  'Taiwan',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Togo',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Uzbekistan',
#  'Venezuela',
#  'Vietnam',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe']

# %%
for index, row in wdi.tail(100).iterrows():
    print(index,row.CountryName, row.CountryCode)
# Out:
# 14662 Zambia ZMB
# 14663 Zambia ZMB
# 14664 Zambia ZMB
# 14665 Zambia ZMB
# 14666 Zambia ZMB
# 14667 Zambia ZMB
# 14668 Zambia ZMB
# 14669 Zambia ZMB
# 14670 Zambia ZMB
# 14671 Zambia ZMB
# 14672 Zambia ZMB
# 14673 Zambia ZMB
# 14674 Zambia ZMB
# 14675 Zambia ZMB
# 14676 Zambia ZMB
# 14677 Zambia ZMB
# 14678 Zambia ZMB
# 14679 Zambia ZMB
# 14680 Zambia ZMB
# 14681 Zambia ZMB
# 14682 Zambia ZMB
# 14683 Zambia ZMB
# 14684 Zambia ZMB
# 14685 Zimbabwe ZWE
# 14686 Zimbabwe ZWE
# 14687 Zimbabwe ZWE
# 14688 Zimbabwe ZWE
# 14689 Zimbabwe ZWE
# 14690 Zimbabwe ZWE
# 14691 Zimbabwe ZWE
# 14692 Zimbabwe ZWE
# 14693 Zimbabwe ZWE
# 14694 Zimbabwe ZWE
# 14695 Zimbabwe ZWE
# 14696 Zimbabwe ZWE
# 14697 Zimbabwe ZWE
# 14698 Zimbabwe ZWE
# 14699 Zimbabwe ZWE
# 14700 Zimbabwe ZWE
# 14701 Zimbabwe ZWE
# 14702 Zimbabwe ZWE
# 14703 Zimbabwe ZWE
# 14704 Zimbabwe ZWE
# 14705 Zimbabwe ZWE
# 14706 Zimbabwe ZWE
# 14707 Zimbabwe ZWE
# 14708 Zimbabwe ZWE
# 14709 Zimbabwe ZWE
# 14710 Zimbabwe ZWE
# 14711 Zimbabwe ZWE
# 14712 Zimbabwe ZWE
# 14713 Zimbabwe ZWE
# 14714 Zimbabwe ZWE
# 14715 Zimbabwe ZWE
# 14716 Zimbabwe ZWE
# 14717 Zimbabwe ZWE
# 14718 Zimbabwe ZWE
# 14719 Zimbabwe ZWE
# 14720 Zimbabwe ZWE
# 14721 Zimbabwe ZWE
# 14722 Zimbabwe ZWE
# 14723 Zimbabwe ZWE
# 14724 Zimbabwe ZWE
# 14725 Zimbabwe ZWE
# 14726 Zimbabwe ZWE
# 14727 Zimbabwe ZWE
# 14728 Zimbabwe ZWE
# 14729 Zimbabwe ZWE
# 14730 Zimbabwe ZWE
# 14731 Zimbabwe ZWE
# 14732 Zimbabwe ZWE
# 14733 Zimbabwe ZWE
# 14734 Zimbabwe ZWE
# 14735 Zimbabwe ZWE
# 14736 Zimbabwe ZWE
# 14737 Zimbabwe ZWE
# 14738 Zimbabwe ZWE
# 14739 Zimbabwe ZWE
# 14740 Zimbabwe ZWE
# 14741 Zimbabwe ZWE
# 14742 Zimbabwe ZWE
# 14743 Zimbabwe ZWE
# 14744 Zimbabwe ZWE
# 14745 Zimbabwe ZWE
# 14746 Zimbabwe ZWE
# 14747 Zimbabwe ZWE
# 14748 Zimbabwe ZWE
# 14749 Zimbabwe ZWE
# 14750 Zimbabwe ZWE
# 14751 Zimbabwe ZWE
# 14752 Zimbabwe ZWE
# 14753 Zimbabwe ZWE
# 14754 Zimbabwe ZWE
# 14755 Zimbabwe ZWE
# 14756 Zimbabwe ZWE
# 14757 Zimbabwe ZWE
# 14758 Zimbabwe ZWE
# 14759 Zimbabwe ZWE
# 14760 Zimbabwe ZWE
# 14761 Zimbabwe ZWE

# %%
pivot = wdi.groupby('CountryName')

# %%
table = pd.pivot_table(wdi, values='Value', index='CountryName', columns='IndicatorCode')
table.reset_index(inplace=True)
table
# Out:
# IndicatorCode         CountryName  DT.AMT.BLAT.CD  DT.AMT.DLXF.CD  \
# 0                     Afghanistan      93356000.0     122152000.0
# 1                         Albania      63421000.0     628276000.0
# 2                         Algeria     156481000.0     229092000.0
# 3                  American Samoa             NaN             NaN
# 4                         Andorra             NaN             NaN
# ..                            ...             ...             ...
# 241            West Bank and Gaza             NaN             NaN
# 242                         World             NaN             NaN
# 243                   Yemen, Rep.     149907000.0     443917000.0
# 244                        Zambia      67311000.0     158140000.0
# 245                      Zimbabwe     144888000.0     167018000.0
#
# IndicatorCode  DT.AMT.DPNG.CD  DT.AMT.MLAT.CD  DT.AMT.OFFT.CD  DT.AMT.PBND.CD  \
# 0                         0.0      28796000.0     122152000.0             0.0
# 1                         0.0     156997000.0     220418000.0     364230000.0
# 2                         0.0      13042000.0     169523000.0             0.0
# 3                         NaN             NaN             NaN             NaN
# 4                         NaN             NaN             NaN             NaN
# ..                        ...             ...             ...             ...
# 241                       NaN             NaN             NaN             NaN
# 242                       NaN             NaN             NaN             NaN
# 243                       0.0     293834000.0     443741000.0             0.0
# 244                19214000.0      30215000.0      97526000.0             0.0
# 245                       0.0      21505000.0     166393000.0             0.0
#
# IndicatorCode  DT.AMT.PCBK.CD  DT.AMT.PROP.CD  DT.AMT.PRVT.CD  DT.DIS.BLAT.CD  \
# 0                         0.0             0.0             0.0      10075000.0
# 1                  37376000.0       6252000.0     407858000.0     137095000.0
# 2                   8523000.0      51046000.0      59569000.0      29678000.0
# 3                         NaN             NaN             NaN             NaN
# 4                         NaN             NaN             NaN             NaN
# ..                        ...             ...             ...             ...
# 241                       NaN             NaN             NaN             NaN
# 242                       NaN             NaN             NaN             NaN
# 243                  176000.0             0.0        176000.0      90364000.0
# 244                       0.0      41400000.0      41400000.0     297432000.0
# 245                       0.0        625000.0        625000.0      82512000.0
#
# IndicatorCode  DT.DIS.DLXF.CD  DT.DIS.MLAT.CD  DT.DIS.OFFT.CD  DT.DIS.PCBK.CD  \
# 0                  23323000.0      13248000.0      23323000.0             0.0
# 1                 350193000.0     157102000.0     294197000.0      40916000.0
# 2                  81867000.0      52110000.0      81788000.0             0.0
# 3                         NaN             NaN             NaN             NaN
# 4                         NaN             NaN             NaN             NaN
# ..                        ...             ...             ...             ...
# 241                       NaN             NaN             NaN             NaN
# 242                       NaN             NaN             NaN             NaN
# 243               537722000.0     447358000.0     537722000.0             0.0
# 244               763274000.0     391696000.0     689128000.0             0.0
# 245                83777000.0       1265000.0      83777000.0             0.0
#
# IndicatorCode  DT.DIS.PROP.CD  DT.DIS.PRVT.CD  DT.INT.BLAT.CD  DT.INT.DLXF.CD  \
# 0                         0.0             0.0      49265000.0      60463000.0
# 1                  15080000.0      55996000.0      10959000.0      67325000.0
# 2                     79000.0         79000.0      13945000.0      21832000.0
# 3                         NaN             NaN             NaN             NaN
# 4                         NaN             NaN             NaN             NaN
# ..                        ...             ...             ...             ...
# 241                       NaN             NaN             NaN             NaN
# 242                       NaN             NaN             NaN             NaN
# 243                       0.0             0.0      29897000.0      77728000.0
# 244                74139000.0      74139000.0      35654000.0     170737000.0
# 245                       0.0             0.0      21587000.0      23214000.0
#
# IndicatorCode  DT.INT.DPNG.CD  DT.INT.MLAT.CD  DT.INT.OFFT.CD  DT.INT.PBND.CD  \
# 0                         0.0      11198000.0      60463000.0             0.0
# 1                         0.0      23108000.0      34067000.0      27521000.0
# 2                         0.0             0.0      13945000.0             0.0
# 3                         NaN             NaN             NaN             NaN
# 4                         NaN             NaN             NaN             NaN
# ..                        ...             ...             ...             ...
# 241                       NaN             NaN             NaN             NaN
# 242                       NaN             NaN             NaN             NaN
# 243                       0.0      47831000.0      77728000.0             0.0
# 244                  713000.0       8801000.0      44455000.0     125312000.0
# 245                       0.0       1626000.0      23213000.0             0.0
#
# IndicatorCode  DT.INT.PCBK.CD  DT.INT.PROP.CD  DT.INT.PRVT.CD  EN.BIR.THRD.NO  \
# 0                         0.0             0.0             0.0            17.0
# 1                   5636000.0        101000.0      33258000.0            10.0
# 2                    401000.0       7486000.0       7887000.0            14.0
# 3                         NaN             NaN             NaN             8.0
# 4                         NaN             NaN             NaN             2.0
# ..                        ...             ...             ...             ...
# 241                       NaN             NaN             NaN            13.0
# 242                       NaN             NaN             NaN          4393.0
# 243                       0.0             0.0             0.0            18.0
# 244                       0.0        257000.0     125569000.0            18.0
# 245                       0.0          1000.0          1000.0            17.0
#
# IndicatorCode  EN.FSH.THRD.NO  EN.HPT.THRD.NO  EN.MAM.THRD.NO  FB.AST.NPER.ZS  \
# 0                         5.0             5.0            10.0       13.488399
# 1                        44.0             0.0             3.0       20.900000
# 2                        40.0            18.0            13.0             NaN
# 3                        11.0             1.0             1.0             NaN
# 4                         0.0             0.0             2.0             NaN
# ..                        ...             ...             ...             ...
# 241                       2.0             0.0             3.0        2.487018
# 242                    7819.0         14781.0          3309.0             NaN
# 243                      28.0           162.0             8.0             NaN
# 244                      20.0            20.0            11.0             NaN
# 245                       3.0            17.0            10.0             NaN
#
# IndicatorCode  FB.BNK.CAPA.ZS  IC.BUS.DFRN.XQ  IC.BUS.DISC.XQ  IC.BUS.EASE.XQ  \
# 0                   12.222749       40.580000        1.000000      177.000000
# 1                    9.700000       60.500000        9.000000       97.000000
# 2                         NaN       45.720000        4.000000      163.000000
# 3                         NaN             NaN             NaN             NaN
# 4                         NaN             NaN             NaN             NaN
# ..                        ...             ...             ...             ...
# 241                  9.674752       54.830000        6.000000      129.000000
# 242                       NaN       61.027778        5.525926       94.957672
# 243                       NaN       44.540000        6.000000      170.000000
# 244                       NaN       60.500000        4.000000       97.000000
# 245                       NaN       48.170000        8.000000      155.000000
#
# IndicatorCode  IC.CRD.INFO.XQ  IC.CRD.PRVT.ZS  IC.CRD.PUBL.ZS  IC.CUS.DURS.EX  \
# 0                    0.000000        0.000000        0.500000             NaN
# 1                    6.000000        0.000000       27.100000             NaN
# 2                    0.000000        0.000000        1.900000             NaN
# 3                         NaN             NaN             NaN             NaN
# 4                         NaN             NaN             NaN             NaN
# ..                        ...             ...             ...             ...
# 241                  8.000000        0.000000       22.500000             NaN
# 242                  4.375661       29.554339       11.795238             NaN
# 243                  0.000000        0.000000        1.300000             NaN
# 244                  8.000000        8.900000        0.000000             NaN
# 245                  5.000000       32.100000        0.000000             NaN
#
# IndicatorCode  IC.ELC.DURS  IC.ELC.OUTG  IC.ELC.TIME  IC.FRM.BNKS.ZS  \
# 0                      NaN          NaN   114.000000             NaN
# 1                      NaN          NaN   177.000000             NaN
# 2                      NaN          NaN   180.000000             NaN
# 3                      NaN          NaN          NaN             NaN
# 4                      NaN          NaN          NaN             NaN
# ..                     ...          ...          ...             ...
# 241                    NaN          NaN    63.000000             NaN
# 242                    NaN          NaN    96.634921             NaN
# 243                    NaN          NaN   110.000000             NaN
# 244                    NaN          NaN   117.000000             NaN
# 245                    NaN          NaN   106.000000             NaN
#
# IndicatorCode  IC.FRM.CMPU.ZS  IC.FRM.CORR.ZS  IC.FRM.CRIM.ZS  IC.FRM.DURS  \
# 0                         NaN             NaN             NaN          NaN
# 1                         NaN             NaN             NaN          NaN
# 2                         NaN             NaN             NaN          NaN
# 3                         NaN             NaN             NaN          NaN
# 4                         NaN             NaN             NaN          NaN
# ..                        ...             ...             ...          ...
# 241                       NaN             NaN             NaN          NaN
# 242                       NaN             NaN             NaN          NaN
# 243                       NaN             NaN             NaN          NaN
# 244                       NaN             NaN             NaN          NaN
# 245                       NaN             NaN             NaN          NaN
#
# IndicatorCode  IC.FRM.FEMM.ZS  IC.FRM.FEMO.ZS  IC.FRM.FREG.ZS  IC.FRM.ISOC.ZS  \
# 0                         NaN             NaN             NaN             NaN
# 1                         NaN             NaN             NaN             NaN
# 2                         NaN             NaN             NaN             NaN
# 3                         NaN             NaN             NaN             NaN
# 4                         NaN             NaN             NaN             NaN
# ..                        ...             ...             ...             ...
# 241                       NaN             NaN             NaN             NaN
# 242                       NaN             NaN             NaN             NaN
# 243                       NaN             NaN             NaN             NaN
# 244                       NaN             NaN             NaN             NaN
# 245                       NaN             NaN             NaN             NaN
#
# IndicatorCode  IC.FRM.OUTG.ZS  IC.FRM.TRNG.ZS  IC.GOV.DURS.ZS  IC.ISV.DURS  \
# 0                         NaN             NaN             NaN     2.000000
# 1                         NaN             NaN             NaN     2.000000
# 2                         NaN             NaN             NaN     1.300000
# 3                         NaN             NaN             NaN          NaN
# 4                         NaN             NaN             NaN          NaN
# ..                        ...             ...             ...          ...
# 241                       NaN             NaN             NaN          NaN
# 242                       NaN             NaN             NaN     2.576786
# 243                       NaN             NaN             NaN     3.000000
# 244                       NaN             NaN             NaN     2.400000
# 245                       NaN             NaN             NaN     3.300000
#
# IndicatorCode  IC.LGL.CRED.XQ  IC.LGL.DURS  IC.PRP.DURS  IC.PRP.PROC  \
# 0                     9.00000  1642.000000   250.000000     9.000000
# 1                     7.00000   525.000000    22.000000     6.000000
# 2                     2.00000   630.000000    55.000000    10.000000
# 3                         NaN          NaN          NaN          NaN
# 4                         NaN          NaN          NaN          NaN
# ..                        ...          ...          ...          ...
# 241                   0.00000   540.000000    49.000000     7.000000
# 242                   5.10582   629.871958    48.335676     5.804865
# 243                   0.00000   645.000000    19.000000     6.000000
# 244                   7.00000   611.000000    45.000000     5.000000
# 245                   5.00000   410.000000    36.000000     5.000000
#
# IndicatorCode  IC.REG.COST.PC.ZS  IC.REG.DURS  IC.REG.PROC  IC.TAX.DURS  \
# 0                      19.000000     7.000000     3.000000   275.000000
# 1                      10.400000     5.500000     6.000000   357.000000
# 2                      10.900000    20.000000    12.000000   385.000000
# 3                            NaN          NaN          NaN          NaN
# 4                            NaN          NaN          NaN          NaN
# ..                           ...          ...          ...          ...
# 241                    82.500000    44.000000     9.000000   162.000000
# 242                    26.065079    20.442328     6.910053   260.712698
# 243                    68.000000    40.000000     6.000000   248.000000
# 244                    33.600000     7.500000     6.000000   157.000000
# 245                   112.000000    90.000000     9.000000   242.000000
#
# IndicatorCode  IC.TAX.GIFT.ZS  IC.TAX.LABR.CP.ZS  IC.TAX.METG  \
# 0                         NaN           0.000000          NaN
# 1                         NaN          18.800000          NaN
# 2                         NaN          30.600000          NaN
# 3                         NaN                NaN          NaN
# 4                         NaN                NaN          NaN
# ..                        ...                ...          ...
# 241                       NaN           0.000000          NaN
# 242                       NaN          15.864607          NaN
# 243                       NaN          11.300000          NaN
# 244                       NaN          10.400000          NaN
# 245                       NaN           5.600000          NaN
#
# IndicatorCode  IC.TAX.OTHR.CP.ZS  IC.TAX.PAYM  IC.TAX.PRFT.CP.ZS  \
# 0                      36.300000     20.00000           0.000000
# 1                       3.600000     34.00000          14.100000
# 2                      35.500000     27.00000           6.600000
# 3                            NaN          NaN                NaN
# 4                            NaN          NaN                NaN
# ..                           ...          ...                ...
# 241                     0.300000     28.00000          15.000000
# 242                     8.603933     25.64127          15.887079
# 243                     1.800000     44.00000          20.000000
# 244                     6.200000     26.00000           2.000000
# 245                     8.400000     49.00000          18.800000
#
# IndicatorCode  IC.TAX.TOTL.CP.ZS  IC.WRH.DURS  IC.WRH.PROC  IQ.SCI.MTHD  \
# 0                      36.300000   353.000000    11.000000         40.0
# 1                      36.500000          NaN          NaN         50.0
# 2                      72.700000   204.000000    17.000000         50.0
# 3                            NaN          NaN          NaN          NaN
# 4                            NaN          NaN          NaN          NaN
# ..                           ...          ...          ...          ...
# 241                    15.300000   108.000000    17.000000         80.0
# 242                    40.751323   160.494054    14.295135          NaN
# 243                    33.100000   184.000000    11.000000         60.0
# 244                    18.600000   208.000000    10.000000         40.0
# 245                    32.800000   448.000000    10.000000         50.0
#
# IndicatorCode  IQ.SCI.OVRL  IQ.SCI.PRDC  IQ.SCI.SRCE  SG.GEN.PARL.ZS  \
# 0                51.111100      73.3333         40.0       27.710843
# 1                72.222233      66.6667        100.0       20.714286
# 2                53.333367      80.0001         30.0       31.601732
# 3                      NaN          NaN          NaN             NaN
# 4                      NaN          NaN          NaN       39.285714
# ..                     ...          ...          ...             ...
# 241              80.000000      80.0000         80.0             NaN
# 242                    NaN          NaN          NaN       22.538369
# 243              55.555600      76.6668         30.0        0.000000
# 244              60.000033      80.0001         60.0       12.658228
# 245              62.222200      76.6666         60.0       31.481481
#
# IndicatorCode  SH.DTH.IMRT  SH.DTH.MORT  SH.DTH.NMRT  SH.DYN.MORT  \
# 0                  67399.0      94261.0      36242.0         91.1
# 1                    564.0        618.0        279.0         14.0
# 2                  20899.0      24269.0      14773.0         25.5
# 3                      NaN          NaN          NaN          NaN
# 4                      2.0          2.0          1.0          2.8
# ..                     ...          ...          ...          ...
# 241                 2705.0       3145.0       1771.0         21.1
# 242              4450352.0    5944556.0    2682438.0         42.5
# 243                27775.0      34351.0      18235.0         41.9
# 244                26636.0      38990.0      13188.0         64.0
# 245                25398.0      38087.0      12836.0         70.7
#
# IndicatorCode  SH.DYN.MORT.FE  SH.DYN.MORT.MA  SH.DYN.NMRT  SH.H2O.SAFE.RU.ZS  \
# 0                        87.4            94.6         35.5          47.000000
# 1                        12.5            15.3          6.2          95.200000
# 2                        24.0            26.8         15.5          81.800000
# 3                         NaN             NaN          NaN         100.000000
# 4                         2.6             3.1          1.4         100.000000
# ..                        ...             ...          ...                ...
# 241                      19.3            22.9         11.8          81.500000
# 242                      40.5            44.4         19.2          84.609876
# 243                      38.3            45.5         22.1                NaN
# 244                      58.9            68.9         21.4          51.300000
# 245                      64.9            76.1         23.5          67.300000
#
# IndicatorCode  SH.H2O.SAFE.UR.ZS  SH.H2O.SAFE.ZS  SH.MMR.DTHS  SH.MMR.RISK  \
# 0                      78.200000       55.300000       4300.0         52.0
# 1                      94.900000       95.100000         11.0       1900.0
# 2                      84.300000       83.600000       1300.0        240.0
# 3                     100.000000      100.000000          NaN          NaN
# 4                     100.000000      100.000000          NaN          NaN
# ..                           ...             ...          ...          ...
# 241                    50.700000       58.400000         69.0        490.0
# 242                    96.456467       90.966679     303000.0        180.0
# 243                          NaN             NaN       3300.0         60.0
# 244                    85.600000       65.400000       1400.0         79.0
# 245                    97.000000       76.900000       2400.0         52.0
#
# IndicatorCode  SH.MMR.RISK.ZS  SH.STA.ACSN  SH.STA.ACSN.RU  SH.STA.ACSN.UR  \
# 0                    1.926131    31.900000       27.000000       45.100000
# 1                    0.053361    93.200000       90.200000       95.500000
# 2                    0.419341    87.600000       82.200000       89.800000
# 3                         NaN    62.500000       62.500000       62.500000
# 4                         NaN   100.000000      100.000000      100.000000
# ..                        ...          ...             ...             ...
# 241                  0.205740    92.300000       90.200000       93.000000
# 242                  0.560068    67.522946       50.327703       82.184004
# 243                  1.658729          NaN             NaN             NaN
# 244                  1.258249    43.900000       35.700000       55.600000
# 245                  1.938964    36.800000       30.800000       49.300000
#
# IndicatorCode  SH.STA.MMRT  SI.POV.NAGP  SI.POV.NAHC  SI.POV.RUGP  \
# 0                    396.0          NaN          NaN          NaN
# 1                     29.0          NaN          NaN          NaN
# 2                    140.0          NaN          NaN          NaN
# 3                      NaN          NaN          NaN          NaN
# 4                      NaN          NaN          NaN          NaN
# ..                     ...          ...          ...          ...
# 241                   45.0          NaN          NaN          NaN
# 242                  216.0          NaN          NaN          NaN
# 243                  385.0          NaN          NaN          NaN
# 244                  224.0          NaN          NaN          NaN
# 245                  443.0          NaN          NaN          NaN
#
# IndicatorCode  SI.POV.RUHC  SI.POV.URGP  SI.POV.URHC  SP.DYN.IMRT.FE.IN  \
# 0                      NaN          NaN          NaN               62.1
# 1                      NaN          NaN          NaN               11.2
# 2                      NaN          NaN          NaN               20.5
# 3                      NaN          NaN          NaN                NaN
# 4                      NaN          NaN          NaN                1.9
# ..                     ...          ...          ...                ...
# 241                    NaN          NaN          NaN               16.6
# 242                    NaN          NaN          NaN               29.5
# 243                    NaN          NaN          NaN               30.4
# 244                    NaN          NaN          NaN               39.2
# 245                    NaN          NaN          NaN               41.2
#
# IndicatorCode  SP.DYN.IMRT.IN  SP.DYN.IMRT.MA.IN  SP.HOU.FEMA.ZS
# 0                        66.3               70.3             NaN
# 1                        12.5               13.7             NaN
# 2                        21.9               23.2             NaN
# 3                         NaN                NaN             NaN
# 4                         2.1                2.3             NaN
# ..                        ...                ...             ...
# 241                      18.0               19.4             NaN
# 242                      31.7               33.8             NaN
# 243                      33.8               37.1             NaN
# 244                      43.3               47.2             NaN
# 245                      46.6               51.8             NaN
#
# [246 rows x 104 columns]

# %%
merge = pd.merge(happiness, table, left_on = 'Country', right_on = 'CountryName', how='inner')
merge.drop(columns='CountryName', inplace=True)
merge
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Switzerland      Western Europe               1            7.587
# 1        Iceland      Western Europe               2            7.561
# 2        Denmark      Western Europe               3            7.527
# 3         Norway      Western Europe               4            7.522
# 4         Canada       North America               5            7.427
# ..           ...                 ...             ...              ...
# 134  Afghanistan       Southern Asia             153            3.575
# 135       Rwanda  Sub-Saharan Africa             154            3.465
# 136        Benin  Sub-Saharan Africa             155            3.340
# 137      Burundi  Sub-Saharan Africa             157            2.905
# 138         Togo  Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 4           0.03553                   1.32629  1.32261
# ..              ...                       ...      ...
# 134         0.03084                   0.31982  0.30285
# 135         0.03464                   0.22208  0.77370
# 136         0.03656                   0.28665  0.35386
# 137         0.08658                   0.01530  0.41587
# 138         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 134                   0.30335  0.23414                        0.09719
# 135                   0.42864  0.59201                        0.55191
# 136                   0.31910  0.48450                        0.08010
# 137                   0.22396  0.11850                        0.10062
# 138                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual  DT.AMT.BLAT.CD  DT.AMT.DLXF.CD  \
# 0       0.29678            2.51738             NaN             NaN
# 1       0.43630            2.70201             NaN             NaN
# 2       0.34139            2.49204             NaN             NaN
# 3       0.34699            2.46531             NaN             NaN
# 4       0.45811            2.45176             NaN             NaN
# ..          ...                ...             ...             ...
# 134     0.36510            1.95210      93356000.0     122152000.0
# 135     0.22628            0.67042       3782000.0      25047000.0
# 136     0.18260            1.63328      28067000.0      75306000.0
# 137     0.19727            1.83302       1526000.0      14720000.0
# 138     0.16681            1.56726      12614000.0      39955000.0
#
#      DT.AMT.DPNG.CD  DT.AMT.MLAT.CD  DT.AMT.OFFT.CD  DT.AMT.PBND.CD  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
# ..              ...             ...             ...             ...
# 134             0.0      28796000.0     122152000.0             0.0
# 135             0.0      21265000.0      25047000.0             0.0
# 136             0.0      47239000.0      75306000.0             0.0
# 137             0.0      13194000.0      14720000.0             0.0
# 138             0.0      10953000.0      23567000.0             0.0
#
#      DT.AMT.PCBK.CD  DT.AMT.PROP.CD  DT.AMT.PRVT.CD  DT.DIS.BLAT.CD  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
# ..              ...             ...             ...             ...
# 134             0.0             0.0             0.0      10075000.0
# 135             0.0             0.0             0.0      57762000.0
# 136             0.0             0.0             0.0      92186000.0
# 137             0.0             0.0             0.0      40261000.0
# 138             0.0      16388000.0      16388000.0      88861000.0
#
#      DT.DIS.DLXF.CD  DT.DIS.MLAT.CD  DT.DIS.OFFT.CD  DT.DIS.PCBK.CD  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
# ..              ...             ...             ...             ...
# 134    2.332300e+07    1.324800e+07    2.332300e+07             0.0
# 135    2.371440e+08    1.793820e+08    2.371440e+08             0.0
# 136    3.627700e+08    2.625880e+08    3.547740e+08       7996000.0
# 137    2.703072e+09    2.662811e+09    2.703072e+09             0.0
# 138    2.095820e+08    1.207210e+08    2.095820e+08             0.0
#
#      DT.DIS.PROP.CD  DT.DIS.PRVT.CD  DT.INT.BLAT.CD  DT.INT.DLXF.CD  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
# ..              ...             ...             ...             ...
# 134             0.0             0.0      49265000.0      60463000.0
# 135             0.0             0.0       4429000.0      39149000.0
# 136             0.0       7996000.0       4111000.0      19697000.0
# 137             0.0             0.0        604000.0       2783000.0
# 138             0.0             0.0       6106000.0      12871000.0
#
#      DT.INT.DPNG.CD  DT.INT.MLAT.CD  DT.INT.OFFT.CD  DT.INT.PBND.CD  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
# ..              ...             ...             ...             ...
# 134             0.0      11198000.0      60463000.0             0.0
# 135             0.0       8220000.0      12649000.0      26500000.0
# 136             0.0      15586000.0      19697000.0             0.0
# 137             0.0       2179000.0       2783000.0             0.0
# 138             0.0       6765000.0      12871000.0             0.0
#
#      DT.INT.PCBK.CD  DT.INT.PROP.CD  DT.INT.PRVT.CD  EN.BIR.THRD.NO  \
# 0               NaN             NaN             NaN             6.0
# 1               NaN             NaN             NaN             4.0
# 2               NaN             NaN             NaN             7.0
# 3               NaN             NaN             NaN             7.0
# 4               NaN             NaN             NaN            15.0
# ..              ...             ...             ...             ...
# 134             0.0             0.0             0.0            17.0
# 135             0.0             0.0      26500000.0            16.0
# 136             0.0             0.0             0.0            10.0
# 137             0.0             0.0             0.0            13.0
# 138             0.0             0.0             0.0            11.0
#
#      EN.FSH.THRD.NO  EN.HPT.THRD.NO  EN.MAM.THRD.NO  FB.AST.NPER.ZS  \
# 0               9.0            10.0             2.0             NaN
# 1              16.0             0.0             6.0             NaN
# 2              18.0             4.0             2.0        4.439221
# 3              23.0            14.0             7.0        1.306463
# 4              42.0            11.0            11.0        0.512870
# ..              ...             ...             ...             ...
# 134             5.0             5.0            10.0       13.488399
# 135             9.0             8.0            23.0             NaN
# 136            38.0            17.0            12.0             NaN
# 137            17.0             8.0            12.0       13.123959
# 138            35.0            12.0            11.0             NaN
#
#      FB.BNK.CAPA.ZS  IC.BUS.DFRN.XQ  IC.BUS.DISC.XQ  IC.BUS.EASE.XQ  \
# 0               NaN           76.04             0.0            26.0
# 1               NaN           78.93             7.0            19.0
# 2          7.627405           84.40             7.0             3.0
# 3               NaN           81.61             7.0             9.0
# 4          4.901776           80.07             8.0            14.0
# ..              ...             ...             ...             ...
# 134       12.222749           40.58             1.0           177.0
# 135             NaN           68.12             7.0            62.0
# 136             NaN           47.15             7.0           158.0
# 137       14.375473           48.82             8.0           152.0
# 138             NaN           49.03             7.0           150.0
#
#      IC.CRD.INFO.XQ  IC.CRD.PRVT.ZS  IC.CRD.PUBL.ZS  IC.CUS.DURS.EX  \
# 0               6.0            26.1             0.0             NaN
# 1               7.0           100.0             0.0             NaN
# 2               6.0             7.7             0.0             NaN
# 3               6.0           100.0             0.0             NaN
# 4               8.0           100.0             0.0             NaN
# ..              ...             ...             ...             ...
# 134             0.0             0.0             0.5             NaN
# 135             8.0            18.8             5.4             NaN
# 136             0.0             0.0             0.6             NaN
# 137             0.0             0.0             4.4             NaN
# 138             0.0             0.0             0.5             NaN
#
#      IC.ELC.DURS  IC.ELC.OUTG  IC.ELC.TIME  IC.FRM.BNKS.ZS  IC.FRM.CMPU.ZS  \
# 0            NaN          NaN         39.0             NaN             NaN
# 1            NaN          NaN         22.0             NaN             NaN
# 2            NaN          NaN         38.0             NaN             NaN
# 3            NaN          NaN         66.0             NaN             NaN
# 4            NaN          NaN        137.0             NaN             NaN
# ..           ...          ...          ...             ...             ...
# 134          NaN          NaN        114.0             NaN             NaN
# 135          NaN          NaN         34.0             NaN             NaN
# 136          NaN          NaN         90.0             NaN             NaN
# 137          NaN          NaN        158.0             NaN             NaN
# 138          NaN          NaN         51.0             NaN             NaN
#
#      IC.FRM.CORR.ZS  IC.FRM.CRIM.ZS  IC.FRM.DURS  IC.FRM.FEMM.ZS  \
# 0               NaN             NaN          NaN             NaN
# 1               NaN             NaN          NaN             NaN
# 2               NaN             NaN          NaN             NaN
# 3               NaN             NaN          NaN             NaN
# 4               NaN             NaN          NaN             NaN
# ..              ...             ...          ...             ...
# 134             NaN             NaN          NaN             NaN
# 135             NaN             NaN          NaN             NaN
# 136             NaN             NaN          NaN             NaN
# 137             NaN             NaN          NaN             NaN
# 138             NaN             NaN          NaN             NaN
#
#      IC.FRM.FEMO.ZS  IC.FRM.FREG.ZS  IC.FRM.ISOC.ZS  IC.FRM.OUTG.ZS  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
# ..              ...             ...             ...             ...
# 134             NaN             NaN             NaN             NaN
# 135             NaN             NaN             NaN             NaN
# 136             NaN             NaN             NaN             NaN
# 137             NaN             NaN             NaN             NaN
# 138             NaN             NaN             NaN             NaN
#
#      IC.FRM.TRNG.ZS  IC.GOV.DURS.ZS  IC.ISV.DURS  IC.LGL.CRED.XQ  IC.LGL.DURS  \
# 0               NaN             NaN          3.0             6.0        390.0
# 1               NaN             NaN          1.0             5.0        417.0
# 2               NaN             NaN          1.0             8.0        410.0
# 3               NaN             NaN          0.9             5.0        280.0
# 4               NaN             NaN          0.8             9.0        570.0
# ..              ...             ...          ...             ...          ...
# 134             NaN             NaN          2.0             9.0       1642.0
# 135             NaN             NaN          2.5            11.0        230.0
# 136             NaN             NaN          4.0             6.0        750.0
# 137             NaN             NaN          5.0             2.0        832.0
# 138             NaN             NaN          3.0             6.0        488.0
#
#      IC.PRP.DURS  IC.PRP.PROC  IC.REG.COST.PC.ZS  IC.REG.DURS  IC.REG.PROC  \
# 0           16.0          4.0                2.0         10.0          6.0
# 1            3.5          3.0                2.2          4.0          5.0
# 2            4.0          3.0                0.2          3.0          4.0
# 3            3.0          1.0                0.9          4.0          4.0
# 4           16.5          6.0                0.4          1.5          2.0
# ..           ...          ...                ...          ...          ...
# 134        250.0          9.0               19.0          7.0          3.0
# 135         32.0          3.0               55.0          5.5          7.0
# 136        120.0          4.0               45.3         12.0          7.0
# 137         23.0          5.0               13.4          4.0          3.0
# 138        288.0          5.0               77.8         10.0          6.0
#
#      IC.TAX.DURS  IC.TAX.GIFT.ZS  IC.TAX.LABR.CP.ZS  IC.TAX.METG  \
# 0           63.0             NaN               17.7          NaN
# 1          140.0             NaN               17.7          NaN
# 2          130.0             NaN                3.0          NaN
# 3           83.0             NaN               15.9          NaN
# 4          131.0             NaN               12.7          NaN
# ..           ...             ...                ...          ...
# 134        275.0             NaN                0.0          NaN
# 135        109.0             NaN                5.6          NaN
# 136        270.0             NaN               26.4          NaN
# 137        274.0             NaN               10.2          NaN
# 138        270.0             NaN               23.1          NaN
#
#      IC.TAX.OTHR.CP.ZS  IC.TAX.PAYM  IC.TAX.PRFT.CP.ZS  IC.TAX.TOTL.CP.ZS  \
# 0                  1.8         19.0                9.3               28.8
# 1                  2.8         21.0                9.1               29.6
# 2                  2.8         10.0               18.7               24.5
# 3                  0.0          4.0               23.6               39.5
# 4                  4.5          8.0                3.9               21.1
# ..                 ...          ...                ...                ...
# 134               36.3         20.0                0.0               36.3
# 135                1.6         25.0               25.8               33.0
# 136               21.0         57.0               15.9               63.3
# 137                1.2         25.0               28.9               40.3
# 138               14.7         50.0               10.7               48.5
#
#      IC.WRH.DURS  IC.WRH.PROC  IQ.SCI.MTHD  IQ.SCI.OVRL  IQ.SCI.PRDC  \
# 0          156.0         13.0          NaN          NaN          NaN
# 1           84.0         17.0          NaN          NaN          NaN
# 2           64.0          7.0          NaN          NaN          NaN
# 3          110.5         11.0          NaN          NaN          NaN
# 4          249.0         12.0          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 134        353.0         11.0         40.0    51.111100      73.3333
# 135         77.0         11.0         60.0    73.333367      90.0001
# 136         88.0         13.0         40.0    66.666667      80.0000
# 137         99.0         14.0         40.0    55.555567      86.6667
# 138        165.0         12.0         40.0    65.555567      86.6667
#
#      IQ.SCI.SRCE  SG.GEN.PARL.ZS  SH.DTH.IMRT  SH.DTH.MORT  SH.DTH.NMRT  \
# 0            NaN       30.500000        291.0        334.0        231.0
# 1            NaN       41.269841          7.0          9.0          4.0
# 2            NaN       37.988827        150.0        187.0        129.0
# 3            NaN       39.644970        122.0        160.0         91.0
# 4            NaN       25.328947       1587.0       1824.0       1181.0
# ..           ...             ...          ...          ...          ...
# 134         40.0       27.710843      67399.0      94261.0      36242.0
# 135         70.0       63.750000      10445.0      14207.0       6299.0
# 136         80.0        7.228916      24069.0      37092.0      11955.0
# 137         40.0       30.476190      24956.0      36970.0      13236.0
# 138         70.0       17.582418      13077.0      19512.0       6694.0
#
#      SH.DYN.MORT  SH.DYN.MORT.FE  SH.DYN.MORT.MA  SH.DYN.NMRT  \
# 0            3.9             3.6             4.3          2.7
# 1            2.0             1.8             2.2          0.9
# 2            3.5             3.2             3.9          2.5
# 3            2.6             2.3             2.9          1.5
# 4            4.9             4.5             5.3          3.2
# ..           ...             ...             ...          ...
# 134         91.1            87.4            94.6         35.5
# 135         41.7            37.8            45.4         18.7
# 136         99.5            94.6           104.0         31.8
# 137         81.7            75.6            87.5         28.6
# 138         78.4            72.1            84.4         26.7
#
#      SH.H2O.SAFE.RU.ZS  SH.H2O.SAFE.UR.ZS  SH.H2O.SAFE.ZS  SH.MMR.DTHS  \
# 0                100.0              100.0           100.0          4.0
# 1                100.0              100.0           100.0          0.0
# 2                100.0              100.0           100.0          4.0
# 3                100.0              100.0           100.0          3.0
# 4                 99.0              100.0            99.8         27.0
# ..                 ...                ...             ...          ...
# 134               47.0               78.2            55.3       4300.0
# 135               71.9               86.6            76.1       1100.0
# 136               72.1               85.2            77.9       1600.0
# 137               73.8               91.1            75.9       3500.0
# 138               44.2               91.4            63.1        940.0
#
#      SH.MMR.RISK  SH.MMR.RISK.ZS  SH.STA.ACSN  SH.STA.ACSN.RU  SH.STA.ACSN.UR  \
# 0        12400.0        0.008047         99.9            99.8            99.9
# 1        14600.0        0.006866         98.8           100.0            98.7
# 2         9500.0        0.010535         99.6            99.6            99.6
# 3        11500.0        0.008699         98.1            98.3            98.0
# 4         8800.0        0.011329         99.8            99.0           100.0
# ..           ...             ...          ...             ...             ...
# 134         52.0        1.926131         31.9            27.0            45.1
# 135         85.0        1.178850         61.6            62.9            58.5
# 136         51.0        1.974066         19.7             7.3            35.6
# 137         23.0        4.272948         48.0            48.6            43.8
# 138         58.0        1.717699         11.6             2.9            24.7
#
#      SH.STA.MMRT  SI.POV.NAGP  SI.POV.NAHC  SI.POV.RUGP  SI.POV.RUHC  \
# 0            5.0          NaN          NaN          NaN          NaN
# 1            3.0          NaN          NaN          NaN          NaN
# 2            6.0          NaN          NaN          NaN          NaN
# 3            5.0          NaN          NaN          NaN          NaN
# 4            7.0          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 134        396.0          NaN          NaN          NaN          NaN
# 135        290.0          NaN          NaN          NaN          NaN
# 136        405.0          NaN          NaN          NaN          NaN
# 137        712.0          NaN          NaN          NaN          NaN
# 138        368.0          NaN          NaN          NaN          NaN
#
#      SI.POV.URGP  SI.POV.URHC  SP.DYN.IMRT.FE.IN  SP.DYN.IMRT.IN  \
# 0            NaN          NaN                3.1             3.4
# 1            NaN          NaN                1.4             1.6
# 2            NaN          NaN                2.6             2.9
# 3            NaN          NaN                1.8             2.0
# 4            NaN          NaN                4.0             4.3
# ..           ...          ...                ...             ...
# 134          NaN          NaN               62.1            66.3
# 135          NaN          NaN               27.8            31.1
# 136          NaN          NaN               59.2            64.2
# 137          NaN          NaN               48.0            54.1
# 138          NaN          NaN               46.7            52.3
#
#      SP.DYN.IMRT.MA.IN  SP.HOU.FEMA.ZS
# 0                  3.6             NaN
# 1                  1.7             NaN
# 2                  3.2             NaN
# 3                  2.2             NaN
# 4                  4.7             NaN
# ..                 ...             ...
# 134               70.3             NaN
# 135               34.2             NaN
# 136               68.9             NaN
# 137               60.0             NaN
# 138               57.6             NaN
#
# [139 rows x 115 columns]

# %%
df1=merge.loc[:,'Country':'Dystopia Residual']
df2=merge.loc[:,'SP.DYN.IMRT.IN']
example_subset = pd.concat([test1, test2], axis=1)
example_subset
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Switzerland      Western Europe               1            7.587
# 1        Iceland      Western Europe               2            7.561
# 2        Denmark      Western Europe               3            7.527
# 3         Norway      Western Europe               4            7.522
# 4         Canada       North America               5            7.427
# ..           ...                 ...             ...              ...
# 134  Afghanistan       Southern Asia             153            3.575
# 135       Rwanda  Sub-Saharan Africa             154            3.465
# 136        Benin  Sub-Saharan Africa             155            3.340
# 137      Burundi  Sub-Saharan Africa             157            2.905
# 138         Togo  Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 4           0.03553                   1.32629  1.32261
# ..              ...                       ...      ...
# 134         0.03084                   0.31982  0.30285
# 135         0.03464                   0.22208  0.77370
# 136         0.03656                   0.28665  0.35386
# 137         0.08658                   0.01530  0.41587
# 138         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 134                   0.30335  0.23414                        0.09719
# 135                   0.42864  0.59201                        0.55191
# 136                   0.31910  0.48450                        0.08010
# 137                   0.22396  0.11850                        0.10062
# 138                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual  SP.DYN.IMRT.IN
# 0       0.29678            2.51738             3.4
# 1       0.43630            2.70201             1.6
# 2       0.34139            2.49204             2.9
# 3       0.34699            2.46531             2.0
# 4       0.45811            2.45176             4.3
# ..          ...                ...             ...
# 134     0.36510            1.95210            66.3
# 135     0.22628            0.67042            31.1
# 136     0.18260            1.63328            64.2
# 137     0.19727            1.83302            54.1
# 138     0.16681            1.56726            52.3
#
# [139 rows x 13 columns]
