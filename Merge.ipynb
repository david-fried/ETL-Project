# %%
import pandas as pd
pd.options.display.max_columns = None
happiness = pd.read_csv('2015 Happiness Data.csv')
wdi = pd.read_csv('wdi_2015.csv')

# %%
print(len(happiness))
happiness.head(3)
# Out:
# 158
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204

# %%
print(len(wdi))
wdi.head(3)
# Out:
# 14762
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB                           Bird species, threatened
# 1  Arab World         ARB  Business extent of disclosure index (0=less di...
# 2  Arab World         ARB  Cost of business start-up procedures (% of GNI...
#
#        IndicatorCode  Year       Value
# 0     EN.BIR.THRD.NO  2015  297.000000
# 1     IC.BUS.DISC.XQ  2015    5.666667
# 2  IC.REG.COST.PC.ZS  2015   31.142857

# %%
print(wdi.IndicatorName.nunique())
print(wdi.IndicatorCode.nunique())
# Out:
# 103
# 103

# %%
x=list(wdi['IndicatorName'].unique())
indicators= [x[0]]
for i in range(1, len(x)-1):
    if x[i+1].split()[0:2] != x[i].split()[0:2]:
        indicators.append(x[i+1])
print(f'approximation of number of indicators: {len(indicators)}')
indicators
# Out:
# approximation of number of indicators: 65
# ['Bird species, threatened',
#  'Cost of business start-up procedures (% of GNI per capita)',
#  'Depth of credit information index (0=low to 8=high)',
#  'Distance to frontier score (0=lowest performance to 100=frontier)',
#  'Ease of doing business index (1=most business-friendly regulations)',
#  'Fish species, threatened',
#  'Improved sanitation facilities (% of population with access)',
#  'Improved water source (% of population with access)',
#  'Labor tax and contributions (% of commercial profits)',
#  'Lifetime risk of maternal death (%)',
#  'Mammal species, threatened',
#  'Maternal mortality ratio (modeled estimate, per 100,000 live births)',
#  'Mortality rate, infant (per 1,000 live births)',
#  'Number of maternal deaths',
#  'Other taxes payable by businesses (% of commercial profits)',
#  'Plant species (higher), threatened',
#  'Private credit bureau coverage (% of adults)',
#  'Procedures to build a warehouse (number)',
#  'Profit tax (% of commercial profits)',
#  'Proportion of seats held by women in national parliaments (%)',
#  'Public credit registry coverage (% of adults)',
#  'Start-up procedures to register a business (number)',
#  'Strength of legal rights index (0=weak to 12=strong)',
#  'Tax payments (number)',
#  'Time required to build a warehouse (days)',
#  'Time to prepare and pay taxes (hours)',
#  'Total tax rate (% of commercial profits)',
#  'Methodology assessment of statistical capacity (scale 0 - 100)',
#  'Overall level of statistical capacity (scale 0 - 100)',
#  'Periodicity and timeliness assessment of statistical capacity (scale 0 - 100)',
#  'Source data assessment of statistical capacity (scale 0 - 100)',
#  'Bank capital to assets ratio (%)',
#  'Bank nonperforming loans to total gross loans (%)',
#  'Disbursements on external debt, long-term (DIS, current US$)',
#  'Interest payments on external debt, long-term (INT, current US$)',
#  'Number of infant deaths',
#  'PPG, bilateral (AMT, current US$)',
#  'PPG, bonds (AMT, current US$)',
#  'PPG, commercial banks (AMT, current US$)',
#  'PPG, multilateral (AMT, current US$)',
#  'PPG, official creditors (AMT, current US$)',
#  'PPG, other private creditors (AMT, current US$)',
#  'PPG, private creditors (AMT, current US$)',
#  'Principal repayments on external debt, long-term (AMT, current US$)',
#  'Average time to clear exports through customs (days)',
#  'Delay in obtaining an electrical connection (days)',
#  'Firms competing against unregistered firms (% of firms)',
#  'Firms expected to give gifts in meetings with tax officials (% of firms)',
#  'Firms formally registered when operations started (% of firms)',
#  'Firms offering formal training (% of firms)',
#  'Firms using banks to finance investment (% of firms)',
#  'Firms with female participation in ownership (% of firms)',
#  'Informal payments to public officials (% of firms)',
#  'Internationally-recognized quality certification (% of firms)',
#  'Losses due to theft, robbery, vandalism, and arson (% sales)',
#  'Number of visits or required meetings with tax officials',
#  'Power outages in firms in a typical month (number)',
#  'Time required to obtain an operating license (days)',
#  'Time spent dealing with the requirements of government regulations (% of senior management time)',
#  'Value lost due to electrical outages (% of sales)',
#  'Poverty gap at national poverty lines (%)',
#  'Poverty headcount ratio at national poverty lines (% of population)',
#  'Rural poverty gap at national poverty lines (%)',
#  'Urban poverty gap at national poverty lines (%)',
#  'Female headed households (% of households with a female head)']

# %%
for items,row in wdi.iterrows():
    print(items, row.IndicatorCode, row.IndicatorName, )
# Out:
# 0 EN.BIR.THRD.NO Bird species, threatened
# 1 IC.BUS.DISC.XQ Business extent of disclosure index (0=less disclosure to 10=more disclosure)
# 2 IC.REG.COST.PC.ZS Cost of business start-up procedures (% of GNI per capita)
# 3 IC.CRD.INFO.XQ Depth of credit information index (0=low to 8=high)
# 4 IC.BUS.DFRN.XQ Distance to frontier score (0=lowest performance to 100=frontier)
# 5 IC.BUS.EASE.XQ Ease of doing business index (1=most business-friendly regulations)
# 6 EN.FSH.THRD.NO Fish species, threatened
# 7 SH.STA.ACSN Improved sanitation facilities (% of population with access)
# 8 SH.STA.ACSN.RU Improved sanitation facilities, rural (% of rural population with access)
# 9 SH.STA.ACSN.UR Improved sanitation facilities, urban (% of urban population with access)
# 10 SH.H2O.SAFE.ZS Improved water source (% of population with access)
# 11 SH.H2O.SAFE.RU.ZS Improved water source, rural (% of rural population with access)
# 12 SH.H2O.SAFE.UR.ZS Improved water source, urban (% of urban population with access)
# 13 IC.TAX.LABR.CP.ZS Labor tax and contributions (% of commercial profits)
# 14 SH.MMR.RISK.ZS Lifetime risk of maternal death (%)
# 15 SH.MMR.RISK Lifetime risk of maternal death (1 in: rate varies by country)
# 16 EN.MAM.THRD.NO Mammal species, threatened
# 17 SH.STA.MMRT Maternal mortality ratio (modeled estimate, per 100,000 live births)
# 18 SP.DYN.IMRT.IN Mortality rate, infant (per 1,000 live births)
# 19 SP.DYN.IMRT.FE.IN Mortality rate, infant, female (per 1,000 live births)
# 20 SP.DYN.IMRT.MA.IN Mortality rate, infant, male (per 1,000 live births)
# 21 SH.DYN.NMRT Mortality rate, neonatal (per 1,000 live births)
# 22 SH.DYN.MORT Mortality rate, under-5 (per 1,000)
# 23 SH.DYN.MORT.FE Mortality rate, under-5, female (per 1,000 live births)
# 24 SH.DYN.MORT.MA Mortality rate, under-5, male (per 1,000 live births)
# 25 SH.MMR.DTHS Number of maternal deaths
# 26 IC.TAX.OTHR.CP.ZS Other taxes payable by businesses (% of commercial profits)
# 27 EN.HPT.THRD.NO Plant species (higher), threatened
# 28 IC.CRD.PRVT.ZS Private credit bureau coverage (% of adults)
# 29 IC.WRH.PROC Procedures to build a warehouse (number)
# 30 IC.PRP.PROC Procedures to register property (number)
# 31 IC.TAX.PRFT.CP.ZS Profit tax (% of commercial profits)
# 32 SG.GEN.PARL.ZS Proportion of seats held by women in national parliaments (%)
# 33 IC.CRD.PUBL.ZS Public credit registry coverage (% of adults)
# 34 IC.REG.PROC Start-up procedures to register a business (number)
# 35 IC.LGL.CRED.XQ Strength of legal rights index (0=weak to 12=strong)
# 36 IC.TAX.PAYM Tax payments (number)
# 37 IC.WRH.DURS Time required to build a warehouse (days)
# 38 IC.LGL.DURS Time required to enforce a contract (days)
# 39 IC.ELC.TIME Time required to get electricity (days)
# 40 IC.PRP.DURS Time required to register property (days)
# 41 IC.REG.DURS Time required to start a business (days)
# 42 IC.TAX.DURS Time to prepare and pay taxes (hours)
# 43 IC.ISV.DURS Time to resolve insolvency (years)
# 44 IC.TAX.TOTL.CP.ZS Total tax rate (% of commercial profits)
# 45 EN.BIR.THRD.NO Bird species, threatened
# 46 IC.BUS.DISC.XQ Business extent of disclosure index (0=less disclosure to 10=more disclosure)
# 47 IC.REG.COST.PC.ZS Cost of business start-up procedures (% of GNI per capita)
# 48 IC.CRD.INFO.XQ Depth of credit information index (0=low to 8=high)
# 49 IC.BUS.DFRN.XQ Distance to frontier score (0=lowest performance to 100=frontier)
# 50 IC.BUS.EASE.XQ Ease of doing business index (1=most business-friendly regulations)
# 51 EN.FSH.THRD.NO Fish species, threatened
# 52 SH.STA.ACSN Improved sanitation facilities (% of population with access)
# 53 SH.STA.ACSN.RU Improved sanitation facilities, rural (% of rural population with access)
# 54 SH.STA.ACSN.UR Improved sanitation facilities, urban (% of urban population with access)
# 55 SH.H2O.SAFE.ZS Improved water source (% of population with access)
# 56 SH.H2O.SAFE.RU.ZS Improved water source, rural (% of rural population with access)
# 57 SH.H2O.SAFE.UR.ZS Improved water source, urban (% of urban population with access)
# 58 IC.TAX.LABR.CP.ZS Labor tax and contributions (% of commercial profits)
# 59 SH.MMR.RISK.ZS Lifetime risk of maternal death (%)
# 60 SH.MMR.RISK Lifetime risk of maternal death (1 in: rate varies by country)
# 61 EN.MAM.THRD.NO Mammal species, threatened
# 62 SH.STA.MMRT Maternal mortality ratio (modeled estimate, per 100,000 live births)
# 63 IQ.SCI.MTHD Methodology assessment of statistical capacity (scale 0 - 100)
# 64 SP.DYN.IMRT.IN Mortality rate, infant (per 1,000 live births)
# 65 SP.DYN.IMRT.FE.IN Mortality rate, infant, female (per 1,000 live births)
# 66 SP.DYN.IMRT.MA.IN Mortality rate, infant, male (per 1,000 live births)
# 67 SH.DYN.NMRT Mortality rate, neonatal (per 1,000 live births)
# 68 SH.DYN.MORT Mortality rate, under-5 (per 1,000)
# 69 SH.DYN.MORT.FE Mortality rate, under-5, female (per 1,000 live births)
# 70 SH.DYN.MORT.MA Mortality rate, under-5, male (per 1,000 live births)
# 71 SH.MMR.DTHS Number of maternal deaths
# 72 IC.TAX.OTHR.CP.ZS Other taxes payable by businesses (% of commercial profits)
# 73 IQ.SCI.OVRL Overall level of statistical capacity (scale 0 - 100)
# 74 IQ.SCI.PRDC Periodicity and timeliness assessment of statistical capacity (scale 0 - 100)
# 75 EN.HPT.THRD.NO Plant species (higher), threatened
# 76 IC.CRD.PRVT.ZS Private credit bureau coverage (% of adults)
# 77 IC.WRH.PROC Procedures to build a warehouse (number)
# 78 IC.PRP.PROC Procedures to register property (number)
# 79 IC.TAX.PRFT.CP.ZS Profit tax (% of commercial profits)
# 80 SG.GEN.PARL.ZS Proportion of seats held by women in national parliaments (%)
# 81 IC.CRD.PUBL.ZS Public credit registry coverage (% of adults)
# 82 IQ.SCI.SRCE Source data assessment of statistical capacity (scale 0 - 100)
# 83 IC.REG.PROC Start-up procedures to register a business (number)
# 84 IC.LGL.CRED.XQ Strength of legal rights index (0=weak to 12=strong)
# 85 IC.TAX.PAYM Tax payments (number)
# 86 IC.WRH.DURS Time required to build a warehouse (days)
# 87 IC.LGL.DURS Time required to enforce a contract (days)
# 88 IC.ELC.TIME Time required to get electricity (days)
# 89 IC.PRP.DURS Time required to register property (days)
# 90 IC.REG.DURS Time required to start a business (days)
# 91 IC.TAX.DURS Time to prepare and pay taxes (hours)
# 92 IC.ISV.DURS Time to resolve insolvency (years)
# 93 IC.TAX.TOTL.CP.ZS Total tax rate (% of commercial profits)
# 94 FB.BNK.CAPA.ZS Bank capital to assets ratio (%)
# 95 FB.AST.NPER.ZS Bank nonperforming loans to total gross loans (%)
# 96 EN.BIR.THRD.NO Bird species, threatened
# 97 IC.BUS.DISC.XQ Business extent of disclosure index (0=less disclosure to 10=more disclosure)
# 98 IC.REG.COST.PC.ZS Cost of business start-up procedures (% of GNI per capita)
# 99 IC.CRD.INFO.XQ Depth of credit information index (0=low to 8=high)
# 100 IC.BUS.DFRN.XQ Distance to frontier score (0=lowest performance to 100=frontier)
# 101 IC.BUS.EASE.XQ Ease of doing business index (1=most business-friendly regulations)
# 102 EN.FSH.THRD.NO Fish species, threatened
# 103 SH.STA.ACSN Improved sanitation facilities (% of population with access)
# 104 SH.STA.ACSN.RU Improved sanitation facilities, rural (% of rural population with access)
# 105 SH.STA.ACSN.UR Improved sanitation facilities, urban (% of urban population with access)
# 106 SH.H2O.SAFE.ZS Improved water source (% of population with access)
# 107 SH.H2O.SAFE.RU.ZS Improved water source, rural (% of rural population with access)
# 108 SH.H2O.SAFE.UR.ZS Improved water source, urban (% of urban population with access)
# 109 IC.TAX.LABR.CP.ZS Labor tax and contributions (% of commercial profits)
# 110 SH.MMR.RISK.ZS Lifetime risk of maternal death (%)
# 111 SH.MMR.RISK Lifetime risk of maternal death (1 in: rate varies by country)
# 112 EN.MAM.THRD.NO Mammal species, threatened
# 113 SH.STA.MMRT Maternal mortality ratio (modeled estimate, per 100,000 live births)
# 114 SP.DYN.IMRT.IN Mortality rate, infant (per 1,000 live births)
# 115 SP.DYN.IMRT.FE.IN Mortality rate, infant, female (per 1,000 live births)
# 116 SP.DYN.IMRT.MA.IN Mortality rate, infant, male (per 1,000 live births)
# 117 SH.DYN.NMRT Mortality rate, neonatal (per 1,000 live births)
# 118 SH.DYN.MORT Mortality rate, under-5 (per 1,000)
# 119 SH.DYN.MORT.FE Mortality rate, under-5, female (per 1,000 live births)
# 120 SH.DYN.MORT.MA Mortality rate, under-5, male (per 1,000 live births)
# 121 SH.MMR.DTHS Number of maternal deaths
# 122 IC.TAX.OTHR.CP.ZS Other taxes payable by businesses (% of commercial profits)
# 123 EN.HPT.THRD.NO Plant species (higher), threatened
# 124 IC.CRD.PRVT.ZS Private credit bureau coverage (% of adults)
# 125 IC.WRH.PROC Procedures to build a warehouse (number)
# 126 IC.PRP.PROC Procedures to register property (number)
# 127 IC.TAX.PRFT.CP.ZS Profit tax (% of commercial profits)
# 128 SG.GEN.PARL.ZS Proportion of seats held by women in national parliaments (%)
# 129 IC.CRD.PUBL.ZS Public credit registry coverage (% of adults)
# 130 IC.REG.PROC Start-up procedures to register a business (number)
# 131 IC.LGL.CRED.XQ Strength of legal rights index (0=weak to 12=strong)
# 132 IC.TAX.PAYM Tax payments (number)
# 133 IC.WRH.DURS Time required to build a warehouse (days)
# 134 IC.LGL.DURS Time required to enforce a contract (days)
# 135 IC.ELC.TIME Time required to get electricity (days)
# 136 IC.PRP.DURS Time required to register property (days)
# 137 IC.REG.DURS Time required to start a business (days)
# 138 IC.TAX.DURS Time to prepare and pay taxes (hours)
# 139 IC.ISV.DURS Time to resolve insolvency (years)
# 140 IC.TAX.TOTL.CP.ZS Total tax rate (% of commercial profits)
# 141 EN.BIR.THRD.NO Bird species, threatened
# 142 IC.BUS.DISC.XQ Business extent of disclosure index (0=less disclosure to 10=more disclosure)
# 143 IC.REG.COST.PC.ZS Cost of business start-up procedures (% of GNI per capita)
# 144 IC.CRD.INFO.XQ Depth of credit information index (0=low to 8=high)
# 145 IC.BUS.DFRN.XQ Distance to frontier score (0=lowest performance to 100=frontier)
# 146 IC.BUS.EASE.XQ Ease of doing business index (1=most business-friendly regulations)
# 147 EN.FSH.THRD.NO Fish species, threatened
# 148 SH.STA.ACSN Improved sanitation facilities (% of population with access)
# 149 SH.STA.ACSN.RU Improved sanitation facilities, rural (% of rural population with access)
# 150 SH.STA.ACSN.UR Improved sanitation facilities, urban (% of urban population with access)
# 151 SH.H2O.SAFE.ZS Improved water source (% of population with access)
# 152 SH.H2O.SAFE.RU.ZS Improved water source, rural (% of rural population with access)
# 153 SH.H2O.SAFE.UR.ZS Improved water source, urban (% of urban population with access)
# 154 IC.TAX.LABR.CP.ZS Labor tax and contributions (% of commercial profits)
# 155 SH.MMR.RISK.ZS Lifetime risk of maternal death (%)
# 156 SH.MMR.RISK Lifetime risk of maternal death (1 in: rate varies by country)
# 157 EN.MAM.THRD.NO Mammal species, threatened
# 158 SH.STA.MMRT Maternal mortality ratio (modeled estimate, per 100,000 live births)
# 159 SP.DYN.IMRT.IN Mortality rate, infant (per 1,000 live births)
# 160 SP.DYN.IMRT.FE.IN Mortality rate, infant, female (per 1,000 live births)
# 161 SP.DYN.IMRT.MA.IN Mortality rate, infant, male (per 1,000 live births)
# 162 SH.DYN.NMRT Mortality rate, neonatal (per 1,000 live births)
# 163 SH.DYN.MORT Mortality rate, under-5 (per 1,000)
# 164 SH.DYN.MORT.FE Mortality rate, under-5, female (per 1,000 live births)
# 165 SH.DYN.MORT.MA Mortality rate, under-5, male (per 1,000 live births)
# 166 SH.MMR.DTHS Number of maternal deaths
# 167 IC.TAX.OTHR.CP.ZS Other taxes payable by businesses (% of commercial profits)
# 168 EN.HPT.THRD.NO Plant species (higher), threatened
# 169 IC.CRD.PRVT.ZS Private credit bureau coverage (% of adults)
# 170 IC.WRH.PROC Procedures to build a warehouse (number)
# 171 IC.PRP.PROC Procedures to register property (number)
# 172 IC.TAX.PRFT.CP.ZS Profit tax (% of commercial profits)
# 173 SG.GEN.PARL.ZS Proportion of seats held by women in national parliaments (%)
# 174 IC.CRD.PUBL.ZS Public credit registry coverage (% of adults)
# 175 IC.REG.PROC Start-up procedures to register a business (number)
# 176 IC.LGL.CRED.XQ Strength of legal rights index (0=weak to 12=strong)
# 177 IC.TAX.PAYM Tax payments (number)
# 178 IC.WRH.DURS Time required to build a warehouse (days)
# 179 IC.LGL.DURS Time required to enforce a contract (days)
# 180 IC.ELC.TIME Time required to get electricity (days)
# 181 IC.PRP.DURS Time required to register property (days)
# 182 IC.REG.DURS Time required to start a business (days)
# 183 IC.TAX.DURS Time to prepare and pay taxes (hours)
# 184 IC.ISV.DURS Time to resolve insolvency (years)
# 185 IC.TAX.TOTL.CP.ZS Total tax rate (% of commercial profits)
# 186 EN.BIR.THRD.NO Bird species, threatened
# 187 IC.BUS.DISC.XQ Business extent of disclosure index (0=less disclosure to 10=more disclosure)
# 188 IC.REG.COST.PC.ZS Cost of business start-up procedures (% of GNI per capita)
# 189 IC.CRD.INFO.XQ Depth of credit information index (0=low to 8=high)
# 190 DT.DIS.DLXF.CD Disbursements on external debt, long-term (DIS, current US$)
# 191 IC.BUS.DFRN.XQ Distance to frontier score (0=lowest performance to 100=frontier)
# 192 IC.BUS.EASE.XQ Ease of doing business index (1=most business-friendly regulations)
# 193 EN.FSH.THRD.NO Fish species, threatened
# 194 SH.STA.ACSN Improved sanitation facilities (% of population with access)
# 195 SH.STA.ACSN.RU Improved sanitation facilities, rural (% of rural population with access)
# 196 SH.STA.ACSN.UR Improved sanitation facilities, urban (% of urban population with access)
# 197 SH.H2O.SAFE.ZS Improved water source (% of population with access)
# 198 SH.H2O.SAFE.RU.ZS Improved water source, rural (% of rural population with access)
# 199 SH.H2O.SAFE.UR.ZS Improved water source, urban (% of urban population with access)
# 200 DT.INT.DLXF.CD Interest payments on external debt, long-term (INT, current US$)
# 201 DT.INT.DPNG.CD Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)
# 202 IC.TAX.LABR.CP.ZS Labor tax and contributions (% of commercial profits)
# 203 SH.MMR.RISK.ZS Lifetime risk of maternal death (%)
# 204 SH.MMR.RISK Lifetime risk of maternal death (1 in: rate varies by country)
# 205 EN.MAM.THRD.NO Mammal species, threatened
# 206 SH.STA.MMRT Maternal mortality ratio (modeled estimate, per 100,000 live births)
# 207 IQ.SCI.MTHD Methodology assessment of statistical capacity (scale 0 - 100)
# 208 SP.DYN.IMRT.IN Mortality rate, infant (per 1,000 live births)
# 209 SP.DYN.IMRT.FE.IN Mortality rate, infant, female (per 1,000 live births)
# 210 SP.DYN.IMRT.MA.IN Mortality rate, infant, male (per 1,000 live births)
# 211 SH.DYN.NMRT Mortality rate, neonatal (per 1,000 live births)
# 212 SH.DYN.MORT Mortality rate, under-5 (per 1,000)
# 213 SH.DYN.MORT.FE Mortality rate, under-5, female (per 1,000 live births)
# 214 SH.DYN.MORT.MA Mortality rate, under-5, male (per 1,000 live births)
# 215 SH.DTH.IMRT Number of infant deaths
# 216 SH.MMR.DTHS Number of maternal deaths
# 217 SH.DTH.NMRT Number of neonatal deaths
# 218 SH.DTH.MORT Number of under-five deaths
# 219 IC.TAX.OTHR.CP.ZS Other taxes payable by businesses (% of commercial profits)
# 220 IQ.SCI.OVRL Overall level of statistical capacity (scale 0 - 100)
# 221 IQ.SCI.PRDC Periodicity and timeliness assessment of statistical capacity (scale 0 - 100)
# 222 EN.HPT.THRD.NO Plant species (higher), threatened
# 223 DT.AMT.BLAT.CD PPG, bilateral (AMT, current US$)
# 224 DT.DIS.BLAT.CD PPG, bilateral (DIS, current US$)
# 225 DT.INT.BLAT.CD PPG, bilateral (INT, current US$)
# 226 DT.AMT.PBND.CD PPG, bonds (AMT, current US$)
# 227 DT.INT.PBND.CD PPG, bonds (INT, current US$)
# 228 DT.AMT.PCBK.CD PPG, commercial banks (AMT, current US$)
# 229 DT.DIS.PCBK.CD PPG, commercial banks (DIS, current US$)
# 230 DT.INT.PCBK.CD PPG, commercial banks (INT, current US$)
# 231 DT.AMT.MLAT.CD PPG, multilateral (AMT, current US$)
# 232 DT.DIS.MLAT.CD PPG, multilateral (DIS, current US$)
# 233 DT.INT.MLAT.CD PPG, multilateral (INT, current US$)
# 234 DT.AMT.OFFT.CD PPG, official creditors (AMT, current US$)
# 235 DT.DIS.OFFT.CD PPG, official creditors (DIS, current US$)
# 236 DT.INT.OFFT.CD PPG, official creditors (INT, current US$)
# 237 DT.AMT.PROP.CD PPG, other private creditors (AMT, current US$)
# 238 DT.DIS.PROP.CD PPG, other private creditors (DIS, current US$)
# 239 DT.INT.PROP.CD PPG, other private creditors (INT, current US$)
# 240 DT.AMT.PRVT.CD PPG, private creditors (AMT, current US$)
# 241 DT.DIS.PRVT.CD PPG, private creditors (DIS, current US$)
# 242 DT.INT.PRVT.CD PPG, private creditors (INT, current US$)
# 243 DT.AMT.DLXF.CD Principal repayments on external debt, long-term (AMT, current US$)
# 244 DT.AMT.DPNG.CD Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)
# 245 IC.CRD.PRVT.ZS Private credit bureau coverage (% of adults)
# 246 IC.WRH.PROC Procedures to build a warehouse (number)
# 247 IC.PRP.PROC Procedures to register property (number)
# 248 IC.TAX.PRFT.CP.ZS Profit tax (% of commercial profits)
# 249 SG.GEN.PARL.ZS Proportion of seats held by women in national parliaments (%)
# 250 IC.CRD.PUBL.ZS Public credit registry coverage (% of adults)
# 251 IQ.SCI.SRCE Source data assessment of statistical capacity (scale 0 - 100)
# 252 IC.REG.PROC Start-up procedures to register a business (number)
# 253 IC.LGL.CRED.XQ Strength of legal rights index (0=weak to 12=strong)
# 254 IC.TAX.PAYM Tax payments (number)
# 255 IC.WRH.DURS Time required to build a warehouse (days)
# 256 IC.LGL.DURS Time required to enforce a contract (days)
# 257 IC.ELC.TIME Time required to get electricity (days)
# 258 IC.PRP.DURS Time required to register property (days)
# 259 IC.REG.DURS Time required to start a business (days)
# 260 IC.TAX.DURS Time to prepare and pay taxes (hours)
# 261 IC.ISV.DURS Time to resolve insolvency (years)
# 262 IC.TAX.TOTL.CP.ZS Total tax rate (% of commercial profits)
# 263 FB.BNK.CAPA.ZS Bank capital to assets ratio (%)
# 264 FB.AST.NPER.ZS Bank nonperforming loans to total gross loans (%)
# 265 EN.BIR.THRD.NO Bird species, threatened
# 266 IC.BUS.DISC.XQ Business extent of disclosure index (0=less disclosure to 10=more disclosure)
# 267 IC.REG.COST.PC.ZS Cost of business start-up procedures (% of GNI per capita)
# 268 IC.CRD.INFO.XQ Depth of credit information index (0=low to 8=high)
# 269 IC.BUS.DFRN.XQ Distance to frontier score (0=lowest performance to 100=frontier)
# 270 IC.BUS.EASE.XQ Ease of doing business index (1=most business-friendly regulations)
# 271 EN.FSH.THRD.NO Fish species, threatened
# 272 SH.STA.ACSN Improved sanitation facilities (% of population with access)
# 273 SH.STA.ACSN.RU Improved sanitation facilities, rural (% of rural population with access)
# 274 SH.STA.ACSN.UR Improved sanitation facilities, urban (% of urban population with access)
# 275 SH.H2O.SAFE.ZS Improved water source (% of population with access)
# 276 SH.H2O.SAFE.RU.ZS Improved water source, rural (% of rural population with access)
# 277 SH.H2O.SAFE.UR.ZS Improved water source, urban (% of urban population with access)
# 278 IC.TAX.LABR.CP.ZS Labor tax and contributions (% of commercial profits)
# 279 SH.MMR.RISK.ZS Lifetime risk of maternal death (%)
# 280 SH.MMR.RISK Lifetime risk of maternal death (1 in: rate varies by country)
# 281 EN.MAM.THRD.NO Mammal species, threatened
# 282 SH.STA.MMRT Maternal mortality ratio (modeled estimate, per 100,000 live births)
# 283 SP.DYN.IMRT.IN Mortality rate, infant (per 1,000 live births)
# 284 SP.DYN.IMRT.FE.IN Mortality rate, infant, female (per 1,000 live births)
# 285 SP.DYN.IMRT.MA.IN Mortality rate, infant, male (per 1,000 live births)
# 286 SH.DYN.NMRT Mortality rate, neonatal (per 1,000 live births)
# 287 SH.DYN.MORT Mortality rate, under-5 (per 1,000)
# 288 SH.DYN.MORT.FE Mortality rate, under-5, female (per 1,000 live births)
# 289 SH.DYN.MORT.MA Mortality rate, under-5, male (per 1,000 live births)
# 290 SH.MMR.DTHS Number of maternal deaths
# 291 IC.TAX.OTHR.CP.ZS Other taxes payable by businesses (% of commercial profits)
# 292 EN.HPT.THRD.NO Plant species (higher), threatened
# 293 IC.CRD.PRVT.ZS Private credit bureau coverage (% of adults)
# 294 IC.WRH.PROC Procedures to build a warehouse (number)
# 295 IC.PRP.PROC Procedures to register property (number)
# 296 IC.TAX.PRFT.CP.ZS Profit tax (% of commercial profits)
# 297 SG.GEN.PARL.ZS Proportion of seats held by women in national parliaments (%)
# 298 IC.CRD.PUBL.ZS Public credit registry coverage (% of adults)
# 299 IC.REG.PROC Start-up procedures to register a business (number)
# 300 IC.LGL.CRED.XQ Strength of legal rights index (0=weak to 12=strong)
# 301 IC.TAX.PAYM Tax payments (number)
# 302 IC.WRH.DURS Time required to build a warehouse (days)
# 303 IC.LGL.DURS Time required to enforce a contract (days)
# 304 IC.ELC.TIME Time required to get electricity (days)
# 305 IC.PRP.DURS Time required to register property (days)
# 306 IC.REG.DURS Time required to start a business (days)
# 307 IC.TAX.DURS Time to prepare and pay taxes (hours)
# 308 IC.ISV.DURS Time to resolve insolvency (years)
# 309 IC.TAX.TOTL.CP.ZS Total tax rate (% of commercial profits)
# 310 FB.BNK.CAPA.ZS Bank capital to assets ratio (%)
# 311 FB.AST.NPER.ZS Bank nonperforming loans to total gross loans (%)
# 312 EN.BIR.THRD.NO Bird species, threatened
# 313 IC.BUS.DISC.XQ Business extent of disclosure index (0=less disclosure to 10=more disclosure)
# 314 IC.REG.COST.PC.ZS Cost of business start-up procedures (% of GNI per capita)
# 315 IC.CRD.INFO.XQ Depth of credit information index (0=low to 8=high)
# 316 IC.BUS.DFRN.XQ Distance to frontier score (0=lowest performance to 100=frontier)
# 317 IC.BUS.EASE.XQ Ease of doing business index (1=most business-friendly regulations)
# 318 EN.FSH.THRD.NO Fish species, threatened
# 319 SH.STA.ACSN Improved sanitation facilities (% of population with access)
# 320 SH.STA.ACSN.RU Improved sanitation facilities, rural (% of rural population with access)
# 321 SH.STA.ACSN.UR Improved sanitation facilities, urban (% of urban population with access)
# 322 SH.H2O.SAFE.ZS Improved water source (% of population with access)
# 323 SH.H2O.SAFE.RU.ZS Improved water source, rural (% of rural population with access)
# 324 SH.H2O.SAFE.UR.ZS Improved water source, urban (% of urban population with access)
# 325 IC.TAX.LABR.CP.ZS Labor tax and contributions (% of commercial profits)
# 326 SH.MMR.RISK.ZS Lifetime risk of maternal death (%)
# 327 SH.MMR.RISK Lifetime risk of maternal death (1 in: rate varies by country)
# 328 EN.MAM.THRD.NO Mammal species, threatened
# 329 SH.STA.MMRT Maternal mortality ratio (modeled estimate, per 100,000 live births)
# 330 SP.DYN.IMRT.IN Mortality rate, infant (per 1,000 live births)
# 331 SP.DYN.IMRT.FE.IN Mortality rate, infant, female (per 1,000 live births)
# 332 SP.DYN.IMRT.MA.IN Mortality rate, infant, male (per 1,000 live births)
# 333 SH.DYN.NMRT Mortality rate, neonatal (per 1,000 live births)
# 334 SH.DYN.MORT Mortality rate, under-5 (per 1,000)
# 335 SH.DYN.MORT.FE Mortality rate, under-5, female (per 1,000 live births)
# 336 SH.DYN.MORT.MA Mortality rate, under-5, male (per 1,000 live births)
# 337 SH.MMR.DTHS Number of maternal deaths
# 338 IC.TAX.OTHR.CP.ZS Other taxes payable by businesses (% of commercial profits)
# 339 EN.HPT.THRD.NO Plant species (higher), threatened
# 340 IC.CRD.PRVT.ZS Private credit bureau coverage (% of adults)
# 341 IC.WRH.PROC Procedures to build a warehouse (number)
# 342 IC.PRP.PROC Procedures to register property (number)
# 343 IC.TAX.PRFT.CP.ZS Profit tax (% of commercial profits)
# 344 SG.GEN.PARL.ZS Proportion of seats held by women in national parliaments (%)
# 345 IC.CRD.PUBL.ZS Public credit registry coverage (% of adults)
# 346 IC.REG.PROC Start-up procedures to register a business (number)
# 347 IC.LGL.CRED.XQ Strength of legal rights index (0=weak to 12=strong)
# 348 IC.TAX.PAYM Tax payments (number)
# 349 IC.WRH.DURS Time required to build a warehouse (days)
# 350 IC.LGL.DURS Time required to enforce a contract (days)
# 351 IC.ELC.TIME Time required to get electricity (days)
# 352 IC.PRP.DURS Time required to register property (days)
# 353 IC.REG.DURS Time required to start a business (days)
# 354 IC.TAX.DURS Time to prepare and pay taxes (hours)
# 355 IC.ISV.DURS Time to resolve insolvency (years)
# 356 IC.TAX.TOTL.CP.ZS Total tax rate (% of commercial profits)
# 357 FB.BNK.CAPA.ZS Bank capital to assets ratio (%)
# 358 FB.AST.NPER.ZS Bank nonperforming loans to total gross loans (%)
# 359 EN.BIR.THRD.NO Bird species, threatened
# 360 IC.BUS.DISC.XQ Business extent of disclosure index (0=less disclosure to 10=more disclosure)
# 361 IC.REG.COST.PC.ZS Cost of business start-up procedures (% of GNI per capita)
# 362 IC.CRD.INFO.XQ Depth of credit information index (0=low to 8=high)
# 363 DT.DIS.DLXF.CD Disbursements on external debt, long-term (DIS, current US$)
# 364 IC.BUS.DFRN.XQ Distance to frontier score (0=lowest performance to 100=frontier)
# 365 IC.BUS.EASE.XQ Ease of doing business index (1=most business-friendly regulations)
# 366 EN.FSH.THRD.NO Fish species, threatened
# 367 SH.STA.ACSN Improved sanitation facilities (% of population with access)
# 368 SH.STA.ACSN.RU Improved sanitation facilities, rural (% of rural population with access)
# 369 SH.STA.ACSN.UR Improved sanitation facilities, urban (% of urban population with access)
# 370 SH.H2O.SAFE.ZS Improved water source (% of population with access)
# 371 SH.H2O.SAFE.RU.ZS Improved water source, rural (% of rural population with access)
# 372 SH.H2O.SAFE.UR.ZS Improved water source, urban (% of urban population with access)
# 373 DT.INT.DLXF.CD Interest payments on external debt, long-term (INT, current US$)
# 374 DT.INT.DPNG.CD Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)
# 375 IC.TAX.LABR.CP.ZS Labor tax and contributions (% of commercial profits)
# 376 SH.MMR.RISK.ZS Lifetime risk of maternal death (%)
# 377 SH.MMR.RISK Lifetime risk of maternal death (1 in: rate varies by country)
# 378 EN.MAM.THRD.NO Mammal species, threatened
# 379 SH.STA.MMRT Maternal mortality ratio (modeled estimate, per 100,000 live births)
# 380 IQ.SCI.MTHD Methodology assessment of statistical capacity (scale 0 - 100)
# 381 SP.DYN.IMRT.IN Mortality rate, infant (per 1,000 live births)
# 382 SP.DYN.IMRT.FE.IN Mortality rate, infant, female (per 1,000 live births)
# 383 SP.DYN.IMRT.MA.IN Mortality rate, infant, male (per 1,000 live births)
# 384 SH.DYN.NMRT Mortality rate, neonatal (per 1,000 live births)
# 385 SH.DYN.MORT Mortality rate, under-5 (per 1,000)
# 386 SH.DYN.MORT.FE Mortality rate, under-5, female (per 1,000 live births)
# 387 SH.DYN.MORT.MA Mortality rate, under-5, male (per 1,000 live births)
# 388 SH.DTH.IMRT Number of infant deaths
# 389 SH.MMR.DTHS Number of maternal deaths
# 390 SH.DTH.NMRT Number of neonatal deaths
# 391 SH.DTH.MORT Number of under-five deaths
# 392 IC.TAX.OTHR.CP.ZS Other taxes payable by businesses (% of commercial profits)
# 393 IQ.SCI.OVRL Overall level of statistical capacity (scale 0 - 100)
# 394 IQ.SCI.PRDC Periodicity and timeliness assessment of statistical capacity (scale 0 - 100)
# 395 EN.HPT.THRD.NO Plant species (higher), threatened
# 396 DT.AMT.BLAT.CD PPG, bilateral (AMT, current US$)
# 397 DT.DIS.BLAT.CD PPG, bilateral (DIS, current US$)
# 398 DT.INT.BLAT.CD PPG, bilateral (INT, current US$)
# 399 DT.AMT.PBND.CD PPG, bonds (AMT, current US$)
# 400 DT.INT.PBND.CD PPG, bonds (INT, current US$)
# 401 DT.AMT.PCBK.CD PPG, commercial banks (AMT, current US$)
# 402 DT.DIS.PCBK.CD PPG, commercial banks (DIS, current US$)
# 403 DT.INT.PCBK.CD PPG, commercial banks (INT, current US$)
# 404 DT.AMT.MLAT.CD PPG, multilateral (AMT, current US$)
# 405 DT.DIS.MLAT.CD PPG, multilateral (DIS, current US$)
# 406 DT.INT.MLAT.CD PPG, multilateral (INT, current US$)
# 407 DT.AMT.OFFT.CD PPG, official creditors (AMT, current US$)
# 408 DT.DIS.OFFT.CD PPG, official creditors (DIS, current US$)
# 409 DT.INT.OFFT.CD PPG, official creditors (INT, current US$)
# 410 DT.AMT.PROP.CD PPG, other private creditors (AMT, current US$)
# 411 DT.DIS.PROP.CD PPG, other private creditors (DIS, current US$)
# 412 DT.INT.PROP.CD PPG, other private creditors (INT, current US$)
# 413 DT.AMT.PRVT.CD PPG, private creditors (AMT, current US$)
# 414 DT.DIS.PRVT.CD PPG, private creditors (DIS, current US$)
# 415 DT.INT.PRVT.CD PPG, private creditors (INT, current US$)
# 416 DT.AMT.DLXF.CD Principal repayments on external debt, long-term (AMT, current US$)
# 417 DT.AMT.DPNG.CD Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)
# 418 IC.CRD.PRVT.ZS Private credit bureau coverage (% of adults)
# 419 IC.WRH.PROC Procedures to build a warehouse (number)
# 420 IC.PRP.PROC Procedures to register property (number)
# 421 IC.TAX.PRFT.CP.ZS Profit tax (% of commercial profits)
# 422 SG.GEN.PARL.ZS Proportion of seats held by women in national parliaments (%)
# 423 IC.CRD.PUBL.ZS Public credit registry coverage (% of adults)
# 424 IQ.SCI.SRCE Source data assessment of statistical capacity (scale 0 - 100)
# 425 IC.REG.PROC Start-up procedures to register a business (number)
# 426 IC.LGL.CRED.XQ Strength of legal rights index (0=weak to 12=strong)
# 427 IC.TAX.PAYM Tax payments (number)
# 428 IC.WRH.DURS Time required to build a warehouse (days)
# 429 IC.LGL.DURS Time required to enforce a contract (days)
# 430 IC.ELC.TIME Time required to get electricity (days)
# 431 IC.PRP.DURS Time required to register property (days)
# 432 IC.REG.DURS Time required to start a business (days)
# 433 IC.TAX.DURS Time to prepare and pay taxes (hours)
# 434 IC.ISV.DURS Time to resolve insolvency (years)
# 435 IC.TAX.TOTL.CP.ZS Total tax rate (% of commercial profits)
# 436 FB.BNK.CAPA.ZS Bank capital to assets ratio (%)
# 437 FB.AST.NPER.ZS Bank nonperforming loans to total gross loans (%)
# 438 EN.BIR.THRD.NO Bird species, threatened
# 439 IC.BUS.DISC.XQ Business extent of disclosure index (0=less disclosure to 10=more disclosure)
# 440 IC.REG.COST.PC.ZS Cost of business start-up procedures (% of GNI per capita)
# 441 IC.CRD.INFO.XQ Depth of credit information index (0=low to 8=high)
# 442 IC.BUS.DFRN.XQ Distance to frontier score (0=lowest performance to 100=frontier)
# 443 IC.BUS.EASE.XQ Ease of doing business index (1=most business-friendly regulations)
# 444 EN.FSH.THRD.NO Fish species, threatened
# 445 SH.STA.ACSN Improved sanitation facilities (% of population with access)
# 446 SH.STA.ACSN.RU Improved sanitation facilities, rural (% of rural population with access)
# 447 SH.STA.ACSN.UR Improved sanitation facilities, urban (% of urban population with access)
# 448 SH.H2O.SAFE.ZS Improved water source (% of population with access)
# 449 SH.H2O.SAFE.RU.ZS Improved water source, rural (% of rural population with access)
# 450 SH.H2O.SAFE.UR.ZS Improved water source, urban (% of urban population with access)
# 451 IC.TAX.LABR.CP.ZS Labor tax and contributions (% of commercial profits)
# 452 SH.MMR.RISK.ZS Lifetime risk of maternal death (%)
# 453 SH.MMR.RISK Lifetime risk of maternal death (1 in: rate varies by country)
# 454 EN.MAM.THRD.NO Mammal species, threatened
# 455 SH.STA.MMRT Maternal mortality ratio (modeled estimate, per 100,000 live births)
# 456 SP.DYN.IMRT.IN Mortality rate, infant (per 1,000 live births)
# 457 SP.DYN.IMRT.FE.IN Mortality rate, infant, female (per 1,000 live births)
# 458 SP.DYN.IMRT.MA.IN Mortality rate, infant, male (per 1,000 live births)
# 459 SH.DYN.NMRT Mortality rate, neonatal (per 1,000 live births)
# 460 SH.DYN.MORT Mortality rate, under-5 (per 1,000)
# 461 SH.DYN.MORT.FE Mortality rate, under-5, female (per 1,000 live births)
# 462 SH.DYN.MORT.MA Mortality rate, under-5, male (per 1,000 live births)
# 463 SH.MMR.DTHS Number of maternal deaths
# 464 IC.TAX.OTHR.CP.ZS Other taxes payable by businesses (% of commercial profits)
# 465 EN.HPT.THRD.NO Plant species (higher), threatened
# 466 IC.CRD.PRVT.ZS Private credit bureau coverage (% of adults)
# 467 IC.WRH.PROC Procedures to build a warehouse (number)
# 468 IC.PRP.PROC Procedures to register property (number)
# 469 IC.TAX.PRFT.CP.ZS Profit tax (% of commercial profits)
# 470 SG.GEN.PARL.ZS Proportion of seats held by women in national parliaments (%)
# 471 IC.CRD.PUBL.ZS Public credit registry coverage (% of adults)
# 472 IC.REG.PROC Start-up procedures to register a business (number)
# 473 IC.LGL.CRED.XQ Strength of legal rights index (0=weak to 12=strong)
# 474 IC.TAX.PAYM Tax payments (number)
# 475 IC.WRH.DURS Time required to build a warehouse (days)
# 476 IC.LGL.DURS Time required to enforce a contract (days)
# 477 IC.ELC.TIME Time required to get electricity (days)
# 478 IC.PRP.DURS Time required to register property (days)
# 479 IC.REG.DURS Time required to start a business (days)
# 480 IC.TAX.DURS Time to prepare and pay taxes (hours)
# 481 IC.ISV.DURS Time to resolve insolvency (years)
# 482 IC.TAX.TOTL.CP.ZS Total tax rate (% of commercial profits)
# 483 EN.BIR.THRD.NO Bird species, threatened
# 484 IC.BUS.DISC.XQ Business extent of disclosure index (0=less disclosure to 10=more disclosure)
# 485 IC.REG.COST.PC.ZS Cost of business start-up procedures (% of GNI per capita)
# 486 IC.CRD.INFO.XQ Depth of credit information index (0=low to 8=high)
# 487 IC.BUS.DFRN.XQ Distance to frontier score (0=lowest performance to 100=frontier)
# 488 IC.BUS.EASE.XQ Ease of doing business index (1=most business-friendly regulations)
# 489 EN.FSH.THRD.NO Fish species, threatened
# 490 SH.STA.ACSN Improved sanitation facilities (% of population with access)
# 491 SH.STA.ACSN.RU Improved sanitation facilities, rural (% of rural population with access)
# 492 SH.STA.ACSN.UR Improved sanitation facilities, urban (% of urban population with access)
# 493 SH.H2O.SAFE.ZS Improved water source (% of population with access)
# 494 SH.H2O.SAFE.RU.ZS Improved water source, rural (% of rural population with access)
# 495 SH.H2O.SAFE.UR.ZS Improved water source, urban (% of urban population with access)
# 496 IC.TAX.LABR.CP.ZS Labor tax and contributions (% of commercial profits)
# 497 SH.MMR.RISK.ZS Lifetime risk of maternal death (%)
# 498 SH.MMR.RISK Lifetime risk of maternal death (1 in: rate varies by country)
# 499 EN.MAM.THRD.NO Mammal species, threatened
# 500 SH.STA.MMRT Maternal mortality ratio (modeled estimate, per 100,000 live births)
# 501 IQ.SCI.MTHD Methodology assessment of statistical capacity (scale 0 - 100)
# 502 SP.DYN.IMRT.IN Mortality rate, infant (per 1,000 live births)
# 503 SP.DYN.IMRT.FE.IN Mortality rate, infant, female (per 1,000 live births)
# 504 SP.DYN.IMRT.MA.IN Mortality rate, infant, male (per 1,000 live births)
# 505 SH.DYN.NMRT Mortality rate, neonatal (per 1,000 live births)
# 506 SH.DYN.MORT Mortality rate, under-5 (per 1,000)
# 507 SH.DYN.MORT.FE Mortality rate, under-5, female (per 1,000 live births)
# 508 SH.DYN.MORT.MA Mortality rate, under-5, male (per 1,000 live births)
# 509 SH.MMR.DTHS Number of maternal deaths
# 510 IC.TAX.OTHR.CP.ZS Other taxes payable by businesses (% of commercial profits)
# 511 IQ.SCI.OVRL Overall level of statistical capacity (scale 0 - 100)
# 512 IQ.SCI.PRDC Periodicity and timeliness assessment of statistical capacity (scale 0 - 100)
# 513 EN.HPT.THRD.NO Plant species (higher), threatened
# 514 IC.CRD.PRVT.ZS Private credit bureau coverage (% of adults)
# 515 IC.WRH.PROC Procedures to build a warehouse (number)
# 516 IC.PRP.PROC Procedures to register property (number)
# 517 IC.TAX.PRFT.CP.ZS Profit tax (% of commercial profits)
# 518 SG.GEN.PARL.ZS Proportion of seats held by women in national parliaments (%)
# 519 IC.CRD.PUBL.ZS Public credit registry coverage (% of adults)
# 520 IQ.SCI.SRCE Source data assessment of statistical capacity (scale 0 - 100)
# 521 IC.REG.PROC Start-up procedures to register a business (number)
# 522 IC.LGL.CRED.XQ Strength of legal rights index (0=weak to 12=strong)
# 523 IC.TAX.PAYM Tax payments (number)
# 524 IC.WRH.DURS Time required to build a warehouse (days)
# 525 IC.LGL.DURS Time required to enforce a contract (days)
# 526 IC.ELC.TIME Time required to get electricity (days)
# 527 IC.PRP.DURS Time required to register property (days)
# 528 IC.REG.DURS Time required to start a business (days)
# 529 IC.TAX.DURS Time to prepare and pay taxes (hours)
# 530 IC.ISV.DURS Time to resolve insolvency (years)
# 531 IC.TAX.TOTL.CP.ZS Total tax rate (% of commercial profits)
# 532 EN.BIR.THRD.NO Bird species, threatened
# 533 IC.BUS.DISC.XQ Business extent of disclosure index (0=less disclosure to 10=more disclosure)
# 534 IC.REG.COST.PC.ZS Cost of business start-up procedures (% of GNI per capita)
# 535 IC.CRD.INFO.XQ Depth of credit information index (0=low to 8=high)
# 536 IC.BUS.DFRN.XQ Distance to frontier score (0=lowest performance to 100=frontier)
# 537 IC.BUS.EASE.XQ Ease of doing business index (1=most business-friendly regulations)
# 538 EN.FSH.THRD.NO Fish species, threatened
# 539 SH.STA.ACSN Improved sanitation facilities (% of population with access)
# 540 SH.STA.ACSN.RU Improved sanitation facilities, rural (% of rural population with access)
# 541 SH.STA.ACSN.UR Improved sanitation facilities, urban (% of urban population with access)
# 542 SH.H2O.SAFE.ZS Improved water source (% of population with access)
# 543 SH.H2O.SAFE.RU.ZS Improved water source, rural (% of rural population with access)
# 544 SH.H2O.SAFE.UR.ZS Improved water source, urban (% of urban population with access)
# 545 IC.TAX.LABR.CP.ZS Labor tax and contributions (% of commercial profits)
# 546 SH.MMR.RISK.ZS Lifetime risk of maternal death (%)
# 547 SH.MMR.RISK Lifetime risk of maternal death (1 in: rate varies by country)
# 548 EN.MAM.THRD.NO Mammal species, threatened
# 549 SH.STA.MMRT Maternal mortality ratio (modeled estimate, per 100,000 live births)
# 550 IQ.SCI.MTHD Methodology assessment of statistical capacity (scale 0 - 100)
# 551 SP.DYN.IMRT.IN Mortality rate, infant (per 1,000 live births)
# 552 SP.DYN.IMRT.FE.IN Mortality rate, infant, female (per 1,000 live births)
# 553 SP.DYN.IMRT.MA.IN Mortality rate, infant, male (per 1,000 live births)
# 554 SH.DYN.NMRT Mortality rate, neonatal (per 1,000 live births)
# 555 SH.DYN.MORT Mortality rate, under-5 (per 1,000)
# 556 SH.DYN.MORT.FE Mortality rate, under-5, female (per 1,000 live births)
# 557 SH.DYN.MORT.MA Mortality rate, under-5, male (per 1,000 live births)
# 558 SH.MMR.DTHS Number of maternal deaths
# 559 IC.TAX.OTHR.CP.ZS Other taxes payable by businesses (% of commercial profits)
# 560 IQ.SCI.OVRL Overall level of statistical capacity (scale 0 - 100)
# 561 IQ.SCI.PRDC Periodicity and timeliness assessment of statistical capacity (scale 0 - 100)
# 562 EN.HPT.THRD.NO Plant species (higher), threatened
# 563 IC.CRD.PRVT.ZS Private credit bureau coverage (% of adults)
# 564 IC.WRH.PROC Procedures to build a warehouse (number)
# 565 IC.PRP.PROC Procedures to register property (number)
# 566 IC.TAX.PRFT.CP.ZS Profit tax (% of commercial profits)
# 567 SG.GEN.PARL.ZS Proportion of seats held by women in national parliaments (%)
# 568 IC.CRD.PUBL.ZS Public credit registry coverage (% of adults)
# 569 IQ.SCI.SRCE Source data assessment of statistical capacity (scale 0 - 100)
# 570 IC.REG.PROC Start-up procedures to register a business (number)
# 571 IC.LGL.CRED.XQ Strength of legal rights index (0=weak to 12=strong)
# 572 IC.TAX.PAYM Tax payments (number)
# 573 IC.WRH.DURS Time required to build a warehouse (days)
# 574 IC.LGL.DURS Time required to enforce a contract (days)
# 575 IC.ELC.TIME Time required to get electricity (days)
# 576 IC.PRP.DURS Time required to register property (days)
# 577 IC.REG.DURS Time required to start a business (days)
# 578 IC.TAX.DURS Time to prepare and pay taxes (hours)
# 579 IC.ISV.DURS Time to resolve insolvency (years)
# 580 IC.TAX.TOTL.CP.ZS Total tax rate (% of commercial profits)
# 581 FB.BNK.CAPA.ZS Bank capital to assets ratio (%)
# 582 FB.AST.NPER.ZS Bank nonperforming loans to total gross loans (%)
# 583 EN.BIR.THRD.NO Bird species, threatened
# 584 IC.BUS.DISC.XQ Business extent of disclosure index (0=less disclosure to 10=more disclosure)
# 585 IC.REG.COST.PC.ZS Cost of business start-up procedures (% of GNI per capita)
# 586 IC.CRD.INFO.XQ Depth of credit information index (0=low to 8=high)
# 587 IC.BUS.DFRN.XQ Distance to frontier score (0=lowest performance to 100=frontier)
# 588 IC.BUS.EASE.XQ Ease of doing business index (1=most business-friendly regulations)
# 589 EN.FSH.THRD.NO Fish species, threatened
# 590 SH.STA.ACSN Improved sanitation facilities (% of population with access)
# 591 SH.STA.ACSN.RU Improved sanitation facilities, rural (% of rural population with access)
# 592 SH.STA.ACSN.UR Improved sanitation facilities, urban (% of urban population with access)
# 593 SH.H2O.SAFE.ZS Improved water source (% of population with access)
# 594 SH.H2O.SAFE.RU.ZS Improved water source, rural (% of rural population with access)
# 595 SH.H2O.SAFE.UR.ZS Improved water source, urban (% of urban population with access)
# 596 IC.TAX.LABR.CP.ZS Labor tax and contributions (% of commercial profits)
# 597 SH.MMR.RISK.ZS Lifetime risk of maternal death (%)
# 598 SH.MMR.RISK Lifetime risk of maternal death (1 in: rate varies by country)
# 599 EN.MAM.THRD.NO Mammal species, threatened
# 600 SH.STA.MMRT Maternal mortality ratio (modeled estimate, per 100,000 live births)
# 601 SP.DYN.IMRT.IN Mortality rate, infant (per 1,000 live births)
# 602 SP.DYN.IMRT.FE.IN Mortality rate, infant, female (per 1,000 live births)
# 603 SP.DYN.IMRT.MA.IN Mortality rate, infant, male (per 1,000 live births)
# 604 SH.DYN.NMRT Mortality rate, neonatal (per 1,000 live births)
# 605 SH.DYN.MORT Mortality rate, under-5 (per 1,000)
# 606 SH.DYN.MORT.FE Mortality rate, under-5, female (per 1,000 live births)
# 607 SH.DYN.MORT.MA Mortality rate, under-5, male (per 1,000 live births)
# 608 SH.DTH.IMRT Number of infant deaths
# 609 SH.MMR.DTHS Number of maternal deaths
# 610 SH.DTH.NMRT Number of neonatal deaths
# 611 SH.DTH.MORT Number of under-five deaths
# 612 IC.TAX.OTHR.CP.ZS Other taxes payable by businesses (% of commercial profits)
# 613 EN.HPT.THRD.NO Plant species (higher), threatened
# 614 IC.CRD.PRVT.ZS Private credit bureau coverage (% of adults)
# 615 IC.WRH.PROC Procedures to build a warehouse (number)
# 616 IC.PRP.PROC Procedures to register property (number)
# 617 IC.TAX.PRFT.CP.ZS Profit tax (% of commercial profits)
# 618 SG.GEN.PARL.ZS Proportion of seats held by women in national parliaments (%)
# 619 IC.CRD.PUBL.ZS Public credit registry coverage (% of adults)
# 620 IC.REG.PROC Start-up procedures to register a business (number)
# 621 IC.LGL.CRED.XQ Strength of legal rights index (0=weak to 12=strong)
# 622 IC.TAX.PAYM Tax payments (number)
# 623 IC.WRH.DURS Time required to build a warehouse (days)
# 624 IC.LGL.DURS Time required to enforce a contract (days)
# 625 IC.ELC.TIME Time required to get electricity (days)
# 626 IC.PRP.DURS Time required to register property (days)
# 627 IC.REG.DURS Time required to start a business (days)
# 628 IC.TAX.DURS Time to prepare and pay taxes (hours)
# 629 IC.ISV.DURS Time to resolve insolvency (years)
# 630 IC.TAX.TOTL.CP.ZS Total tax rate (% of commercial profits)
# 631 EN.BIR.THRD.NO Bird species, threatened
# 632 IC.BUS.DISC.XQ Business extent of disclosure index (0=less disclosure to 10=more disclosure)
# 633 IC.REG.COST.PC.ZS Cost of business start-up procedures (% of GNI per capita)
# 634 IC.CRD.INFO.XQ Depth of credit information index (0=low to 8=high)
# 635 IC.BUS.DFRN.XQ Distance to frontier score (0=lowest performance to 100=frontier)
# 636 IC.BUS.EASE.XQ Ease of doing business index (1=most business-friendly regulations)
# 637 EN.FSH.THRD.NO Fish species, threatened
# 638 SH.STA.ACSN Improved sanitation facilities (% of population with access)
# 639 SH.STA.ACSN.RU Improved sanitation facilities, rural (% of rural population with access)
# 640 SH.STA.ACSN.UR Improved sanitation facilities, urban (% of urban population with access)
# 641 SH.H2O.SAFE.ZS Improved water source (% of population with access)
# 642 SH.H2O.SAFE.RU.ZS Improved water source, rural (% of rural population with access)
# 643 SH.H2O.SAFE.UR.ZS Improved water source, urban (% of urban population with access)
# 644 IC.TAX.LABR.CP.ZS Labor tax and contributions (% of commercial profits)
# 645 SH.MMR.RISK.ZS Lifetime risk of maternal death (%)
# 646 SH.MMR.RISK Lifetime risk of maternal death (1 in: rate varies by country)
# 647 EN.MAM.THRD.NO Mammal species, threatened
# 648 SH.STA.MMRT Maternal mortality ratio (modeled estimate, per 100,000 live births)
# 649 SP.DYN.IMRT.IN Mortality rate, infant (per 1,000 live births)
# 650 SP.DYN.IMRT.FE.IN Mortality rate, infant, female (per 1,000 live births)
# 651 SP.DYN.IMRT.MA.IN Mortality rate, infant, male (per 1,000 live births)
# 652 SH.DYN.NMRT Mortality rate, neonatal (per 1,000 live births)
# 653 SH.DYN.MORT Mortality rate, under-5 (per 1,000)
# 654 SH.DYN.MORT.FE Mortality rate, under-5, female (per 1,000 live births)
# 655 SH.DYN.MORT.MA Mortality rate, under-5, male (per 1,000 live births)
# 656 SH.MMR.DTHS Number of maternal deaths
# 657 IC.TAX.OTHR.CP.ZS Other taxes payable by businesses (% of commercial profits)
# 658 EN.HPT.THRD.NO Plant species (higher), threatened
# 659 IC.CRD.PRVT.ZS Private credit bureau coverage (% of adults)
# 660 IC.WRH.PROC Procedures to build a warehouse (number)
# 661 IC.PRP.PROC Procedures to register property (number)
# 662 IC.TAX.PRFT.CP.ZS Profit tax (% of commercial profits)
# 663 SG.GEN.PARL.ZS Proportion of seats held by women in national parliaments (%)
# 664 IC.CRD.PUBL.ZS Public credit registry coverage (% of adults)
# 665 IC.REG.PROC Start-up procedures to register a business (number)
# 666 IC.LGL.CRED.XQ Strength of legal rights index (0=weak to 12=strong)
# 667 IC.TAX.PAYM Tax payments (number)
# 668 IC.WRH.DURS Time required to build a warehouse (days)
# 669 IC.LGL.DURS Time required to enforce a contract (days)
# 670 IC.ELC.TIME Time required to get electricity (days)
# 671 IC.PRP.DURS Time required to register property (days)
# 672 IC.REG.DURS Time required to start a business (days)
# 673 IC.TAX.DURS Time to prepare and pay taxes (hours)
# 674 IC.ISV.DURS Time to resolve insolvency (years)
# 675 IC.TAX.TOTL.CP.ZS Total tax rate (% of commercial profits)
# 676 FB.BNK.CAPA.ZS Bank capital to assets ratio (%)
# 677 FB.AST.NPER.ZS Bank nonperforming loans to total gross loans (%)
# 678 EN.BIR.THRD.NO Bird species, threatened
# 679 IC.BUS.DISC.XQ Business extent of disclosure index (0=less disclosure to 10=more disclosure)
# 680 IC.REG.COST.PC.ZS Cost of business start-up procedures (% of GNI per capita)
# 681 IC.CRD.INFO.XQ Depth of credit information index (0=low to 8=high)
# 682 IC.BUS.DFRN.XQ Distance to frontier score (0=lowest performance to 100=frontier)
# 683 IC.BUS.EASE.XQ Ease of doing business index (1=most business-friendly regulations)
# 684 EN.FSH.THRD.NO Fish species, threatened
# 685 SH.STA.ACSN Improved sanitation facilities (% of population with access)
# 686 SH.STA.ACSN.RU Improved sanitation facilities, rural (% of rural population with access)
# 687 SH.STA.ACSN.UR Improved sanitation facilities, urban (% of urban population with access)
# 688 SH.H2O.SAFE.ZS Improved water source (% of population with access)
# 689 SH.H2O.SAFE.RU.ZS Improved water source, rural (% of rural population with access)
# 690 SH.H2O.SAFE.UR.ZS Improved water source, urban (% of urban population with access)
# 691 IC.TAX.LABR.CP.ZS Labor tax and contributions (% of commercial profits)
# 692 SH.MMR.RISK.ZS Lifetime risk of maternal death (%)
# 693 SH.MMR.RISK Lifetime risk of maternal death (1 in: rate varies by country)
# 694 EN.MAM.THRD.NO Mammal species, threatened
# 695 SH.STA.MMRT Maternal mortality ratio (modeled estimate, per 100,000 live births)
# 696 SP.DYN.IMRT.IN Mortality rate, infant (per 1,000 live births)
# 697 SP.DYN.IMRT.FE.IN Mortality rate, infant, female (per 1,000 live births)
# 698 SP.DYN.IMRT.MA.IN Mortality rate, infant, male (per 1,000 live births)
# 699 SH.DYN.NMRT Mortality rate, neonatal (per 1,000 live births)
# 700 SH.DYN.MORT Mortality rate, under-5 (per 1,000)
# 701 SH.DYN.MORT.FE Mortality rate, under-5, female (per 1,000 live births)
# 702 SH.DYN.MORT.MA Mortality rate, under-5, male (per 1,000 live births)
# 703 SH.MMR.DTHS Number of maternal deaths
# 704 IC.TAX.OTHR.CP.ZS Other taxes payable by businesses (% of commercial profits)
# 705 EN.HPT.THRD.NO Plant species (higher), threatened
# 706 IC.CRD.PRVT.ZS Private credit bureau coverage (% of adults)
# 707 IC.WRH.PROC Procedures to build a warehouse (number)
# 708 IC.PRP.PROC Procedures to register property (number)
# 709 IC.TAX.PRFT.CP.ZS Profit tax (% of commercial profits)
# 710 SG.GEN.PARL.ZS Proportion of seats held by women in national parliaments (%)
# 711 IC.CRD.PUBL.ZS Public credit registry coverage (% of adults)
# 712 IC.REG.PROC Start-up procedures to register a business (number)
# ...
# 14526 IQ.SCI.SRCE Source data assessment of statistical capacity (scale 0 - 100)
# 14527 IC.REG.PROC Start-up procedures to register a business (number)
# 14528 IC.LGL.CRED.XQ Strength of legal rights index (0=weak to 12=strong)
# 14529 IC.TAX.PAYM Tax payments (number)
# 14530 IC.WRH.DURS Time required to build a warehouse (days)
# 14531 IC.LGL.DURS Time required to enforce a contract (days)
# 14532 IC.ELC.TIME Time required to get electricity (days)
# 14533 IC.PRP.DURS Time required to register property (days)
# 14534 IC.REG.DURS Time required to start a business (days)
# 14535 IC.TAX.DURS Time to prepare and pay taxes (hours)
# 14536 IC.TAX.TOTL.CP.ZS Total tax rate (% of commercial profits)
# 14537 EN.BIR.THRD.NO Bird species, threatened
# 14538 IC.BUS.DISC.XQ Business extent of disclosure index (0=less disclosure to 10=more disclosure)
# 14539 IC.REG.COST.PC.ZS Cost of business start-up procedures (% of GNI per capita)
# 14540 IC.CRD.INFO.XQ Depth of credit information index (0=low to 8=high)
# 14541 DT.DIS.DLXF.CD Disbursements on external debt, long-term (DIS, current US$)
# 14542 IC.BUS.DFRN.XQ Distance to frontier score (0=lowest performance to 100=frontier)
# 14543 IC.BUS.EASE.XQ Ease of doing business index (1=most business-friendly regulations)
# 14544 EN.FSH.THRD.NO Fish species, threatened
# 14545 DT.INT.DLXF.CD Interest payments on external debt, long-term (INT, current US$)
# 14546 DT.INT.DPNG.CD Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)
# 14547 IC.TAX.LABR.CP.ZS Labor tax and contributions (% of commercial profits)
# 14548 SH.MMR.RISK.ZS Lifetime risk of maternal death (%)
# 14549 SH.MMR.RISK Lifetime risk of maternal death (1 in: rate varies by country)
# 14550 EN.MAM.THRD.NO Mammal species, threatened
# 14551 SH.STA.MMRT Maternal mortality ratio (modeled estimate, per 100,000 live births)
# 14552 IQ.SCI.MTHD Methodology assessment of statistical capacity (scale 0 - 100)
# 14553 SP.DYN.IMRT.IN Mortality rate, infant (per 1,000 live births)
# 14554 SP.DYN.IMRT.FE.IN Mortality rate, infant, female (per 1,000 live births)
# 14555 SP.DYN.IMRT.MA.IN Mortality rate, infant, male (per 1,000 live births)
# 14556 SH.DYN.NMRT Mortality rate, neonatal (per 1,000 live births)
# 14557 SH.DYN.MORT Mortality rate, under-5 (per 1,000)
# 14558 SH.DYN.MORT.FE Mortality rate, under-5, female (per 1,000 live births)
# 14559 SH.DYN.MORT.MA Mortality rate, under-5, male (per 1,000 live births)
# 14560 SH.DTH.IMRT Number of infant deaths
# 14561 SH.MMR.DTHS Number of maternal deaths
# 14562 SH.DTH.NMRT Number of neonatal deaths
# 14563 SH.DTH.MORT Number of under-five deaths
# 14564 IC.TAX.OTHR.CP.ZS Other taxes payable by businesses (% of commercial profits)
# 14565 IQ.SCI.OVRL Overall level of statistical capacity (scale 0 - 100)
# 14566 IQ.SCI.PRDC Periodicity and timeliness assessment of statistical capacity (scale 0 - 100)
# 14567 EN.HPT.THRD.NO Plant species (higher), threatened
# 14568 DT.AMT.BLAT.CD PPG, bilateral (AMT, current US$)
# 14569 DT.DIS.BLAT.CD PPG, bilateral (DIS, current US$)
# 14570 DT.INT.BLAT.CD PPG, bilateral (INT, current US$)
# 14571 DT.AMT.PBND.CD PPG, bonds (AMT, current US$)
# 14572 DT.INT.PBND.CD PPG, bonds (INT, current US$)
# 14573 DT.AMT.PCBK.CD PPG, commercial banks (AMT, current US$)
# 14574 DT.DIS.PCBK.CD PPG, commercial banks (DIS, current US$)
# 14575 DT.INT.PCBK.CD PPG, commercial banks (INT, current US$)
# 14576 DT.AMT.MLAT.CD PPG, multilateral (AMT, current US$)
# 14577 DT.DIS.MLAT.CD PPG, multilateral (DIS, current US$)
# 14578 DT.INT.MLAT.CD PPG, multilateral (INT, current US$)
# 14579 DT.AMT.OFFT.CD PPG, official creditors (AMT, current US$)
# 14580 DT.DIS.OFFT.CD PPG, official creditors (DIS, current US$)
# 14581 DT.INT.OFFT.CD PPG, official creditors (INT, current US$)
# 14582 DT.AMT.PROP.CD PPG, other private creditors (AMT, current US$)
# 14583 DT.DIS.PROP.CD PPG, other private creditors (DIS, current US$)
# 14584 DT.INT.PROP.CD PPG, other private creditors (INT, current US$)
# 14585 DT.AMT.PRVT.CD PPG, private creditors (AMT, current US$)
# 14586 DT.DIS.PRVT.CD PPG, private creditors (DIS, current US$)
# 14587 DT.INT.PRVT.CD PPG, private creditors (INT, current US$)
# 14588 DT.AMT.DLXF.CD Principal repayments on external debt, long-term (AMT, current US$)
# 14589 DT.AMT.DPNG.CD Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)
# 14590 IC.CRD.PRVT.ZS Private credit bureau coverage (% of adults)
# 14591 IC.WRH.PROC Procedures to build a warehouse (number)
# 14592 IC.PRP.PROC Procedures to register property (number)
# 14593 IC.TAX.PRFT.CP.ZS Profit tax (% of commercial profits)
# 14594 SG.GEN.PARL.ZS Proportion of seats held by women in national parliaments (%)
# 14595 IC.CRD.PUBL.ZS Public credit registry coverage (% of adults)
# 14596 IQ.SCI.SRCE Source data assessment of statistical capacity (scale 0 - 100)
# 14597 IC.REG.PROC Start-up procedures to register a business (number)
# 14598 IC.LGL.CRED.XQ Strength of legal rights index (0=weak to 12=strong)
# 14599 IC.TAX.PAYM Tax payments (number)
# 14600 IC.WRH.DURS Time required to build a warehouse (days)
# 14601 IC.LGL.DURS Time required to enforce a contract (days)
# 14602 IC.ELC.TIME Time required to get electricity (days)
# 14603 IC.PRP.DURS Time required to register property (days)
# 14604 IC.REG.DURS Time required to start a business (days)
# 14605 IC.TAX.DURS Time to prepare and pay taxes (hours)
# 14606 IC.ISV.DURS Time to resolve insolvency (years)
# 14607 IC.TAX.TOTL.CP.ZS Total tax rate (% of commercial profits)
# 14608 EN.BIR.THRD.NO Bird species, threatened
# 14609 IC.BUS.DISC.XQ Business extent of disclosure index (0=less disclosure to 10=more disclosure)
# 14610 IC.REG.COST.PC.ZS Cost of business start-up procedures (% of GNI per capita)
# 14611 IC.CRD.INFO.XQ Depth of credit information index (0=low to 8=high)
# 14612 DT.DIS.DLXF.CD Disbursements on external debt, long-term (DIS, current US$)
# 14613 IC.BUS.DFRN.XQ Distance to frontier score (0=lowest performance to 100=frontier)
# 14614 IC.BUS.EASE.XQ Ease of doing business index (1=most business-friendly regulations)
# 14615 EN.FSH.THRD.NO Fish species, threatened
# 14616 SH.STA.ACSN Improved sanitation facilities (% of population with access)
# 14617 SH.STA.ACSN.RU Improved sanitation facilities, rural (% of rural population with access)
# 14618 SH.STA.ACSN.UR Improved sanitation facilities, urban (% of urban population with access)
# 14619 SH.H2O.SAFE.ZS Improved water source (% of population with access)
# 14620 SH.H2O.SAFE.RU.ZS Improved water source, rural (% of rural population with access)
# 14621 SH.H2O.SAFE.UR.ZS Improved water source, urban (% of urban population with access)
# 14622 DT.INT.DLXF.CD Interest payments on external debt, long-term (INT, current US$)
# 14623 DT.INT.DPNG.CD Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)
# 14624 IC.TAX.LABR.CP.ZS Labor tax and contributions (% of commercial profits)
# 14625 SH.MMR.RISK.ZS Lifetime risk of maternal death (%)
# 14626 SH.MMR.RISK Lifetime risk of maternal death (1 in: rate varies by country)
# 14627 EN.MAM.THRD.NO Mammal species, threatened
# 14628 SH.STA.MMRT Maternal mortality ratio (modeled estimate, per 100,000 live births)
# 14629 IQ.SCI.MTHD Methodology assessment of statistical capacity (scale 0 - 100)
# 14630 SP.DYN.IMRT.IN Mortality rate, infant (per 1,000 live births)
# 14631 SP.DYN.IMRT.FE.IN Mortality rate, infant, female (per 1,000 live births)
# 14632 SP.DYN.IMRT.MA.IN Mortality rate, infant, male (per 1,000 live births)
# 14633 SH.DYN.NMRT Mortality rate, neonatal (per 1,000 live births)
# 14634 SH.DYN.MORT Mortality rate, under-5 (per 1,000)
# 14635 SH.DYN.MORT.FE Mortality rate, under-5, female (per 1,000 live births)
# 14636 SH.DYN.MORT.MA Mortality rate, under-5, male (per 1,000 live births)
# 14637 SH.DTH.IMRT Number of infant deaths
# 14638 SH.MMR.DTHS Number of maternal deaths
# 14639 SH.DTH.NMRT Number of neonatal deaths
# 14640 SH.DTH.MORT Number of under-five deaths
# 14641 IC.TAX.OTHR.CP.ZS Other taxes payable by businesses (% of commercial profits)
# 14642 IQ.SCI.OVRL Overall level of statistical capacity (scale 0 - 100)
# 14643 IQ.SCI.PRDC Periodicity and timeliness assessment of statistical capacity (scale 0 - 100)
# 14644 EN.HPT.THRD.NO Plant species (higher), threatened
# 14645 DT.AMT.BLAT.CD PPG, bilateral (AMT, current US$)
# 14646 DT.DIS.BLAT.CD PPG, bilateral (DIS, current US$)
# 14647 DT.INT.BLAT.CD PPG, bilateral (INT, current US$)
# 14648 DT.AMT.PBND.CD PPG, bonds (AMT, current US$)
# 14649 DT.INT.PBND.CD PPG, bonds (INT, current US$)
# 14650 DT.AMT.PCBK.CD PPG, commercial banks (AMT, current US$)
# 14651 DT.DIS.PCBK.CD PPG, commercial banks (DIS, current US$)
# 14652 DT.INT.PCBK.CD PPG, commercial banks (INT, current US$)
# 14653 DT.AMT.MLAT.CD PPG, multilateral (AMT, current US$)
# 14654 DT.DIS.MLAT.CD PPG, multilateral (DIS, current US$)
# 14655 DT.INT.MLAT.CD PPG, multilateral (INT, current US$)
# 14656 DT.AMT.OFFT.CD PPG, official creditors (AMT, current US$)
# 14657 DT.DIS.OFFT.CD PPG, official creditors (DIS, current US$)
# 14658 DT.INT.OFFT.CD PPG, official creditors (INT, current US$)
# 14659 DT.AMT.PROP.CD PPG, other private creditors (AMT, current US$)
# 14660 DT.DIS.PROP.CD PPG, other private creditors (DIS, current US$)
# 14661 DT.INT.PROP.CD PPG, other private creditors (INT, current US$)
# 14662 DT.AMT.PRVT.CD PPG, private creditors (AMT, current US$)
# 14663 DT.DIS.PRVT.CD PPG, private creditors (DIS, current US$)
# 14664 DT.INT.PRVT.CD PPG, private creditors (INT, current US$)
# 14665 DT.AMT.DLXF.CD Principal repayments on external debt, long-term (AMT, current US$)
# 14666 DT.AMT.DPNG.CD Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)
# 14667 IC.CRD.PRVT.ZS Private credit bureau coverage (% of adults)
# 14668 IC.WRH.PROC Procedures to build a warehouse (number)
# 14669 IC.PRP.PROC Procedures to register property (number)
# 14670 IC.TAX.PRFT.CP.ZS Profit tax (% of commercial profits)
# 14671 SG.GEN.PARL.ZS Proportion of seats held by women in national parliaments (%)
# 14672 IC.CRD.PUBL.ZS Public credit registry coverage (% of adults)
# 14673 IQ.SCI.SRCE Source data assessment of statistical capacity (scale 0 - 100)
# 14674 IC.REG.PROC Start-up procedures to register a business (number)
# 14675 IC.LGL.CRED.XQ Strength of legal rights index (0=weak to 12=strong)
# 14676 IC.TAX.PAYM Tax payments (number)
# 14677 IC.WRH.DURS Time required to build a warehouse (days)
# 14678 IC.LGL.DURS Time required to enforce a contract (days)
# 14679 IC.ELC.TIME Time required to get electricity (days)
# 14680 IC.PRP.DURS Time required to register property (days)
# 14681 IC.REG.DURS Time required to start a business (days)
# 14682 IC.TAX.DURS Time to prepare and pay taxes (hours)
# 14683 IC.ISV.DURS Time to resolve insolvency (years)
# 14684 IC.TAX.TOTL.CP.ZS Total tax rate (% of commercial profits)
# 14685 EN.BIR.THRD.NO Bird species, threatened
# 14686 IC.BUS.DISC.XQ Business extent of disclosure index (0=less disclosure to 10=more disclosure)
# 14687 IC.REG.COST.PC.ZS Cost of business start-up procedures (% of GNI per capita)
# 14688 IC.CRD.INFO.XQ Depth of credit information index (0=low to 8=high)
# 14689 DT.DIS.DLXF.CD Disbursements on external debt, long-term (DIS, current US$)
# 14690 IC.BUS.DFRN.XQ Distance to frontier score (0=lowest performance to 100=frontier)
# 14691 IC.BUS.EASE.XQ Ease of doing business index (1=most business-friendly regulations)
# 14692 EN.FSH.THRD.NO Fish species, threatened
# 14693 SH.STA.ACSN Improved sanitation facilities (% of population with access)
# 14694 SH.STA.ACSN.RU Improved sanitation facilities, rural (% of rural population with access)
# 14695 SH.STA.ACSN.UR Improved sanitation facilities, urban (% of urban population with access)
# 14696 SH.H2O.SAFE.ZS Improved water source (% of population with access)
# 14697 SH.H2O.SAFE.RU.ZS Improved water source, rural (% of rural population with access)
# 14698 SH.H2O.SAFE.UR.ZS Improved water source, urban (% of urban population with access)
# 14699 DT.INT.DLXF.CD Interest payments on external debt, long-term (INT, current US$)
# 14700 DT.INT.DPNG.CD Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)
# 14701 IC.TAX.LABR.CP.ZS Labor tax and contributions (% of commercial profits)
# 14702 SH.MMR.RISK.ZS Lifetime risk of maternal death (%)
# 14703 SH.MMR.RISK Lifetime risk of maternal death (1 in: rate varies by country)
# 14704 EN.MAM.THRD.NO Mammal species, threatened
# 14705 SH.STA.MMRT Maternal mortality ratio (modeled estimate, per 100,000 live births)
# 14706 IQ.SCI.MTHD Methodology assessment of statistical capacity (scale 0 - 100)
# 14707 SP.DYN.IMRT.IN Mortality rate, infant (per 1,000 live births)
# 14708 SP.DYN.IMRT.FE.IN Mortality rate, infant, female (per 1,000 live births)
# 14709 SP.DYN.IMRT.MA.IN Mortality rate, infant, male (per 1,000 live births)
# 14710 SH.DYN.NMRT Mortality rate, neonatal (per 1,000 live births)
# 14711 SH.DYN.MORT Mortality rate, under-5 (per 1,000)
# 14712 SH.DYN.MORT.FE Mortality rate, under-5, female (per 1,000 live births)
# 14713 SH.DYN.MORT.MA Mortality rate, under-5, male (per 1,000 live births)
# 14714 SH.DTH.IMRT Number of infant deaths
# 14715 SH.MMR.DTHS Number of maternal deaths
# 14716 SH.DTH.NMRT Number of neonatal deaths
# 14717 SH.DTH.MORT Number of under-five deaths
# 14718 IC.TAX.OTHR.CP.ZS Other taxes payable by businesses (% of commercial profits)
# 14719 IQ.SCI.OVRL Overall level of statistical capacity (scale 0 - 100)
# 14720 IQ.SCI.PRDC Periodicity and timeliness assessment of statistical capacity (scale 0 - 100)
# 14721 EN.HPT.THRD.NO Plant species (higher), threatened
# 14722 DT.AMT.BLAT.CD PPG, bilateral (AMT, current US$)
# 14723 DT.DIS.BLAT.CD PPG, bilateral (DIS, current US$)
# 14724 DT.INT.BLAT.CD PPG, bilateral (INT, current US$)
# 14725 DT.AMT.PBND.CD PPG, bonds (AMT, current US$)
# 14726 DT.INT.PBND.CD PPG, bonds (INT, current US$)
# 14727 DT.AMT.PCBK.CD PPG, commercial banks (AMT, current US$)
# 14728 DT.DIS.PCBK.CD PPG, commercial banks (DIS, current US$)
# 14729 DT.INT.PCBK.CD PPG, commercial banks (INT, current US$)
# 14730 DT.AMT.MLAT.CD PPG, multilateral (AMT, current US$)
# 14731 DT.DIS.MLAT.CD PPG, multilateral (DIS, current US$)
# 14732 DT.INT.MLAT.CD PPG, multilateral (INT, current US$)
# 14733 DT.AMT.OFFT.CD PPG, official creditors (AMT, current US$)
# 14734 DT.DIS.OFFT.CD PPG, official creditors (DIS, current US$)
# 14735 DT.INT.OFFT.CD PPG, official creditors (INT, current US$)
# 14736 DT.AMT.PROP.CD PPG, other private creditors (AMT, current US$)
# 14737 DT.DIS.PROP.CD PPG, other private creditors (DIS, current US$)
# 14738 DT.INT.PROP.CD PPG, other private creditors (INT, current US$)
# 14739 DT.AMT.PRVT.CD PPG, private creditors (AMT, current US$)
# 14740 DT.DIS.PRVT.CD PPG, private creditors (DIS, current US$)
# 14741 DT.INT.PRVT.CD PPG, private creditors (INT, current US$)
# 14742 DT.AMT.DLXF.CD Principal repayments on external debt, long-term (AMT, current US$)
# 14743 DT.AMT.DPNG.CD Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)
# 14744 IC.CRD.PRVT.ZS Private credit bureau coverage (% of adults)
# 14745 IC.WRH.PROC Procedures to build a warehouse (number)
# 14746 IC.PRP.PROC Procedures to register property (number)
# 14747 IC.TAX.PRFT.CP.ZS Profit tax (% of commercial profits)
# 14748 SG.GEN.PARL.ZS Proportion of seats held by women in national parliaments (%)
# 14749 IC.CRD.PUBL.ZS Public credit registry coverage (% of adults)
# 14750 IQ.SCI.SRCE Source data assessment of statistical capacity (scale 0 - 100)
# 14751 IC.REG.PROC Start-up procedures to register a business (number)
# 14752 IC.LGL.CRED.XQ Strength of legal rights index (0=weak to 12=strong)
# 14753 IC.TAX.PAYM Tax payments (number)
# 14754 IC.WRH.DURS Time required to build a warehouse (days)
# 14755 IC.LGL.DURS Time required to enforce a contract (days)
# 14756 IC.ELC.TIME Time required to get electricity (days)
# 14757 IC.PRP.DURS Time required to register property (days)
# 14758 IC.REG.DURS Time required to start a business (days)
# 14759 IC.TAX.DURS Time to prepare and pay taxes (hours)
# 14760 IC.ISV.DURS Time to resolve insolvency (years)
# 14761 IC.TAX.TOTL.CP.ZS Total tax rate (% of commercial profits)

# %%
wdi_in = wdi.groupby('CountryName')

# %%
h=list(happiness.Country.unique())

# %%
h.sort()
h
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Bangladesh',
#  'Belarus',
#  'Belgium',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo (Brazzaville)',
#  'Congo (Kinshasa)',
#  'Costa Rica',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Estonia',
#  'Ethiopia',
#  'Finland',
#  'France',
#  'Gabon',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Guatemala',
#  'Guinea',
#  'Haiti',
#  'Honduras',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Ivory Coast',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Laos',
#  'Latvia',
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Lithuania',
#  'Luxembourg',
#  'Macedonia',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Mali',
#  'Malta',
#  'Mauritania',
#  'Mauritius',
#  'Mexico',
#  'Moldova',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Nepal',
#  'Netherlands',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'North Cyprus',
#  'Norway',
#  'Oman',
#  'Pakistan',
#  'Palestinian Territories',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Qatar',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Sierra Leone',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'Somaliland region',
#  'South Africa',
#  'South Korea',
#  'Spain',
#  'Sri Lanka',
#  'Sudan',
#  'Suriname',
#  'Swaziland',
#  'Sweden',
#  'Switzerland',
#  'Syria',
#  'Taiwan',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Togo',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Uzbekistan',
#  'Venezuela',
#  'Vietnam',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe']

# %%
for index, row in wdi.tail(100).iterrows():
    print(index,row.CountryName, row.CountryCode)
# Out:
# 14662 Zambia ZMB
# 14663 Zambia ZMB
# 14664 Zambia ZMB
# 14665 Zambia ZMB
# 14666 Zambia ZMB
# 14667 Zambia ZMB
# 14668 Zambia ZMB
# 14669 Zambia ZMB
# 14670 Zambia ZMB
# 14671 Zambia ZMB
# 14672 Zambia ZMB
# 14673 Zambia ZMB
# 14674 Zambia ZMB
# 14675 Zambia ZMB
# 14676 Zambia ZMB
# 14677 Zambia ZMB
# 14678 Zambia ZMB
# 14679 Zambia ZMB
# 14680 Zambia ZMB
# 14681 Zambia ZMB
# 14682 Zambia ZMB
# 14683 Zambia ZMB
# 14684 Zambia ZMB
# 14685 Zimbabwe ZWE
# 14686 Zimbabwe ZWE
# 14687 Zimbabwe ZWE
# 14688 Zimbabwe ZWE
# 14689 Zimbabwe ZWE
# 14690 Zimbabwe ZWE
# 14691 Zimbabwe ZWE
# 14692 Zimbabwe ZWE
# 14693 Zimbabwe ZWE
# 14694 Zimbabwe ZWE
# 14695 Zimbabwe ZWE
# 14696 Zimbabwe ZWE
# 14697 Zimbabwe ZWE
# 14698 Zimbabwe ZWE
# 14699 Zimbabwe ZWE
# 14700 Zimbabwe ZWE
# 14701 Zimbabwe ZWE
# 14702 Zimbabwe ZWE
# 14703 Zimbabwe ZWE
# 14704 Zimbabwe ZWE
# 14705 Zimbabwe ZWE
# 14706 Zimbabwe ZWE
# 14707 Zimbabwe ZWE
# 14708 Zimbabwe ZWE
# 14709 Zimbabwe ZWE
# 14710 Zimbabwe ZWE
# 14711 Zimbabwe ZWE
# 14712 Zimbabwe ZWE
# 14713 Zimbabwe ZWE
# 14714 Zimbabwe ZWE
# 14715 Zimbabwe ZWE
# 14716 Zimbabwe ZWE
# 14717 Zimbabwe ZWE
# 14718 Zimbabwe ZWE
# 14719 Zimbabwe ZWE
# 14720 Zimbabwe ZWE
# 14721 Zimbabwe ZWE
# 14722 Zimbabwe ZWE
# 14723 Zimbabwe ZWE
# 14724 Zimbabwe ZWE
# 14725 Zimbabwe ZWE
# 14726 Zimbabwe ZWE
# 14727 Zimbabwe ZWE
# 14728 Zimbabwe ZWE
# 14729 Zimbabwe ZWE
# 14730 Zimbabwe ZWE
# 14731 Zimbabwe ZWE
# 14732 Zimbabwe ZWE
# 14733 Zimbabwe ZWE
# 14734 Zimbabwe ZWE
# 14735 Zimbabwe ZWE
# 14736 Zimbabwe ZWE
# 14737 Zimbabwe ZWE
# 14738 Zimbabwe ZWE
# 14739 Zimbabwe ZWE
# 14740 Zimbabwe ZWE
# 14741 Zimbabwe ZWE
# 14742 Zimbabwe ZWE
# 14743 Zimbabwe ZWE
# 14744 Zimbabwe ZWE
# 14745 Zimbabwe ZWE
# 14746 Zimbabwe ZWE
# 14747 Zimbabwe ZWE
# 14748 Zimbabwe ZWE
# 14749 Zimbabwe ZWE
# 14750 Zimbabwe ZWE
# 14751 Zimbabwe ZWE
# 14752 Zimbabwe ZWE
# 14753 Zimbabwe ZWE
# 14754 Zimbabwe ZWE
# 14755 Zimbabwe ZWE
# 14756 Zimbabwe ZWE
# 14757 Zimbabwe ZWE
# 14758 Zimbabwe ZWE
# 14759 Zimbabwe ZWE
# 14760 Zimbabwe ZWE
# 14761 Zimbabwe ZWE

# %%
pivot = wdi.groupby('CountryName')

# %%
table = pd.pivot_table(wdi, values='Value', index='CountryName', columns='IndicatorCode')
table.reset_index(inplace=True)
table
# Out:
# IndicatorCode         CountryName  DT.AMT.BLAT.CD  DT.AMT.DLXF.CD  \
# 0                     Afghanistan      93356000.0     122152000.0
# 1                         Albania      63421000.0     628276000.0
# 2                         Algeria     156481000.0     229092000.0
# 3                  American Samoa             NaN             NaN
# 4                         Andorra             NaN             NaN
# ..                            ...             ...             ...
# 241            West Bank and Gaza             NaN             NaN
# 242                         World             NaN             NaN
# 243                   Yemen, Rep.     149907000.0     443917000.0
# 244                        Zambia      67311000.0     158140000.0
# 245                      Zimbabwe     144888000.0     167018000.0
#
# IndicatorCode  DT.AMT.DPNG.CD  DT.AMT.MLAT.CD  DT.AMT.OFFT.CD  DT.AMT.PBND.CD  \
# 0                         0.0      28796000.0     122152000.0             0.0
# 1                         0.0     156997000.0     220418000.0     364230000.0
# 2                         0.0      13042000.0     169523000.0             0.0
# 3                         NaN             NaN             NaN             NaN
# 4                         NaN             NaN             NaN             NaN
# ..                        ...             ...             ...             ...
# 241                       NaN             NaN             NaN             NaN
# 242                       NaN             NaN             NaN             NaN
# 243                       0.0     293834000.0     443741000.0             0.0
# 244                19214000.0      30215000.0      97526000.0             0.0
# 245                       0.0      21505000.0     166393000.0             0.0
#
# IndicatorCode  DT.AMT.PCBK.CD  DT.AMT.PROP.CD  DT.AMT.PRVT.CD  DT.DIS.BLAT.CD  \
# 0                         0.0             0.0             0.0      10075000.0
# 1                  37376000.0       6252000.0     407858000.0     137095000.0
# 2                   8523000.0      51046000.0      59569000.0      29678000.0
# 3                         NaN             NaN             NaN             NaN
# 4                         NaN             NaN             NaN             NaN
# ..                        ...             ...             ...             ...
# 241                       NaN             NaN             NaN             NaN
# 242                       NaN             NaN             NaN             NaN
# 243                  176000.0             0.0        176000.0      90364000.0
# 244                       0.0      41400000.0      41400000.0     297432000.0
# 245                       0.0        625000.0        625000.0      82512000.0
#
# IndicatorCode  DT.DIS.DLXF.CD  DT.DIS.MLAT.CD  DT.DIS.OFFT.CD  DT.DIS.PCBK.CD  \
# 0                  23323000.0      13248000.0      23323000.0             0.0
# 1                 350193000.0     157102000.0     294197000.0      40916000.0
# 2                  81867000.0      52110000.0      81788000.0             0.0
# 3                         NaN             NaN             NaN             NaN
# 4                         NaN             NaN             NaN             NaN
# ..                        ...             ...             ...             ...
# 241                       NaN             NaN             NaN             NaN
# 242                       NaN             NaN             NaN             NaN
# 243               537722000.0     447358000.0     537722000.0             0.0
# 244               763274000.0     391696000.0     689128000.0             0.0
# 245                83777000.0       1265000.0      83777000.0             0.0
#
# IndicatorCode  DT.DIS.PROP.CD  DT.DIS.PRVT.CD  DT.INT.BLAT.CD  DT.INT.DLXF.CD  \
# 0                         0.0             0.0      49265000.0      60463000.0
# 1                  15080000.0      55996000.0      10959000.0      67325000.0
# 2                     79000.0         79000.0      13945000.0      21832000.0
# 3                         NaN             NaN             NaN             NaN
# 4                         NaN             NaN             NaN             NaN
# ..                        ...             ...             ...             ...
# 241                       NaN             NaN             NaN             NaN
# 242                       NaN             NaN             NaN             NaN
# 243                       0.0             0.0      29897000.0      77728000.0
# 244                74139000.0      74139000.0      35654000.0     170737000.0
# 245                       0.0             0.0      21587000.0      23214000.0
#
# IndicatorCode  DT.INT.DPNG.CD  DT.INT.MLAT.CD  DT.INT.OFFT.CD  DT.INT.PBND.CD  \
# 0                         0.0      11198000.0      60463000.0             0.0
# 1                         0.0      23108000.0      34067000.0      27521000.0
# 2                         0.0             0.0      13945000.0             0.0
# 3                         NaN             NaN             NaN             NaN
# 4                         NaN             NaN             NaN             NaN
# ..                        ...             ...             ...             ...
# 241                       NaN             NaN             NaN             NaN
# 242                       NaN             NaN             NaN             NaN
# 243                       0.0      47831000.0      77728000.0             0.0
# 244                  713000.0       8801000.0      44455000.0     125312000.0
# 245                       0.0       1626000.0      23213000.0             0.0
#
# IndicatorCode  DT.INT.PCBK.CD  DT.INT.PROP.CD  DT.INT.PRVT.CD  EN.BIR.THRD.NO  \
# 0                         0.0             0.0             0.0            17.0
# 1                   5636000.0        101000.0      33258000.0            10.0
# 2                    401000.0       7486000.0       7887000.0            14.0
# 3                         NaN             NaN             NaN             8.0
# 4                         NaN             NaN             NaN             2.0
# ..                        ...             ...             ...             ...
# 241                       NaN             NaN             NaN            13.0
# 242                       NaN             NaN             NaN          4393.0
# 243                       0.0             0.0             0.0            18.0
# 244                       0.0        257000.0     125569000.0            18.0
# 245                       0.0          1000.0          1000.0            17.0
#
# IndicatorCode  EN.FSH.THRD.NO  EN.HPT.THRD.NO  EN.MAM.THRD.NO  FB.AST.NPER.ZS  \
# 0                         5.0             5.0            10.0       13.488399
# 1                        44.0             0.0             3.0       20.900000
# 2                        40.0            18.0            13.0             NaN
# 3                        11.0             1.0             1.0             NaN
# 4                         0.0             0.0             2.0             NaN
# ..                        ...             ...             ...             ...
# 241                       2.0             0.0             3.0        2.487018
# 242                    7819.0         14781.0          3309.0             NaN
# 243                      28.0           162.0             8.0             NaN
# 244                      20.0            20.0            11.0             NaN
# 245                       3.0            17.0            10.0             NaN
#
# IndicatorCode  FB.BNK.CAPA.ZS  IC.BUS.DFRN.XQ  IC.BUS.DISC.XQ  IC.BUS.EASE.XQ  \
# 0                   12.222749       40.580000        1.000000      177.000000
# 1                    9.700000       60.500000        9.000000       97.000000
# 2                         NaN       45.720000        4.000000      163.000000
# 3                         NaN             NaN             NaN             NaN
# 4                         NaN             NaN             NaN             NaN
# ..                        ...             ...             ...             ...
# 241                  9.674752       54.830000        6.000000      129.000000
# 242                       NaN       61.027778        5.525926       94.957672
# 243                       NaN       44.540000        6.000000      170.000000
# 244                       NaN       60.500000        4.000000       97.000000
# 245                       NaN       48.170000        8.000000      155.000000
#
# IndicatorCode  IC.CRD.INFO.XQ  IC.CRD.PRVT.ZS  IC.CRD.PUBL.ZS  IC.CUS.DURS.EX  \
# 0                    0.000000        0.000000        0.500000             NaN
# 1                    6.000000        0.000000       27.100000             NaN
# 2                    0.000000        0.000000        1.900000             NaN
# 3                         NaN             NaN             NaN             NaN
# 4                         NaN             NaN             NaN             NaN
# ..                        ...             ...             ...             ...
# 241                  8.000000        0.000000       22.500000             NaN
# 242                  4.375661       29.554339       11.795238             NaN
# 243                  0.000000        0.000000        1.300000             NaN
# 244                  8.000000        8.900000        0.000000             NaN
# 245                  5.000000       32.100000        0.000000             NaN
#
# IndicatorCode  IC.ELC.DURS  IC.ELC.OUTG  IC.ELC.TIME  IC.FRM.BNKS.ZS  \
# 0                      NaN          NaN   114.000000             NaN
# 1                      NaN          NaN   177.000000             NaN
# 2                      NaN          NaN   180.000000             NaN
# 3                      NaN          NaN          NaN             NaN
# 4                      NaN          NaN          NaN             NaN
# ..                     ...          ...          ...             ...
# 241                    NaN          NaN    63.000000             NaN
# 242                    NaN          NaN    96.634921             NaN
# 243                    NaN          NaN   110.000000             NaN
# 244                    NaN          NaN   117.000000             NaN
# 245                    NaN          NaN   106.000000             NaN
#
# IndicatorCode  IC.FRM.CMPU.ZS  IC.FRM.CORR.ZS  IC.FRM.CRIM.ZS  IC.FRM.DURS  \
# 0                         NaN             NaN             NaN          NaN
# 1                         NaN             NaN             NaN          NaN
# 2                         NaN             NaN             NaN          NaN
# 3                         NaN             NaN             NaN          NaN
# 4                         NaN             NaN             NaN          NaN
# ..                        ...             ...             ...          ...
# 241                       NaN             NaN             NaN          NaN
# 242                       NaN             NaN             NaN          NaN
# 243                       NaN             NaN             NaN          NaN
# 244                       NaN             NaN             NaN          NaN
# 245                       NaN             NaN             NaN          NaN
#
# IndicatorCode  IC.FRM.FEMM.ZS  IC.FRM.FEMO.ZS  IC.FRM.FREG.ZS  IC.FRM.ISOC.ZS  \
# 0                         NaN             NaN             NaN             NaN
# 1                         NaN             NaN             NaN             NaN
# 2                         NaN             NaN             NaN             NaN
# 3                         NaN             NaN             NaN             NaN
# 4                         NaN             NaN             NaN             NaN
# ..                        ...             ...             ...             ...
# 241                       NaN             NaN             NaN             NaN
# 242                       NaN             NaN             NaN             NaN
# 243                       NaN             NaN             NaN             NaN
# 244                       NaN             NaN             NaN             NaN
# 245                       NaN             NaN             NaN             NaN
#
# IndicatorCode  IC.FRM.OUTG.ZS  IC.FRM.TRNG.ZS  IC.GOV.DURS.ZS  IC.ISV.DURS  \
# 0                         NaN             NaN             NaN     2.000000
# 1                         NaN             NaN             NaN     2.000000
# 2                         NaN             NaN             NaN     1.300000
# 3                         NaN             NaN             NaN          NaN
# 4                         NaN             NaN             NaN          NaN
# ..                        ...             ...             ...          ...
# 241                       NaN             NaN             NaN          NaN
# 242                       NaN             NaN             NaN     2.576786
# 243                       NaN             NaN             NaN     3.000000
# 244                       NaN             NaN             NaN     2.400000
# 245                       NaN             NaN             NaN     3.300000
#
# IndicatorCode  IC.LGL.CRED.XQ  IC.LGL.DURS  IC.PRP.DURS  IC.PRP.PROC  \
# 0                     9.00000  1642.000000   250.000000     9.000000
# 1                     7.00000   525.000000    22.000000     6.000000
# 2                     2.00000   630.000000    55.000000    10.000000
# 3                         NaN          NaN          NaN          NaN
# 4                         NaN          NaN          NaN          NaN
# ..                        ...          ...          ...          ...
# 241                   0.00000   540.000000    49.000000     7.000000
# 242                   5.10582   629.871958    48.335676     5.804865
# 243                   0.00000   645.000000    19.000000     6.000000
# 244                   7.00000   611.000000    45.000000     5.000000
# 245                   5.00000   410.000000    36.000000     5.000000
#
# IndicatorCode  IC.REG.COST.PC.ZS  IC.REG.DURS  IC.REG.PROC  IC.TAX.DURS  \
# 0                      19.000000     7.000000     3.000000   275.000000
# 1                      10.400000     5.500000     6.000000   357.000000
# 2                      10.900000    20.000000    12.000000   385.000000
# 3                            NaN          NaN          NaN          NaN
# 4                            NaN          NaN          NaN          NaN
# ..                           ...          ...          ...          ...
# 241                    82.500000    44.000000     9.000000   162.000000
# 242                    26.065079    20.442328     6.910053   260.712698
# 243                    68.000000    40.000000     6.000000   248.000000
# 244                    33.600000     7.500000     6.000000   157.000000
# 245                   112.000000    90.000000     9.000000   242.000000
#
# IndicatorCode  IC.TAX.GIFT.ZS  IC.TAX.LABR.CP.ZS  IC.TAX.METG  \
# 0                         NaN           0.000000          NaN
# 1                         NaN          18.800000          NaN
# 2                         NaN          30.600000          NaN
# 3                         NaN                NaN          NaN
# 4                         NaN                NaN          NaN
# ..                        ...                ...          ...
# 241                       NaN           0.000000          NaN
# 242                       NaN          15.864607          NaN
# 243                       NaN          11.300000          NaN
# 244                       NaN          10.400000          NaN
# 245                       NaN           5.600000          NaN
#
# IndicatorCode  IC.TAX.OTHR.CP.ZS  IC.TAX.PAYM  IC.TAX.PRFT.CP.ZS  \
# 0                      36.300000     20.00000           0.000000
# 1                       3.600000     34.00000          14.100000
# 2                      35.500000     27.00000           6.600000
# 3                            NaN          NaN                NaN
# 4                            NaN          NaN                NaN
# ..                           ...          ...                ...
# 241                     0.300000     28.00000          15.000000
# 242                     8.603933     25.64127          15.887079
# 243                     1.800000     44.00000          20.000000
# 244                     6.200000     26.00000           2.000000
# 245                     8.400000     49.00000          18.800000
#
# IndicatorCode  IC.TAX.TOTL.CP.ZS  IC.WRH.DURS  IC.WRH.PROC  IQ.SCI.MTHD  \
# 0                      36.300000   353.000000    11.000000         40.0
# 1                      36.500000          NaN          NaN         50.0
# 2                      72.700000   204.000000    17.000000         50.0
# 3                            NaN          NaN          NaN          NaN
# 4                            NaN          NaN          NaN          NaN
# ..                           ...          ...          ...          ...
# 241                    15.300000   108.000000    17.000000         80.0
# 242                    40.751323   160.494054    14.295135          NaN
# 243                    33.100000   184.000000    11.000000         60.0
# 244                    18.600000   208.000000    10.000000         40.0
# 245                    32.800000   448.000000    10.000000         50.0
#
# IndicatorCode  IQ.SCI.OVRL  IQ.SCI.PRDC  IQ.SCI.SRCE  SG.GEN.PARL.ZS  \
# 0                51.111100      73.3333         40.0       27.710843
# 1                72.222233      66.6667        100.0       20.714286
# 2                53.333367      80.0001         30.0       31.601732
# 3                      NaN          NaN          NaN             NaN
# 4                      NaN          NaN          NaN       39.285714
# ..                     ...          ...          ...             ...
# 241              80.000000      80.0000         80.0             NaN
# 242                    NaN          NaN          NaN       22.538369
# 243              55.555600      76.6668         30.0        0.000000
# 244              60.000033      80.0001         60.0       12.658228
# 245              62.222200      76.6666         60.0       31.481481
#
# IndicatorCode  SH.DTH.IMRT  SH.DTH.MORT  SH.DTH.NMRT  SH.DYN.MORT  \
# 0                  67399.0      94261.0      36242.0         91.1
# 1                    564.0        618.0        279.0         14.0
# 2                  20899.0      24269.0      14773.0         25.5
# 3                      NaN          NaN          NaN          NaN
# 4                      2.0          2.0          1.0          2.8
# ..                     ...          ...          ...          ...
# 241                 2705.0       3145.0       1771.0         21.1
# 242              4450352.0    5944556.0    2682438.0         42.5
# 243                27775.0      34351.0      18235.0         41.9
# 244                26636.0      38990.0      13188.0         64.0
# 245                25398.0      38087.0      12836.0         70.7
#
# IndicatorCode  SH.DYN.MORT.FE  SH.DYN.MORT.MA  SH.DYN.NMRT  SH.H2O.SAFE.RU.ZS  \
# 0                        87.4            94.6         35.5          47.000000
# 1                        12.5            15.3          6.2          95.200000
# 2                        24.0            26.8         15.5          81.800000
# 3                         NaN             NaN          NaN         100.000000
# 4                         2.6             3.1          1.4         100.000000
# ..                        ...             ...          ...                ...
# 241                      19.3            22.9         11.8          81.500000
# 242                      40.5            44.4         19.2          84.609876
# 243                      38.3            45.5         22.1                NaN
# 244                      58.9            68.9         21.4          51.300000
# 245                      64.9            76.1         23.5          67.300000
#
# IndicatorCode  SH.H2O.SAFE.UR.ZS  SH.H2O.SAFE.ZS  SH.MMR.DTHS  SH.MMR.RISK  \
# 0                      78.200000       55.300000       4300.0         52.0
# 1                      94.900000       95.100000         11.0       1900.0
# 2                      84.300000       83.600000       1300.0        240.0
# 3                     100.000000      100.000000          NaN          NaN
# 4                     100.000000      100.000000          NaN          NaN
# ..                           ...             ...          ...          ...
# 241                    50.700000       58.400000         69.0        490.0
# 242                    96.456467       90.966679     303000.0        180.0
# 243                          NaN             NaN       3300.0         60.0
# 244                    85.600000       65.400000       1400.0         79.0
# 245                    97.000000       76.900000       2400.0         52.0
#
# IndicatorCode  SH.MMR.RISK.ZS  SH.STA.ACSN  SH.STA.ACSN.RU  SH.STA.ACSN.UR  \
# 0                    1.926131    31.900000       27.000000       45.100000
# 1                    0.053361    93.200000       90.200000       95.500000
# 2                    0.419341    87.600000       82.200000       89.800000
# 3                         NaN    62.500000       62.500000       62.500000
# 4                         NaN   100.000000      100.000000      100.000000
# ..                        ...          ...             ...             ...
# 241                  0.205740    92.300000       90.200000       93.000000
# 242                  0.560068    67.522946       50.327703       82.184004
# 243                  1.658729          NaN             NaN             NaN
# 244                  1.258249    43.900000       35.700000       55.600000
# 245                  1.938964    36.800000       30.800000       49.300000
#
# IndicatorCode  SH.STA.MMRT  SI.POV.NAGP  SI.POV.NAHC  SI.POV.RUGP  \
# 0                    396.0          NaN          NaN          NaN
# 1                     29.0          NaN          NaN          NaN
# 2                    140.0          NaN          NaN          NaN
# 3                      NaN          NaN          NaN          NaN
# 4                      NaN          NaN          NaN          NaN
# ..                     ...          ...          ...          ...
# 241                   45.0          NaN          NaN          NaN
# 242                  216.0          NaN          NaN          NaN
# 243                  385.0          NaN          NaN          NaN
# 244                  224.0          NaN          NaN          NaN
# 245                  443.0          NaN          NaN          NaN
#
# IndicatorCode  SI.POV.RUHC  SI.POV.URGP  SI.POV.URHC  SP.DYN.IMRT.FE.IN  \
# 0                      NaN          NaN          NaN               62.1
# 1                      NaN          NaN          NaN               11.2
# 2                      NaN          NaN          NaN               20.5
# 3                      NaN          NaN          NaN                NaN
# 4                      NaN          NaN          NaN                1.9
# ..                     ...          ...          ...                ...
# 241                    NaN          NaN          NaN               16.6
# 242                    NaN          NaN          NaN               29.5
# 243                    NaN          NaN          NaN               30.4
# 244                    NaN          NaN          NaN               39.2
# 245                    NaN          NaN          NaN               41.2
#
# IndicatorCode  SP.DYN.IMRT.IN  SP.DYN.IMRT.MA.IN  SP.HOU.FEMA.ZS
# 0                        66.3               70.3             NaN
# 1                        12.5               13.7             NaN
# 2                        21.9               23.2             NaN
# 3                         NaN                NaN             NaN
# 4                         2.1                2.3             NaN
# ..                        ...                ...             ...
# 241                      18.0               19.4             NaN
# 242                      31.7               33.8             NaN
# 243                      33.8               37.1             NaN
# 244                      43.3               47.2             NaN
# 245                      46.6               51.8             NaN
#
# [246 rows x 104 columns]

# %%
merge = pd.merge(happiness, table, left_on = 'Country', right_on = 'CountryName', how='inner')
merge.drop(columns='CountryName', inplace=True)
merge
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Switzerland      Western Europe               1            7.587
# 1        Iceland      Western Europe               2            7.561
# 2        Denmark      Western Europe               3            7.527
# 3         Norway      Western Europe               4            7.522
# 4         Canada       North America               5            7.427
# ..           ...                 ...             ...              ...
# 134  Afghanistan       Southern Asia             153            3.575
# 135       Rwanda  Sub-Saharan Africa             154            3.465
# 136        Benin  Sub-Saharan Africa             155            3.340
# 137      Burundi  Sub-Saharan Africa             157            2.905
# 138         Togo  Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 4           0.03553                   1.32629  1.32261
# ..              ...                       ...      ...
# 134         0.03084                   0.31982  0.30285
# 135         0.03464                   0.22208  0.77370
# 136         0.03656                   0.28665  0.35386
# 137         0.08658                   0.01530  0.41587
# 138         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 134                   0.30335  0.23414                        0.09719
# 135                   0.42864  0.59201                        0.55191
# 136                   0.31910  0.48450                        0.08010
# 137                   0.22396  0.11850                        0.10062
# 138                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual  DT.AMT.BLAT.CD  DT.AMT.DLXF.CD  \
# 0       0.29678            2.51738             NaN             NaN
# 1       0.43630            2.70201             NaN             NaN
# 2       0.34139            2.49204             NaN             NaN
# 3       0.34699            2.46531             NaN             NaN
# 4       0.45811            2.45176             NaN             NaN
# ..          ...                ...             ...             ...
# 134     0.36510            1.95210      93356000.0     122152000.0
# 135     0.22628            0.67042       3782000.0      25047000.0
# 136     0.18260            1.63328      28067000.0      75306000.0
# 137     0.19727            1.83302       1526000.0      14720000.0
# 138     0.16681            1.56726      12614000.0      39955000.0
#
#      DT.AMT.DPNG.CD  DT.AMT.MLAT.CD  DT.AMT.OFFT.CD  DT.AMT.PBND.CD  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
# ..              ...             ...             ...             ...
# 134             0.0      28796000.0     122152000.0             0.0
# 135             0.0      21265000.0      25047000.0             0.0
# 136             0.0      47239000.0      75306000.0             0.0
# 137             0.0      13194000.0      14720000.0             0.0
# 138             0.0      10953000.0      23567000.0             0.0
#
#      DT.AMT.PCBK.CD  DT.AMT.PROP.CD  DT.AMT.PRVT.CD  DT.DIS.BLAT.CD  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
# ..              ...             ...             ...             ...
# 134             0.0             0.0             0.0      10075000.0
# 135             0.0             0.0             0.0      57762000.0
# 136             0.0             0.0             0.0      92186000.0
# 137             0.0             0.0             0.0      40261000.0
# 138             0.0      16388000.0      16388000.0      88861000.0
#
#      DT.DIS.DLXF.CD  DT.DIS.MLAT.CD  DT.DIS.OFFT.CD  DT.DIS.PCBK.CD  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
# ..              ...             ...             ...             ...
# 134    2.332300e+07    1.324800e+07    2.332300e+07             0.0
# 135    2.371440e+08    1.793820e+08    2.371440e+08             0.0
# 136    3.627700e+08    2.625880e+08    3.547740e+08       7996000.0
# 137    2.703072e+09    2.662811e+09    2.703072e+09             0.0
# 138    2.095820e+08    1.207210e+08    2.095820e+08             0.0
#
#      DT.DIS.PROP.CD  DT.DIS.PRVT.CD  DT.INT.BLAT.CD  DT.INT.DLXF.CD  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
# ..              ...             ...             ...             ...
# 134             0.0             0.0      49265000.0      60463000.0
# 135             0.0             0.0       4429000.0      39149000.0
# 136             0.0       7996000.0       4111000.0      19697000.0
# 137             0.0             0.0        604000.0       2783000.0
# 138             0.0             0.0       6106000.0      12871000.0
#
#      DT.INT.DPNG.CD  DT.INT.MLAT.CD  DT.INT.OFFT.CD  DT.INT.PBND.CD  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
# ..              ...             ...             ...             ...
# 134             0.0      11198000.0      60463000.0             0.0
# 135             0.0       8220000.0      12649000.0      26500000.0
# 136             0.0      15586000.0      19697000.0             0.0
# 137             0.0       2179000.0       2783000.0             0.0
# 138             0.0       6765000.0      12871000.0             0.0
#
#      DT.INT.PCBK.CD  DT.INT.PROP.CD  DT.INT.PRVT.CD  EN.BIR.THRD.NO  \
# 0               NaN             NaN             NaN             6.0
# 1               NaN             NaN             NaN             4.0
# 2               NaN             NaN             NaN             7.0
# 3               NaN             NaN             NaN             7.0
# 4               NaN             NaN             NaN            15.0
# ..              ...             ...             ...             ...
# 134             0.0             0.0             0.0            17.0
# 135             0.0             0.0      26500000.0            16.0
# 136             0.0             0.0             0.0            10.0
# 137             0.0             0.0             0.0            13.0
# 138             0.0             0.0             0.0            11.0
#
#      EN.FSH.THRD.NO  EN.HPT.THRD.NO  EN.MAM.THRD.NO  FB.AST.NPER.ZS  \
# 0               9.0            10.0             2.0             NaN
# 1              16.0             0.0             6.0             NaN
# 2              18.0             4.0             2.0        4.439221
# 3              23.0            14.0             7.0        1.306463
# 4              42.0            11.0            11.0        0.512870
# ..              ...             ...             ...             ...
# 134             5.0             5.0            10.0       13.488399
# 135             9.0             8.0            23.0             NaN
# 136            38.0            17.0            12.0             NaN
# 137            17.0             8.0            12.0       13.123959
# 138            35.0            12.0            11.0             NaN
#
#      FB.BNK.CAPA.ZS  IC.BUS.DFRN.XQ  IC.BUS.DISC.XQ  IC.BUS.EASE.XQ  \
# 0               NaN           76.04             0.0            26.0
# 1               NaN           78.93             7.0            19.0
# 2          7.627405           84.40             7.0             3.0
# 3               NaN           81.61             7.0             9.0
# 4          4.901776           80.07             8.0            14.0
# ..              ...             ...             ...             ...
# 134       12.222749           40.58             1.0           177.0
# 135             NaN           68.12             7.0            62.0
# 136             NaN           47.15             7.0           158.0
# 137       14.375473           48.82             8.0           152.0
# 138             NaN           49.03             7.0           150.0
#
#      IC.CRD.INFO.XQ  IC.CRD.PRVT.ZS  IC.CRD.PUBL.ZS  IC.CUS.DURS.EX  \
# 0               6.0            26.1             0.0             NaN
# 1               7.0           100.0             0.0             NaN
# 2               6.0             7.7             0.0             NaN
# 3               6.0           100.0             0.0             NaN
# 4               8.0           100.0             0.0             NaN
# ..              ...             ...             ...             ...
# 134             0.0             0.0             0.5             NaN
# 135             8.0            18.8             5.4             NaN
# 136             0.0             0.0             0.6             NaN
# 137             0.0             0.0             4.4             NaN
# 138             0.0             0.0             0.5             NaN
#
#      IC.ELC.DURS  IC.ELC.OUTG  IC.ELC.TIME  IC.FRM.BNKS.ZS  IC.FRM.CMPU.ZS  \
# 0            NaN          NaN         39.0             NaN             NaN
# 1            NaN          NaN         22.0             NaN             NaN
# 2            NaN          NaN         38.0             NaN             NaN
# 3            NaN          NaN         66.0             NaN             NaN
# 4            NaN          NaN        137.0             NaN             NaN
# ..           ...          ...          ...             ...             ...
# 134          NaN          NaN        114.0             NaN             NaN
# 135          NaN          NaN         34.0             NaN             NaN
# 136          NaN          NaN         90.0             NaN             NaN
# 137          NaN          NaN        158.0             NaN             NaN
# 138          NaN          NaN         51.0             NaN             NaN
#
#      IC.FRM.CORR.ZS  IC.FRM.CRIM.ZS  IC.FRM.DURS  IC.FRM.FEMM.ZS  \
# 0               NaN             NaN          NaN             NaN
# 1               NaN             NaN          NaN             NaN
# 2               NaN             NaN          NaN             NaN
# 3               NaN             NaN          NaN             NaN
# 4               NaN             NaN          NaN             NaN
# ..              ...             ...          ...             ...
# 134             NaN             NaN          NaN             NaN
# 135             NaN             NaN          NaN             NaN
# 136             NaN             NaN          NaN             NaN
# 137             NaN             NaN          NaN             NaN
# 138             NaN             NaN          NaN             NaN
#
#      IC.FRM.FEMO.ZS  IC.FRM.FREG.ZS  IC.FRM.ISOC.ZS  IC.FRM.OUTG.ZS  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
# ..              ...             ...             ...             ...
# 134             NaN             NaN             NaN             NaN
# 135             NaN             NaN             NaN             NaN
# 136             NaN             NaN             NaN             NaN
# 137             NaN             NaN             NaN             NaN
# 138             NaN             NaN             NaN             NaN
#
#      IC.FRM.TRNG.ZS  IC.GOV.DURS.ZS  IC.ISV.DURS  IC.LGL.CRED.XQ  IC.LGL.DURS  \
# 0               NaN             NaN          3.0             6.0        390.0
# 1               NaN             NaN          1.0             5.0        417.0
# 2               NaN             NaN          1.0             8.0        410.0
# 3               NaN             NaN          0.9             5.0        280.0
# 4               NaN             NaN          0.8             9.0        570.0
# ..              ...             ...          ...             ...          ...
# 134             NaN             NaN          2.0             9.0       1642.0
# 135             NaN             NaN          2.5            11.0        230.0
# 136             NaN             NaN          4.0             6.0        750.0
# 137             NaN             NaN          5.0             2.0        832.0
# 138             NaN             NaN          3.0             6.0        488.0
#
#      IC.PRP.DURS  IC.PRP.PROC  IC.REG.COST.PC.ZS  IC.REG.DURS  IC.REG.PROC  \
# 0           16.0          4.0                2.0         10.0          6.0
# 1            3.5          3.0                2.2          4.0          5.0
# 2            4.0          3.0                0.2          3.0          4.0
# 3            3.0          1.0                0.9          4.0          4.0
# 4           16.5          6.0                0.4          1.5          2.0
# ..           ...          ...                ...          ...          ...
# 134        250.0          9.0               19.0          7.0          3.0
# 135         32.0          3.0               55.0          5.5          7.0
# 136        120.0          4.0               45.3         12.0          7.0
# 137         23.0          5.0               13.4          4.0          3.0
# 138        288.0          5.0               77.8         10.0          6.0
#
#      IC.TAX.DURS  IC.TAX.GIFT.ZS  IC.TAX.LABR.CP.ZS  IC.TAX.METG  \
# 0           63.0             NaN               17.7          NaN
# 1          140.0             NaN               17.7          NaN
# 2          130.0             NaN                3.0          NaN
# 3           83.0             NaN               15.9          NaN
# 4          131.0             NaN               12.7          NaN
# ..           ...             ...                ...          ...
# 134        275.0             NaN                0.0          NaN
# 135        109.0             NaN                5.6          NaN
# 136        270.0             NaN               26.4          NaN
# 137        274.0             NaN               10.2          NaN
# 138        270.0             NaN               23.1          NaN
#
#      IC.TAX.OTHR.CP.ZS  IC.TAX.PAYM  IC.TAX.PRFT.CP.ZS  IC.TAX.TOTL.CP.ZS  \
# 0                  1.8         19.0                9.3               28.8
# 1                  2.8         21.0                9.1               29.6
# 2                  2.8         10.0               18.7               24.5
# 3                  0.0          4.0               23.6               39.5
# 4                  4.5          8.0                3.9               21.1
# ..                 ...          ...                ...                ...
# 134               36.3         20.0                0.0               36.3
# 135                1.6         25.0               25.8               33.0
# 136               21.0         57.0               15.9               63.3
# 137                1.2         25.0               28.9               40.3
# 138               14.7         50.0               10.7               48.5
#
#      IC.WRH.DURS  IC.WRH.PROC  IQ.SCI.MTHD  IQ.SCI.OVRL  IQ.SCI.PRDC  \
# 0          156.0         13.0          NaN          NaN          NaN
# 1           84.0         17.0          NaN          NaN          NaN
# 2           64.0          7.0          NaN          NaN          NaN
# 3          110.5         11.0          NaN          NaN          NaN
# 4          249.0         12.0          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 134        353.0         11.0         40.0    51.111100      73.3333
# 135         77.0         11.0         60.0    73.333367      90.0001
# 136         88.0         13.0         40.0    66.666667      80.0000
# 137         99.0         14.0         40.0    55.555567      86.6667
# 138        165.0         12.0         40.0    65.555567      86.6667
#
#      IQ.SCI.SRCE  SG.GEN.PARL.ZS  SH.DTH.IMRT  SH.DTH.MORT  SH.DTH.NMRT  \
# 0            NaN       30.500000        291.0        334.0        231.0
# 1            NaN       41.269841          7.0          9.0          4.0
# 2            NaN       37.988827        150.0        187.0        129.0
# 3            NaN       39.644970        122.0        160.0         91.0
# 4            NaN       25.328947       1587.0       1824.0       1181.0
# ..           ...             ...          ...          ...          ...
# 134         40.0       27.710843      67399.0      94261.0      36242.0
# 135         70.0       63.750000      10445.0      14207.0       6299.0
# 136         80.0        7.228916      24069.0      37092.0      11955.0
# 137         40.0       30.476190      24956.0      36970.0      13236.0
# 138         70.0       17.582418      13077.0      19512.0       6694.0
#
#      SH.DYN.MORT  SH.DYN.MORT.FE  SH.DYN.MORT.MA  SH.DYN.NMRT  \
# 0            3.9             3.6             4.3          2.7
# 1            2.0             1.8             2.2          0.9
# 2            3.5             3.2             3.9          2.5
# 3            2.6             2.3             2.9          1.5
# 4            4.9             4.5             5.3          3.2
# ..           ...             ...             ...          ...
# 134         91.1            87.4            94.6         35.5
# 135         41.7            37.8            45.4         18.7
# 136         99.5            94.6           104.0         31.8
# 137         81.7            75.6            87.5         28.6
# 138         78.4            72.1            84.4         26.7
#
#      SH.H2O.SAFE.RU.ZS  SH.H2O.SAFE.UR.ZS  SH.H2O.SAFE.ZS  SH.MMR.DTHS  \
# 0                100.0              100.0           100.0          4.0
# 1                100.0              100.0           100.0          0.0
# 2                100.0              100.0           100.0          4.0
# 3                100.0              100.0           100.0          3.0
# 4                 99.0              100.0            99.8         27.0
# ..                 ...                ...             ...          ...
# 134               47.0               78.2            55.3       4300.0
# 135               71.9               86.6            76.1       1100.0
# 136               72.1               85.2            77.9       1600.0
# 137               73.8               91.1            75.9       3500.0
# 138               44.2               91.4            63.1        940.0
#
#      SH.MMR.RISK  SH.MMR.RISK.ZS  SH.STA.ACSN  SH.STA.ACSN.RU  SH.STA.ACSN.UR  \
# 0        12400.0        0.008047         99.9            99.8            99.9
# 1        14600.0        0.006866         98.8           100.0            98.7
# 2         9500.0        0.010535         99.6            99.6            99.6
# 3        11500.0        0.008699         98.1            98.3            98.0
# 4         8800.0        0.011329         99.8            99.0           100.0
# ..           ...             ...          ...             ...             ...
# 134         52.0        1.926131         31.9            27.0            45.1
# 135         85.0        1.178850         61.6            62.9            58.5
# 136         51.0        1.974066         19.7             7.3            35.6
# 137         23.0        4.272948         48.0            48.6            43.8
# 138         58.0        1.717699         11.6             2.9            24.7
#
#      SH.STA.MMRT  SI.POV.NAGP  SI.POV.NAHC  SI.POV.RUGP  SI.POV.RUHC  \
# 0            5.0          NaN          NaN          NaN          NaN
# 1            3.0          NaN          NaN          NaN          NaN
# 2            6.0          NaN          NaN          NaN          NaN
# 3            5.0          NaN          NaN          NaN          NaN
# 4            7.0          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 134        396.0          NaN          NaN          NaN          NaN
# 135        290.0          NaN          NaN          NaN          NaN
# 136        405.0          NaN          NaN          NaN          NaN
# 137        712.0          NaN          NaN          NaN          NaN
# 138        368.0          NaN          NaN          NaN          NaN
#
#      SI.POV.URGP  SI.POV.URHC  SP.DYN.IMRT.FE.IN  SP.DYN.IMRT.IN  \
# 0            NaN          NaN                3.1             3.4
# 1            NaN          NaN                1.4             1.6
# 2            NaN          NaN                2.6             2.9
# 3            NaN          NaN                1.8             2.0
# 4            NaN          NaN                4.0             4.3
# ..           ...          ...                ...             ...
# 134          NaN          NaN               62.1            66.3
# 135          NaN          NaN               27.8            31.1
# 136          NaN          NaN               59.2            64.2
# 137          NaN          NaN               48.0            54.1
# 138          NaN          NaN               46.7            52.3
#
#      SP.DYN.IMRT.MA.IN  SP.HOU.FEMA.ZS
# 0                  3.6             NaN
# 1                  1.7             NaN
# 2                  3.2             NaN
# 3                  2.2             NaN
# 4                  4.7             NaN
# ..                 ...             ...
# 134               70.3             NaN
# 135               34.2             NaN
# 136               68.9             NaN
# 137               60.0             NaN
# 138               57.6             NaN
#
# [139 rows x 115 columns]

# %%
df1=merge.loc[:,'Country':'Dystopia Residual']
df2=merge.loc[:,'SP.DYN.IMRT.IN']
example_subset = pd.concat([df1, df2], axis=1)
example_subset
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Switzerland      Western Europe               1            7.587
# 1        Iceland      Western Europe               2            7.561
# 2        Denmark      Western Europe               3            7.527
# 3         Norway      Western Europe               4            7.522
# 4         Canada       North America               5            7.427
# ..           ...                 ...             ...              ...
# 134  Afghanistan       Southern Asia             153            3.575
# 135       Rwanda  Sub-Saharan Africa             154            3.465
# 136        Benin  Sub-Saharan Africa             155            3.340
# 137      Burundi  Sub-Saharan Africa             157            2.905
# 138         Togo  Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 4           0.03553                   1.32629  1.32261
# ..              ...                       ...      ...
# 134         0.03084                   0.31982  0.30285
# 135         0.03464                   0.22208  0.77370
# 136         0.03656                   0.28665  0.35386
# 137         0.08658                   0.01530  0.41587
# 138         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 134                   0.30335  0.23414                        0.09719
# 135                   0.42864  0.59201                        0.55191
# 136                   0.31910  0.48450                        0.08010
# 137                   0.22396  0.11850                        0.10062
# 138                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual  SP.DYN.IMRT.IN
# 0       0.29678            2.51738             3.4
# 1       0.43630            2.70201             1.6
# 2       0.34139            2.49204             2.9
# 3       0.34699            2.46531             2.0
# 4       0.45811            2.45176             4.3
# ..          ...                ...             ...
# 134     0.36510            1.95210            66.3
# 135     0.22628            0.67042            31.1
# 136     0.18260            1.63328            64.2
# 137     0.19727            1.83302            54.1
# 138     0.16681            1.56726            52.3
#
# [139 rows x 13 columns]

# %%
df1=merge.loc[:,'Country':'Dystopia Residual']
df2=merge.loc[:,'SP.DYN.IMRT.IN',]
example_subset = pd.concat([df1, df2], axis=1)
example_subset
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Switzerland      Western Europe               1            7.587
# 1        Iceland      Western Europe               2            7.561
# 2        Denmark      Western Europe               3            7.527
# 3         Norway      Western Europe               4            7.522
# 4         Canada       North America               5            7.427
# ..           ...                 ...             ...              ...
# 134  Afghanistan       Southern Asia             153            3.575
# 135       Rwanda  Sub-Saharan Africa             154            3.465
# 136        Benin  Sub-Saharan Africa             155            3.340
# 137      Burundi  Sub-Saharan Africa             157            2.905
# 138         Togo  Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 4           0.03553                   1.32629  1.32261
# ..              ...                       ...      ...
# 134         0.03084                   0.31982  0.30285
# 135         0.03464                   0.22208  0.77370
# 136         0.03656                   0.28665  0.35386
# 137         0.08658                   0.01530  0.41587
# 138         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 134                   0.30335  0.23414                        0.09719
# 135                   0.42864  0.59201                        0.55191
# 136                   0.31910  0.48450                        0.08010
# 137                   0.22396  0.11850                        0.10062
# 138                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual  SP.DYN.IMRT.IN
# 0       0.29678            2.51738             3.4
# 1       0.43630            2.70201             1.6
# 2       0.34139            2.49204             2.9
# 3       0.34699            2.46531             2.0
# 4       0.45811            2.45176             4.3
# ..          ...                ...             ...
# 134     0.36510            1.95210            66.3
# 135     0.22628            0.67042            31.1
# 136     0.18260            1.63328            64.2
# 137     0.19727            1.83302            54.1
# 138     0.16681            1.56726            52.3
#
# [139 rows x 13 columns]

# %%
df1=merge.loc[:,'Country':'Dystopia Residual']
df2=merge.loc[:,'SP.DYN.IMRT.IN',]
df3=merge.loc[:,'Country':'Dystopia Residual']
df4=merge.loc[:, 'DT.DIS.PRVT.CD']
example_subset = pd.concat([df1, df2, df4], axis=1)
example_subset
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Switzerland      Western Europe               1            7.587
# 1        Iceland      Western Europe               2            7.561
# 2        Denmark      Western Europe               3            7.527
# 3         Norway      Western Europe               4            7.522
# 4         Canada       North America               5            7.427
# ..           ...                 ...             ...              ...
# 134  Afghanistan       Southern Asia             153            3.575
# 135       Rwanda  Sub-Saharan Africa             154            3.465
# 136        Benin  Sub-Saharan Africa             155            3.340
# 137      Burundi  Sub-Saharan Africa             157            2.905
# 138         Togo  Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 4           0.03553                   1.32629  1.32261
# ..              ...                       ...      ...
# 134         0.03084                   0.31982  0.30285
# 135         0.03464                   0.22208  0.77370
# 136         0.03656                   0.28665  0.35386
# 137         0.08658                   0.01530  0.41587
# 138         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 134                   0.30335  0.23414                        0.09719
# 135                   0.42864  0.59201                        0.55191
# 136                   0.31910  0.48450                        0.08010
# 137                   0.22396  0.11850                        0.10062
# 138                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual  SP.DYN.IMRT.IN  DT.DIS.PRVT.CD
# 0       0.29678            2.51738             3.4             NaN
# 1       0.43630            2.70201             1.6             NaN
# 2       0.34139            2.49204             2.9             NaN
# 3       0.34699            2.46531             2.0             NaN
# 4       0.45811            2.45176             4.3             NaN
# ..          ...                ...             ...             ...
# 134     0.36510            1.95210            66.3             0.0
# 135     0.22628            0.67042            31.1             0.0
# 136     0.18260            1.63328            64.2       7996000.0
# 137     0.19727            1.83302            54.1             0.0
# 138     0.16681            1.56726            52.3             0.0
#
# [139 rows x 14 columns]

# %%
df1=merge.loc[:,'Country':'Dystopia Residual']
df2=merge.loc[:,'SP.DYN.IMRT.IN',]
df3=merge.loc[:, 'DT.DIS.PRVT.CD']
example_subset = pd.concat([df1, df2, df3], axis=1)
example_subset
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Switzerland      Western Europe               1            7.587
# 1        Iceland      Western Europe               2            7.561
# 2        Denmark      Western Europe               3            7.527
# 3         Norway      Western Europe               4            7.522
# 4         Canada       North America               5            7.427
# ..           ...                 ...             ...              ...
# 134  Afghanistan       Southern Asia             153            3.575
# 135       Rwanda  Sub-Saharan Africa             154            3.465
# 136        Benin  Sub-Saharan Africa             155            3.340
# 137      Burundi  Sub-Saharan Africa             157            2.905
# 138         Togo  Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 4           0.03553                   1.32629  1.32261
# ..              ...                       ...      ...
# 134         0.03084                   0.31982  0.30285
# 135         0.03464                   0.22208  0.77370
# 136         0.03656                   0.28665  0.35386
# 137         0.08658                   0.01530  0.41587
# 138         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 134                   0.30335  0.23414                        0.09719
# 135                   0.42864  0.59201                        0.55191
# 136                   0.31910  0.48450                        0.08010
# 137                   0.22396  0.11850                        0.10062
# 138                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual  SP.DYN.IMRT.IN  DT.DIS.PRVT.CD
# 0       0.29678            2.51738             3.4             NaN
# 1       0.43630            2.70201             1.6             NaN
# 2       0.34139            2.49204             2.9             NaN
# 3       0.34699            2.46531             2.0             NaN
# 4       0.45811            2.45176             4.3             NaN
# ..          ...                ...             ...             ...
# 134     0.36510            1.95210            66.3             0.0
# 135     0.22628            0.67042            31.1             0.0
# 136     0.18260            1.63328            64.2       7996000.0
# 137     0.19727            1.83302            54.1             0.0
# 138     0.16681            1.56726            52.3             0.0
#
# [139 rows x 14 columns]

# %%
df1
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Switzerland      Western Europe               1            7.587
# 1        Iceland      Western Europe               2            7.561
# 2        Denmark      Western Europe               3            7.527
# 3         Norway      Western Europe               4            7.522
# 4         Canada       North America               5            7.427
# ..           ...                 ...             ...              ...
# 134  Afghanistan       Southern Asia             153            3.575
# 135       Rwanda  Sub-Saharan Africa             154            3.465
# 136        Benin  Sub-Saharan Africa             155            3.340
# 137      Burundi  Sub-Saharan Africa             157            2.905
# 138         Togo  Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 4           0.03553                   1.32629  1.32261
# ..              ...                       ...      ...
# 134         0.03084                   0.31982  0.30285
# 135         0.03464                   0.22208  0.77370
# 136         0.03656                   0.28665  0.35386
# 137         0.08658                   0.01530  0.41587
# 138         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 134                   0.30335  0.23414                        0.09719
# 135                   0.42864  0.59201                        0.55191
# 136                   0.31910  0.48450                        0.08010
# 137                   0.22396  0.11850                        0.10062
# 138                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 134     0.36510            1.95210
# 135     0.22628            0.67042
# 136     0.18260            1.63328
# 137     0.19727            1.83302
# 138     0.16681            1.56726
#
# [139 rows x 12 columns]

# %%
t=wdi.iloc[:,2:4]
t.drop_duplicates(inplace=True)
t
# Out:
#                                            IndicatorName      IndicatorCode
# 0                               Bird species, threatened     EN.BIR.THRD.NO
# 1      Business extent of disclosure index (0=less di...     IC.BUS.DISC.XQ
# 2      Cost of business start-up procedures (% of GNI...  IC.REG.COST.PC.ZS
# 3      Depth of credit information index (0=low to 8=...     IC.CRD.INFO.XQ
# 4      Distance to frontier score (0=lowest performan...     IC.BUS.DFRN.XQ
# 5      Ease of doing business index (1=most business-...     IC.BUS.EASE.XQ
# 6                               Fish species, threatened     EN.FSH.THRD.NO
# 7      Improved sanitation facilities (% of populatio...        SH.STA.ACSN
# 8      Improved sanitation facilities, rural (% of ru...     SH.STA.ACSN.RU
# 9      Improved sanitation facilities, urban (% of ur...     SH.STA.ACSN.UR
# 10     Improved water source (% of population with ac...     SH.H2O.SAFE.ZS
# 11     Improved water source, rural (% of rural popul...  SH.H2O.SAFE.RU.ZS
# 12     Improved water source, urban (% of urban popul...  SH.H2O.SAFE.UR.ZS
# 13     Labor tax and contributions (% of commercial p...  IC.TAX.LABR.CP.ZS
# 14                   Lifetime risk of maternal death (%)     SH.MMR.RISK.ZS
# 15     Lifetime risk of maternal death (1 in: rate va...        SH.MMR.RISK
# 16                            Mammal species, threatened     EN.MAM.THRD.NO
# 17     Maternal mortality ratio (modeled estimate, pe...        SH.STA.MMRT
# 18        Mortality rate, infant (per 1,000 live births)     SP.DYN.IMRT.IN
# 19     Mortality rate, infant, female (per 1,000 live...  SP.DYN.IMRT.FE.IN
# 20     Mortality rate, infant, male (per 1,000 live b...  SP.DYN.IMRT.MA.IN
# 21      Mortality rate, neonatal (per 1,000 live births)        SH.DYN.NMRT
# 22                   Mortality rate, under-5 (per 1,000)        SH.DYN.MORT
# 23     Mortality rate, under-5, female (per 1,000 liv...     SH.DYN.MORT.FE
# 24     Mortality rate, under-5, male (per 1,000 live ...     SH.DYN.MORT.MA
# 25                             Number of maternal deaths        SH.MMR.DTHS
# 26     Other taxes payable by businesses (% of commer...  IC.TAX.OTHR.CP.ZS
# 27                    Plant species (higher), threatened     EN.HPT.THRD.NO
# 28          Private credit bureau coverage (% of adults)     IC.CRD.PRVT.ZS
# 29              Procedures to build a warehouse (number)        IC.WRH.PROC
# 30              Procedures to register property (number)        IC.PRP.PROC
# 31                  Profit tax (% of commercial profits)  IC.TAX.PRFT.CP.ZS
# 32     Proportion of seats held by women in national ...     SG.GEN.PARL.ZS
# 33         Public credit registry coverage (% of adults)     IC.CRD.PUBL.ZS
# 34     Start-up procedures to register a business (nu...        IC.REG.PROC
# 35     Strength of legal rights index (0=weak to 12=s...     IC.LGL.CRED.XQ
# 36                                 Tax payments (number)        IC.TAX.PAYM
# 37             Time required to build a warehouse (days)        IC.WRH.DURS
# 38            Time required to enforce a contract (days)        IC.LGL.DURS
# 39               Time required to get electricity (days)        IC.ELC.TIME
# 40             Time required to register property (days)        IC.PRP.DURS
# 41              Time required to start a business (days)        IC.REG.DURS
# 42                 Time to prepare and pay taxes (hours)        IC.TAX.DURS
# 43                    Time to resolve insolvency (years)        IC.ISV.DURS
# 44              Total tax rate (% of commercial profits)  IC.TAX.TOTL.CP.ZS
# 63     Methodology assessment of statistical capacity...        IQ.SCI.MTHD
# 73     Overall level of statistical capacity (scale 0...        IQ.SCI.OVRL
# 74     Periodicity and timeliness assessment of stati...        IQ.SCI.PRDC
# 82     Source data assessment of statistical capacity...        IQ.SCI.SRCE
# 94                      Bank capital to assets ratio (%)     FB.BNK.CAPA.ZS
# 95     Bank nonperforming loans to total gross loans (%)     FB.AST.NPER.ZS
# 190    Disbursements on external debt, long-term (DIS...     DT.DIS.DLXF.CD
# 200    Interest payments on external debt, long-term ...     DT.INT.DLXF.CD
# 201    Interest payments on external debt, private no...     DT.INT.DPNG.CD
# 215                              Number of infant deaths        SH.DTH.IMRT
# 217                            Number of neonatal deaths        SH.DTH.NMRT
# 218                          Number of under-five deaths        SH.DTH.MORT
# 223                    PPG, bilateral (AMT, current US$)     DT.AMT.BLAT.CD
# 224                    PPG, bilateral (DIS, current US$)     DT.DIS.BLAT.CD
# 225                    PPG, bilateral (INT, current US$)     DT.INT.BLAT.CD
# 226                        PPG, bonds (AMT, current US$)     DT.AMT.PBND.CD
# 227                        PPG, bonds (INT, current US$)     DT.INT.PBND.CD
# 228             PPG, commercial banks (AMT, current US$)     DT.AMT.PCBK.CD
# 229             PPG, commercial banks (DIS, current US$)     DT.DIS.PCBK.CD
# 230             PPG, commercial banks (INT, current US$)     DT.INT.PCBK.CD
# 231                 PPG, multilateral (AMT, current US$)     DT.AMT.MLAT.CD
# 232                 PPG, multilateral (DIS, current US$)     DT.DIS.MLAT.CD
# 233                 PPG, multilateral (INT, current US$)     DT.INT.MLAT.CD
# 234           PPG, official creditors (AMT, current US$)     DT.AMT.OFFT.CD
# 235           PPG, official creditors (DIS, current US$)     DT.DIS.OFFT.CD
# 236           PPG, official creditors (INT, current US$)     DT.INT.OFFT.CD
# 237      PPG, other private creditors (AMT, current US$)     DT.AMT.PROP.CD
# 238      PPG, other private creditors (DIS, current US$)     DT.DIS.PROP.CD
# 239      PPG, other private creditors (INT, current US$)     DT.INT.PROP.CD
# 240            PPG, private creditors (AMT, current US$)     DT.AMT.PRVT.CD
# 241            PPG, private creditors (DIS, current US$)     DT.DIS.PRVT.CD
# 242            PPG, private creditors (INT, current US$)     DT.INT.PRVT.CD
# 243    Principal repayments on external debt, long-te...     DT.AMT.DLXF.CD
# 244    Principal repayments on external debt, private...     DT.AMT.DPNG.CD
# 3107   Average time to clear exports through customs ...     IC.CUS.DURS.EX
# 3113   Delay in obtaining an electrical connection (d...        IC.ELC.DURS
# 3118   Firms competing against unregistered firms (% ...     IC.FRM.CMPU.ZS
# 3119   Firms expected to give gifts in meetings with ...     IC.TAX.GIFT.ZS
# 3120   Firms formally registered when operations star...     IC.FRM.FREG.ZS
# 3121         Firms offering formal training (% of firms)     IC.FRM.TRNG.ZS
# 3122   Firms using banks to finance investment (% of ...     IC.FRM.BNKS.ZS
# 3123   Firms with female participation in ownership (...     IC.FRM.FEMO.ZS
# 3124          Firms with female top manager (% of firms)     IC.FRM.FEMM.ZS
# 3132   Informal payments to public officials (% of fi...     IC.FRM.CORR.ZS
# 3135   Internationally-recognized quality certificati...     IC.FRM.ISOC.ZS
# 3139   Losses due to theft, robbery, vandalism, and a...     IC.FRM.CRIM.ZS
# 3154   Number of visits or required meetings with tax...        IC.TAX.METG
# 3159   Power outages in firms in a typical month (num...        IC.ELC.OUTG
# 3195   Time required to obtain an operating license (...        IC.FRM.DURS
# 3198   Time spent dealing with the requirements of go...     IC.GOV.DURS.ZS
# 3201   Value lost due to electrical outages (% of sales)     IC.FRM.OUTG.ZS
# 4711           Poverty gap at national poverty lines (%)        SI.POV.NAGP
# 4712   Poverty headcount ratio at national poverty li...        SI.POV.NAHC
# 4741     Rural poverty gap at national poverty lines (%)        SI.POV.RUGP
# 4742   Rural poverty headcount ratio at national pove...        SI.POV.RUHC
# 4755     Urban poverty gap at national poverty lines (%)        SI.POV.URGP
# 4756   Urban poverty headcount ratio at national pove...        SI.POV.URHC
# 13847  Female headed households (% of households with...     SP.HOU.FEMA.ZS

# %%
reset_index_df = t.reset_index()

# %%
indicator_df = reset_index_df.drop(['index'], axis=1)

# %%
pd.set_option('display.max_rows', None)

# %%
indicator_df
# Out:
#                                          IndicatorName      IndicatorCode
# 0                             Bird species, threatened     EN.BIR.THRD.NO
# 1    Business extent of disclosure index (0=less di...     IC.BUS.DISC.XQ
# 2    Cost of business start-up procedures (% of GNI...  IC.REG.COST.PC.ZS
# 3    Depth of credit information index (0=low to 8=...     IC.CRD.INFO.XQ
# 4    Distance to frontier score (0=lowest performan...     IC.BUS.DFRN.XQ
# 5    Ease of doing business index (1=most business-...     IC.BUS.EASE.XQ
# 6                             Fish species, threatened     EN.FSH.THRD.NO
# 7    Improved sanitation facilities (% of populatio...        SH.STA.ACSN
# 8    Improved sanitation facilities, rural (% of ru...     SH.STA.ACSN.RU
# 9    Improved sanitation facilities, urban (% of ur...     SH.STA.ACSN.UR
# 10   Improved water source (% of population with ac...     SH.H2O.SAFE.ZS
# 11   Improved water source, rural (% of rural popul...  SH.H2O.SAFE.RU.ZS
# 12   Improved water source, urban (% of urban popul...  SH.H2O.SAFE.UR.ZS
# 13   Labor tax and contributions (% of commercial p...  IC.TAX.LABR.CP.ZS
# 14                 Lifetime risk of maternal death (%)     SH.MMR.RISK.ZS
# 15   Lifetime risk of maternal death (1 in: rate va...        SH.MMR.RISK
# 16                          Mammal species, threatened     EN.MAM.THRD.NO
# 17   Maternal mortality ratio (modeled estimate, pe...        SH.STA.MMRT
# 18      Mortality rate, infant (per 1,000 live births)     SP.DYN.IMRT.IN
# 19   Mortality rate, infant, female (per 1,000 live...  SP.DYN.IMRT.FE.IN
# 20   Mortality rate, infant, male (per 1,000 live b...  SP.DYN.IMRT.MA.IN
# 21    Mortality rate, neonatal (per 1,000 live births)        SH.DYN.NMRT
# 22                 Mortality rate, under-5 (per 1,000)        SH.DYN.MORT
# 23   Mortality rate, under-5, female (per 1,000 liv...     SH.DYN.MORT.FE
# 24   Mortality rate, under-5, male (per 1,000 live ...     SH.DYN.MORT.MA
# 25                           Number of maternal deaths        SH.MMR.DTHS
# 26   Other taxes payable by businesses (% of commer...  IC.TAX.OTHR.CP.ZS
# 27                  Plant species (higher), threatened     EN.HPT.THRD.NO
# 28        Private credit bureau coverage (% of adults)     IC.CRD.PRVT.ZS
# 29            Procedures to build a warehouse (number)        IC.WRH.PROC
# 30            Procedures to register property (number)        IC.PRP.PROC
# 31                Profit tax (% of commercial profits)  IC.TAX.PRFT.CP.ZS
# 32   Proportion of seats held by women in national ...     SG.GEN.PARL.ZS
# 33       Public credit registry coverage (% of adults)     IC.CRD.PUBL.ZS
# 34   Start-up procedures to register a business (nu...        IC.REG.PROC
# 35   Strength of legal rights index (0=weak to 12=s...     IC.LGL.CRED.XQ
# 36                               Tax payments (number)        IC.TAX.PAYM
# 37           Time required to build a warehouse (days)        IC.WRH.DURS
# 38          Time required to enforce a contract (days)        IC.LGL.DURS
# 39             Time required to get electricity (days)        IC.ELC.TIME
# 40           Time required to register property (days)        IC.PRP.DURS
# 41            Time required to start a business (days)        IC.REG.DURS
# 42               Time to prepare and pay taxes (hours)        IC.TAX.DURS
# 43                  Time to resolve insolvency (years)        IC.ISV.DURS
# 44            Total tax rate (% of commercial profits)  IC.TAX.TOTL.CP.ZS
# 45   Methodology assessment of statistical capacity...        IQ.SCI.MTHD
# 46   Overall level of statistical capacity (scale 0...        IQ.SCI.OVRL
# 47   Periodicity and timeliness assessment of stati...        IQ.SCI.PRDC
# 48   Source data assessment of statistical capacity...        IQ.SCI.SRCE
# 49                    Bank capital to assets ratio (%)     FB.BNK.CAPA.ZS
# 50   Bank nonperforming loans to total gross loans (%)     FB.AST.NPER.ZS
# 51   Disbursements on external debt, long-term (DIS...     DT.DIS.DLXF.CD
# 52   Interest payments on external debt, long-term ...     DT.INT.DLXF.CD
# 53   Interest payments on external debt, private no...     DT.INT.DPNG.CD
# 54                             Number of infant deaths        SH.DTH.IMRT
# 55                           Number of neonatal deaths        SH.DTH.NMRT
# 56                         Number of under-five deaths        SH.DTH.MORT
# 57                   PPG, bilateral (AMT, current US$)     DT.AMT.BLAT.CD
# 58                   PPG, bilateral (DIS, current US$)     DT.DIS.BLAT.CD
# 59                   PPG, bilateral (INT, current US$)     DT.INT.BLAT.CD
# 60                       PPG, bonds (AMT, current US$)     DT.AMT.PBND.CD
# 61                       PPG, bonds (INT, current US$)     DT.INT.PBND.CD
# 62            PPG, commercial banks (AMT, current US$)     DT.AMT.PCBK.CD
# 63            PPG, commercial banks (DIS, current US$)     DT.DIS.PCBK.CD
# 64            PPG, commercial banks (INT, current US$)     DT.INT.PCBK.CD
# 65                PPG, multilateral (AMT, current US$)     DT.AMT.MLAT.CD
# 66                PPG, multilateral (DIS, current US$)     DT.DIS.MLAT.CD
# 67                PPG, multilateral (INT, current US$)     DT.INT.MLAT.CD
# 68          PPG, official creditors (AMT, current US$)     DT.AMT.OFFT.CD
# 69          PPG, official creditors (DIS, current US$)     DT.DIS.OFFT.CD
# 70          PPG, official creditors (INT, current US$)     DT.INT.OFFT.CD
# 71     PPG, other private creditors (AMT, current US$)     DT.AMT.PROP.CD
# 72     PPG, other private creditors (DIS, current US$)     DT.DIS.PROP.CD
# 73     PPG, other private creditors (INT, current US$)     DT.INT.PROP.CD
# 74           PPG, private creditors (AMT, current US$)     DT.AMT.PRVT.CD
# 75           PPG, private creditors (DIS, current US$)     DT.DIS.PRVT.CD
# 76           PPG, private creditors (INT, current US$)     DT.INT.PRVT.CD
# 77   Principal repayments on external debt, long-te...     DT.AMT.DLXF.CD
# 78   Principal repayments on external debt, private...     DT.AMT.DPNG.CD
# 79   Average time to clear exports through customs ...     IC.CUS.DURS.EX
# 80   Delay in obtaining an electrical connection (d...        IC.ELC.DURS
# 81   Firms competing against unregistered firms (% ...     IC.FRM.CMPU.ZS
# 82   Firms expected to give gifts in meetings with ...     IC.TAX.GIFT.ZS
# 83   Firms formally registered when operations star...     IC.FRM.FREG.ZS
# 84         Firms offering formal training (% of firms)     IC.FRM.TRNG.ZS
# 85   Firms using banks to finance investment (% of ...     IC.FRM.BNKS.ZS
# 86   Firms with female participation in ownership (...     IC.FRM.FEMO.ZS
# 87          Firms with female top manager (% of firms)     IC.FRM.FEMM.ZS
# 88   Informal payments to public officials (% of fi...     IC.FRM.CORR.ZS
# 89   Internationally-recognized quality certificati...     IC.FRM.ISOC.ZS
# 90   Losses due to theft, robbery, vandalism, and a...     IC.FRM.CRIM.ZS
# 91   Number of visits or required meetings with tax...        IC.TAX.METG
# 92   Power outages in firms in a typical month (num...        IC.ELC.OUTG
# 93   Time required to obtain an operating license (...        IC.FRM.DURS
# 94   Time spent dealing with the requirements of go...     IC.GOV.DURS.ZS
# 95   Value lost due to electrical outages (% of sales)     IC.FRM.OUTG.ZS
# 96           Poverty gap at national poverty lines (%)        SI.POV.NAGP
# 97   Poverty headcount ratio at national poverty li...        SI.POV.NAHC
# 98     Rural poverty gap at national poverty lines (%)        SI.POV.RUGP
# 99   Rural poverty headcount ratio at national pove...        SI.POV.RUHC
# 100    Urban poverty gap at national poverty lines (%)        SI.POV.URGP
# 101  Urban poverty headcount ratio at national pove...        SI.POV.URHC
# 102  Female headed households (% of households with...     SP.HOU.FEMA.ZS
